# %% [markdown]
# ## Important Library
# 1. https://www.nltk.org/
# - pip install nltk
# 3. https://spacy.io/
# - pip install spacy

# %%
import nltk

# %%
# nltk.download('all')  # Download all available datasets

# %%
corpus = """Hello Welcome, to Data Science NLP Tutorial's.
Please do watch the entire course! to become expert in NLP.
"""

# %%
print(corpus)
# Out:
# Hello Welcome, to Data Science NLP Tutorial's.
# Please do watch the entire course! to become expert in NLP.

# %% [markdown]
# ### Tokenization
# 1. Sentence :- Paragragraphs

# %%
import warnings
warnings.filterwarnings("always")

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.tokenize import sent_tokenize

# %%
documents = sent_tokenize(corpus)

# %%
# print(corpus)

# %%
documents
# Out:
# ["Hello Welcome, to Data Science NLP Tutorial's.",
#  'Please do watch the entire course!',
#  'to become expert in NLP.']

# %%
type(documents)
# Out:
# list

# %%
for i in documents:
    print(i)
# Out:
# Hello Welcome, to Data Science NLP Tutorial's.
# Please do watch the entire course!
# to become expert in NLP.

# %% [markdown]
# ### Tokenization
# - Paragraph --> Words
# - Sentence  --> Words

# %%
from nltk.tokenize import word_tokenize

# %%
corpus
# Out:
# "Hello Welcome, to Data Science NLP Tutorial's.\nPlease do watch the entire course! to become expert in NLP.\n"

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Data',
#  'Science',
#  'NLP',
#  'Tutorial',
#  "'s",
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
for i in documents:
    print(word_tokenize(i))
# Out:
# ['Hello', 'Welcome', ',', 'to', 'Data', 'Science', 'NLP', 'Tutorial', "'s", '.']
# ['Please', 'do', 'watch', 'the', 'entire', 'course', '!']
# ['to', 'become', 'expert', 'in', 'NLP', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Data',
#  'Science',
#  'NLP',
#  'Tutorial',
#  "'",
#  's',
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer = TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Data',
#  'Science',
#  'NLP',
#  "Tutorial's.",
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
Para = """"Basically there's a family where a little boy (Jake) thinks there's a zombie in his closet & his parents are fighting all the time.<br /><br />This movie is slower than a soap opera... and suddenly, Jake decides to become Rambo and kill the zombie.<br /><br />OK, first of all when you're going to make a film you must Decide if its a thriller or a drama! As a drama the movie is watchable. Parents are divorcing & arguing like in real life. And then we have Jake with his closet which totally ruins all the film! I expected to see a BOOGEYMAN similar movie, and instead i watched a drama with some meaningless thriller spots.<br /><br />3 out of 10 just for the well playing parents & descent dialogs. As for the shots with Jake: just ignore them."
"""

# %%
print(Para)
# Out:
# "Basically there's a family where a little boy (Jake) thinks there's a zombie in his closet & his parents are fighting all the time.<br /><br />This movie is slower than a soap opera... and suddenly, Jake decides to become Rambo and kill the zombie.<br /><br />OK, first of all when you're going to make a film you must Decide if its a thriller or a drama! As a drama the movie is watchable. Parents are divorcing & arguing like in real life. And then we have Jake with his closet which totally ruins all the film! I expected to see a BOOGEYMAN similar movie, and instead i watched a drama with some meaningless thriller spots.<br /><br />3 out of 10 just for the well playing parents & descent dialogs. As for the shots with Jake: just ignore them."

# %%
Para = Para.replace("<br />","")

# %%
print(Para)
# Out:
# "Basically there's a family where a little boy (Jake) thinks there's a zombie in his closet & his parents are fighting all the time.This movie is slower than a soap opera... and suddenly, Jake decides to become Rambo and kill the zombie.OK, first of all when you're going to make a film you must Decide if its a thriller or a drama! As a drama the movie is watchable. Parents are divorcing & arguing like in real life. And then we have Jake with his closet which totally ruins all the film! I expected to see a BOOGEYMAN similar movie, and instead i watched a drama with some meaningless thriller spots.3 out of 10 just for the well playing parents & descent dialogs. As for the shots with Jake: just ignore them."

# %%
import nltk

# %%
from nltk.tokenize import sent_tokenize

# %%
sent_tokenize(Para)
# Out:
# ['"Basically there\'s a family where a little boy (Jake) thinks there\'s a zombie in his closet & his parents are fighting all the time.This movie is slower than a soap opera... and suddenly, Jake decides to become Rambo and kill the zombie.OK, first of all when you\'re going to make a film you must Decide if its a thriller or a drama!',
#  'As a drama the movie is watchable.',
#  'Parents are divorcing & arguing like in real life.',
#  'And then we have Jake with his closet which totally ruins all the film!',
#  'I expected to see a BOOGEYMAN similar movie, and instead i watched a drama with some meaningless thriller spots.3 out of 10 just for the well playing parents & descent dialogs.',
#  'As for the shots with Jake: just ignore them."']

# %%
from nltk.tokenize import word_tokenize

# %%
word_tokenize(Para)
# Out:
# ['``',
#  'Basically',
#  'there',
#  "'s",
#  'a',
#  'family',
#  'where',
#  'a',
#  'little',
#  'boy',
#  '(',
#  'Jake',
#  ')',
#  'thinks',
#  'there',
#  "'s",
#  'a',
#  'zombie',
#  'in',
#  'his',
#  'closet',
#  '&',
#  'his',
#  'parents',
#  'are',
#  'fighting',
#  'all',
#  'the',
#  'time.This',
#  'movie',
#  'is',
#  'slower',
#  'than',
#  'a',
#  'soap',
#  'opera',
#  '...',
#  'and',
#  'suddenly',
#  ',',
#  'Jake',
#  'decides',
#  'to',
#  'become',
#  'Rambo',
#  'and',
#  'kill',
#  'the',
#  'zombie.OK',
#  ',',
#  'first',
#  'of',
#  'all',
#  'when',
#  'you',
#  "'re",
#  'going',
#  'to',
#  'make',
#  'a',
#  'film',
#  'you',
#  'must',
#  'Decide',
#  'if',
#  'its',
#  'a',
#  'thriller',
#  'or',
#  'a',
#  'drama',
#  '!',
#  'As',
#  'a',
#  'drama',
#  'the',
#  'movie',
#  'is',
#  'watchable',
#  '.',
#  'Parents',
#  'are',
#  'divorcing',
#  '&',
#  'arguing',
#  'like',
#  'in',
#  'real',
#  'life',
#  '.',
#  'And',
#  'then',
# ...

# %%
--> copus --> sentance --> words
