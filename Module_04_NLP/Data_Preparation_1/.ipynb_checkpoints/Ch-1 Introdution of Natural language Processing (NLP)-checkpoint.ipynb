# %% [markdown]
# ## What is NLP
#
# Natural language processing is a subfield of linguistics, computer science, and artificial intelligence concerned with the interactions between computers and human language, in particular how to program computers to process and analyze large amounts of natural language data.
#
# ![image.png](attachment:3b0918e3-c7e4-4ceb-95fe-df4cdb2986be.png)

# %% [markdown]
# In neuropsychology, linguistics, and the philosophy of language, a natural language or ordinary language is any language that has evolved naturally in humans through use and repetition without conscious planning or premeditation. Natural languages can take different forms, such as speech or signing. They are distinguished from constructed and formal languages such as those used to program computers or to study logic.

# %%
print('\tInput\t\t\t Output(y)')
print("f1\tf2\tf3\tf4 \t| f5")
print("-\t-\t-\t- \t| -")
print("-\t-\t-\t- \t| -")
print("-\t-\t-\t- \t| -")
print("|_________________________|")
print("          ||               ")
print("          Model            ")
print("          ||               ")
print('     y-hat(prediction)           ')
# Out:
# 	Input			 Output(y)
# f1	f2	f3	f4 	| f5
# -	-	-	- 	| -
# -	-	-	- 	| -
# -	-	-	- 	| -
# |_________________________|
#           ||
#           Model
#           ||
#      y-hat(prediction)

# %% [markdown]
# ### What if some of our feature "Text"

# %% [markdown]
# ### Example
# 1. Email Spam Classification
# - Spam
# - Ham(Not Spam)

# %%
print("Email-Subject \t Email_Body \t\t\t\t Spam/Ham")
print()
print("Billionaire \t'You won the lottery of billions$$.' \t    1")
print("\t\t|___________________________________|")
print("\t\t\t\t||                     ")
print("\t\t Changing Meaningful Vectors")
# Out:
# Email-Subject 	 Email_Body 				 Spam/Ham
#
# Billionaire 	'You won the lottery of billions$$.' 	    1
# 		|___________________________________|
# 				||
# 		 Changing Meaningful Vectors

# %% [markdown]
# ### Road of NPL
#
# 0. Stpe 0 :- Programming :- Python
#
# 1. Step 1 :- Text Preprocessing (Cleanning the text data)
# - Tokenization
# - Lemmatization
# - Staming
# - StopWords
#
# 2. Step 2 :- Text Preprocessing (Input text Vectors)
# - Bow(bag of words)
# - TFIDF
# - Uniqram
# - Bigrams
#
# 3. Step 3 :- Text Preprocessing (Input text Vectors)
# - Word2vce
# - fugwords2vce
#
# 4. Step 4 :- Deep Learning
# - Rnn
# - LSTM
# - GRN RNN
# - Word Emidding
# - Tranformer
# - BERT

# %% [markdown]
# ###
# Practical Use case of NLP
# 1. Google Translate
# 2. Gmail - ,sentence completion
# 3. https://text2data.com/demo
# 4. https://huggingface.co
# 5. https://pragnakalp.com/demos/BERT-NLP-QnA-Demo/

# %% [markdown]
# ### Tokenization
# 1. Corpus --> Paragraph
# 2. Docunents --> Sentence
# 3. Vocabularys --> Uniques Words
# 4. Words

# %%
corpus = "My name is Anand and I have a intrest in teaching ML,NLP and DL.I am also a Gamer"
Docunents1 = 'My name is Anand and I have a intrest in teaching ML,NLP and DL'
Docunents2 = 'I am also a Gamer'
