# %% [markdown]
# Google News Pre-train Model

# %%
import gensim
from gensim.models import Word2Vec,KeyedVectors

# %%
# !pip install wget

# %% [markdown]
# ### If you don't want to download everytime this model save in local

# %%
# import gensim.downloader as api

# model = api.load('word2vec-google-news-300')

# %%
# model.save("word2vec-google-news-300.model")

# %%
from gensim.models import KeyedVectors

# Load the saved model
model = KeyedVectors.load("word2vec-google-news-300.model")

# %%
# !wget -c "https://s3.amazonaws.com/dl4j-distribution/GoogleNews-vectors-negative300.bin.gz"

# %%
# model = KeyedVectors.load_word2vec_format('GoogleNews-vectors-negative300.bin.gz',binary=True,limit=500000)

# %%
len(model['men'])
# Out:
# 300

# %%
model['men']
# Out:
# array([-4.78515625e-02,  1.66992188e-01,  7.81250000e-02,  2.10571289e-03,
#         2.25585938e-01, -2.25585938e-01, -2.09960938e-01, -3.73535156e-02,
#        -1.85546875e-02,  1.94335938e-01, -3.00292969e-02, -1.77734375e-01,
#         5.20019531e-02,  1.33789062e-01, -1.13769531e-01,  1.10351562e-01,
#        -3.27148438e-02,  2.89916992e-03,  9.88769531e-03,  9.27734375e-02,
#        -2.19726562e-01, -2.47802734e-02, -8.59375000e-02, -2.67578125e-01,
#        -2.51464844e-02, -2.55859375e-01, -1.61132812e-01,  2.53906250e-01,
#         5.24902344e-02, -1.00097656e-02,  1.82617188e-01,  7.61718750e-02,
#        -1.60980225e-03, -3.10058594e-02, -3.32031250e-02,  1.81640625e-01,
#        -3.88183594e-02, -1.83593750e-01, -8.64257812e-02,  2.20703125e-01,
#        -7.11059570e-03,  8.60595703e-03,  1.73828125e-01, -9.27734375e-02,
#         1.25000000e-01, -1.28906250e-01, -4.85839844e-02, -1.21093750e-01,
# ...

# %% [markdown]
# **Vectors**

# %%
model.most_similar('men')
# Out:
# [('women', 0.7674936652183533),
#  ('Men', 0.6301246285438538),
#  ('males', 0.6242231726646423),
#  ('mens', 0.5807526111602783),
#  ('boys', 0.5781348347663879),
#  ('man', 0.5489763021469116),
#  ('females', 0.5481873750686646),
#  ('teenagers', 0.5462744235992432),
#  ('girls', 0.540932834148407),
#  ('ladies', 0.5234237313270569)]

# %%
model.most_similar('food')
# Out:
# [('foods', 0.6804922819137573),
#  ('Food', 0.6538903713226318),
#  ('foodstuffs', 0.6425830125808716),
#  ('meals', 0.6166685819625854),
#  ('food_stuffs', 0.5928642153739929),
#  ('nourishing_meals', 0.5847609043121338),
#  ('foodstuff', 0.5835225582122803),
#  ('staple_foods', 0.5535788536071777),
#  ('nutritious', 0.5466451644897461),
#  ('meal', 0.5433712601661682)]

# %%
model.most_similar('facebook')
# Out:
# [('Facebook', 0.7563533186912537),
#  ('FaceBook', 0.7076998949050903),
#  ('twitter', 0.6988552808761597),
#  ('myspace', 0.6941817998886108),
#  ('Twitter', 0.664244532585144),
#  ('twitter_facebook', 0.6572229862213135),
#  ('Facebook.com', 0.6529868245124817),
#  ('myspace_facebook', 0.6370643973350525),
#  ('facebook_twitter', 0.6367618441581726),
#  ('linkedin', 0.6356592774391174)]

# %%
len(model.most_similar('facebook'))
# Out:
# 10

# %%
print(model.similarity('man','rich'))
# Out:
# 0.16205195

# %%
print(model.similarity('man','Mysql'))
# Out:
# 0.026557919

# %%
model.doesnt_match(['PHP','java','monkey'])
# Out:
# 'monkey'

# %%
# model.most_similar(positive=['king', 'woman'], negative=['boy'])

# %%
vec = model['King'] - model['man'] + model['women']
model.most_similar([vec])
# Out:
# [('King', 0.5849703550338745),
#  ('women', 0.5633348822593689),
#  ('Women', 0.46788811683654785),
#  ('womens', 0.42034003138542175),
#  ('Al_Anqari', 0.4158094823360443),
#  ("Women's", 0.4115424156188965),
#  ('gender_equality', 0.3964197039604187),
#  ('male_counterparts', 0.39235392212867737),
#  ('Pink_Ribbons', 0.38926416635513306),
#  ('M._Bulik', 0.38446056842803955)]

# %%
vec = model['INR'] - model ['India'] + model['England']
model.most_similar([vec])
# Out:
# [('INR', 0.6442341208457947),
#  ('GBP', 0.5040826797485352),
#  ('£_##.###m', 0.4540838301181793),
#  ('England', 0.4464925527572632),
#  ('£', 0.43341004848480225),
#  ('Â_£', 0.4307197630405426),
#  ('stg###', 0.42992618680000305),
#  ('£_#.##m', 0.42561301589012146),
#  ('Pounds_Sterling', 0.42512619495391846),
#  ('GBP##', 0.42464491724967957)]

# %%
# word2vec
