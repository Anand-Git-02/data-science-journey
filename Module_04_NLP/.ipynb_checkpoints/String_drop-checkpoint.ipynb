# %% [markdown]
# # Data Cleanning

# %% [markdown]
# ### Step :- 1 Chaning Text into Lower_case

# %% [markdown]
# ### Step :- 2 Remove HTML Tags

# %% [markdown]
# ### Step :- 3 Remove URLs

# %% [markdown]
# ### Step :- 4 Remove Punctuations

# %% [markdown]
# ### Step :- 5 Chat Words Treatments

# %% [markdown]
# ### Step :- 6 Spelling Correction

# %% [markdown]
# ### Step :- 7 Handling Emoojis
# - Remove
# - Replace
