# %%
import torch
import math
import numpy as np

# %%
# Inputs
x = torch.tensor(6.7)  # Input feature
y = torch.tensor(0.0)  # True label (binary)

w = torch.tensor(1.0)  # Weight
b = torch.tensor(0.0)  # Bias

# %% [markdown]
# #### 1. Forward pass

# %%
z = w * x + b  # Weighted sum (linear part)
y_pred = torch.sigmoid(z)  # Predicted probability

# %%
z
# Out:
# tensor(6.7000)

# %%
y_pred
# Out:
# tensor(0.9988)

# %%
# Binary Cross-Entropy Loss for scalar
def binary_cross_entropy_loss(prediction, target):
    epsilon = 1e-8  # To prevent log(0)
    prediction = torch.clamp(prediction, epsilon, 1 - epsilon)
    return -(target * torch.log(prediction) + (1 - target) * torch.log(1 - prediction))

# %%
# Compute binary cross-entropy loss
loss = binary_cross_entropy_loss(y_pred, y)

# %%
loss
# Out:
# tensor(6.7012)

# %% [markdown]
# ### 2. Backwade pass

# %%
# Derivatives:
# 1. dL/d(y_pred): Loss with respect to the prediction (y_pred)
dloss_dy_pred = (y_pred - y)/(y_pred*(1-y_pred))

# 2. dy_pred/dz: Prediction (y_pred) with respect to z (sigmoid derivative)
dy_pred_dz = y_pred * (1 - y_pred)

# 3. dz/dw and dz/db: z with respect to w and b
dz_dw = x  # dz/dw = x
dz_db = 1  # dz/db = 1 (bias contributes directly to z)

dL_dw = dloss_dy_pred * dy_pred_dz * dz_dw
dL_db = dloss_dy_pred * dy_pred_dz * dz_db

# %%
print(f"Manual Gradient of loss w.r.t weight (dw): {dL_dw}")
print(f"Manual Gradient of loss w.r.t bias (db): {dL_db}")
# Out:
# Manual Gradient of loss w.r.t weight (dw): 6.691762447357178
# Manual Gradient of loss w.r.t bias (db): 0.998770534992218

# %% [markdown]
# ### Autograd

# %%
# Inputs
x = torch.tensor(6.7)  # Input feature
y = torch.tensor(0.0)  # True label (binary)

w = torch.tensor(1.0,requires_grad=True)  # Weight
b = torch.tensor(0.0,requires_grad=True)  # Bias

# %%
# forward pass
z = w*x + b
y_pred = torch.sigmoid(z)  # Predicted probability

# %%
z
# Out:
# tensor(6.7000, grad_fn=<AddBackward0>)

# %%
y_pred
# Out:
# tensor(0.9988, grad_fn=<SigmoidBackward0>)

# %%
loss = binary_cross_entropy_loss(y_pred, y)

# %%
loss
# Out:
# tensor(6.7012, grad_fn=<NegBackward0>)

# %%
loss.backward()

# %%
print(w.grad)
print(b.grad)
# Out:
# tensor(6.6918)
# tensor(0.9988)

# %% [markdown]
# ### Clearing Grad

# %%
x1 = torch.tensor(2.0,requires_grad=True)

# %%
x1
# Out:
# tensor(2., requires_grad=True)

# %%
y = x1 ** 2

# %%
y.backward()

# %%
x1.grad
# Out:
# tensor(4.)

# %%
x1.grad.zero_()
# Out:
# tensor(0.)

# %% [markdown]
# ### disable gradient tracking

# %% [markdown]
# ##### option 1 - requires_grad_(False)

# %%
x2 = torch.tensor(4.0,requires_grad=True)
y = x2 ** 2

# %%
y.backward()

# %%
x2.grad
# Out:
# tensor(8.)

# %%
x2
# Out:
# tensor(4., requires_grad=True)

# %%
x2.requires_grad_(False)
# Out:
# tensor(4.)

# %%
y = x2 ** 2
y
# Out:
# tensor(16.)

# %%
y.backward()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 y.backward()
#
# File ~/miniconda3/envs/torch_nlp/lib/python3.11/site-packages/torch/_tensor.py:630, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     620 if has_torch_function_unary(self):
#     621     return handle_torch_function(
#     622         Tensor.backward,
#     623         (self,),
#    (...)    628         inputs=inputs,
#     629     )
# --> 630 torch.autograd.backward(
#     631     self, gradient, retain_graph, create_graph, inputs=inputs
#     632 )
#
# File ~/miniconda3/envs/torch_nlp/lib/python3.11/site-packages/torch/autograd/__init__.py:364, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     359     retain_graph = create_graph
#     361 # The reason we repeat the same comment below is that
#     362 # some Python versions print out the first line of a multi-line function
#     363 # calls in the traceback and some print out the last line
# --> 364 _engine_run_backward(
#     365     tensors,
#     366     grad_tensors_,
#     367     retain_graph,
#     368     create_graph,
#     369     inputs_tuple,
#     370     allow_unreachable=True,
#     371     accumulate_grad=True,
#     372 )
#
# File ~/miniconda3/envs/torch_nlp/lib/python3.11/site-packages/torch/autograd/graph.py:865, in _engine_run_backward(t_outputs, *args, **kwargs)
#     863     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     864 try:
# --> 865     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     866         t_outputs, *args, **kwargs
#     867     )  # Calls into the C++ engine to run the backward pass
#     868 finally:
#     869     if attach_logging_hooks:
#
# RuntimeError: Trying to backward through the graph a second time (or directly access saved tensors after they have already been freed). Saved intermediate values of the graph are freed when you call .backward() or autograd.grad(). Specify retain_graph=True if you need to backward through the graph a second time or if you need to access saved tensors after calling backward.

# %% [markdown]
# ##### option 2 - detach()

# %%
x3 = torch.tensor(4.0, requires_grad=True)

# %%
x3
# Out:
# tensor(4., requires_grad=True)

# %%
z = x3.detach()
z
# Out:
# tensor(4.)

# %%
y = x3 ** 2
y
# Out:
# tensor(16., grad_fn=<PowBackward0>)

# %%
y1 = z ** 2
y1
# Out:
# tensor(16.)

# %% [markdown]
# ##### option 3 - torch.no_grad()

# %%
x4 = torch.tensor(4.0,requires_grad=True)
x5 = torch.tensor(5.0,requires_grad=True)

# %%
with torch.no_grad():
    y100 = x4 ** 4
y200 = x4 ** 4

# %%
y100 , y200
# Out:
# (tensor(256.), tensor(256., grad_fn=<PowBackward0>))
