# %%
# write
# read

# step 1 read

with open('Dummy_Files/Example100.txt','r') as copy_file:
    content = copy_file.read()

with open(r'C:\Users\Lenovo\OneDrive\Desktop\Python\python_6_8_25.txt','w') as paste_file:
    paste_file.write(content)

# %%
with open('Dummy_Files/Example.txt','+w') as file:
    file.write('Hello World')
    file.write('\nThis is a new line') 

    file.seek(0)

    print(file.read())
# Out:
# Hello World
# This is a new line

# %%
#### Using the os module
import os
cwd=os.getcwd()
print(f"Current working directory is {cwd}")
# Out:
# Current working directory is C:\Users\Lenovo\Data Science\Classroom\Module_1\Python_Basic

# %%
## create a new directory
new_directory="Python1000"
os.mkdir(new_directory)
print(f"Directory '{new_directory}' create")
# Out:
# Directory 'Python1000' create

# %%
## Listing Files And Directories
items=os.listdir('.')
print(items)
# Out:
# ['.git', '.ipynb_checkpoints', 'Advance_Python', 'Ch-1. Python_Basic_print_function().ipynb', 'Ch-1.2 Operators_and_Variables.ipynb', 'Ch-2 Control Flow Statements.ipynb', 'Ch-3.1 Data Structures List.ipynb', 'Ch-3.2 Tuples.ipynb', 'Ch-3.3 Sets.ipynb', 'Ch-3.4 Dictionary_.ipynb', 'Ch-4 Functions.ipynb', 'Ch-5 Modules.ipynb', 'Ch-6 File Operation.ipynb', 'Ch-7 Exception Handling In Python.ipynb', 'drop_files', 'Dummy_Files', 'EH_Python_5_8_25.ipynb', 'Exercise', 'File_Handing_Exercise', 'my_module.py', 'package', 'Python1000', 'Python_5_8_25.ipynb', 'Sets_16_7_25.ipynb', '__pycache__']

# %%
dir_name="folder"
file_name="file.txt"
full_path=os.path.join(dir_name,file_name)
print(full_path)
# Out:
# folder\file.txt

# %%
path='my_module.py'
if os.path.exists(path):
    print(f"The path '{path}' exists")
else:
    print(f"The path '{path}' does not exists")
# Out:
# The path 'my_module.py' exists

# %%
#Checking if a Path is a File or Directory
import os

path = 'Dummy_Files'
if os.path.isfile(path):
    print(f"The path '{path}' is a file.")
elif os.path.isdir(path):
    print(f"The path '{path}' is a directory.")
else:
    print(f"The path '{path}' is neither a file nor a directory.")
# Out:
# The path 'Dummy_Files' is a directory.
