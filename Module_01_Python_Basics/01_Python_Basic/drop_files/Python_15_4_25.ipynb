# %%
print("Hello World")
# Out:
# Hello World

# %%
# Hello "World"

print("Hello "World"")
# Out:
#   Cell In[2], line 3
#     print("Hello "World"")
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print('Hello "World"')
# Out:
# Hello "World"

# %%
print("Hello \"World\"")
# Out:
# Hello "World"

# %%
print('Hello \'World\'')
# Out:
# Hello 'World'

# %%
print(" \\\\ ")
# Out:
#  \\

# %%
print("Hello \t2")
# Out:
# Hello 	2

# %%
print("Helll\bo")
# Out:
# Hello

# %%
print('Line1')
print("Line2")
# Out:
# Line1
# Line2

# %%
print("Line1\nLine2")
# Out:
# Line1
# Line2

# %%
print('Line1',end=" ")
print("Line2")
# Out:
# Line1 Line2

# %%
print(3 + 5)
# Out:
# 8

# %%
# Datatypes

# number
# 1. int
# 2.float
# 3.complex

# text
# 1.string

# container types
# 1. list
# 2. tuples
# 3. set

# mapping types
# 1. Dictionarys

# %%
# number
# 1. int
print(5)
print(type(5))

# 2.float
print(5.5)
print(type(5.5))


# 3.complex
print(2+3j)
print(type(2+3j))
# Out:
# 5
# <class 'int'>
# 5.5
# <class 'float'>
# (2+3j)
# <class 'complex'>

# %%
print("Hello Anand I am 24 Years old")
# Out:
# Hello Anand I am 24 Years old

# %%
# variable

name = "Anand"

age = 24

print(f"Hello {name} I am {age} Years old")
# Out:
# Hello Anand I am 24 Years old

# %%
# variable

name = input("Enter Your Name :-")

age = input("Enter Your Age   :-")

print(f"Hello {name} I am {age} Years old")
# Out:
# Enter Your Name :- Jack
# Enter Your Age   :- 25
# Hello Jack I am 25 Years old

# %%
# operators

# Arithmetic operators (+,-,*,/,//,%,**)
a = 10
b = 2

a ** b
# Out:
# 100

# %%
# Comparison/Relation operators (<,> ,<= ,>= , == , !=)
# Logical operators
a1 = 5
a2 = 6

print("<",a1 < a2)
print(">",a1 > a2)
print("<=",a1 <= a2)
print(">=",a1 >= a2)
print("==",a1 == a2)
print("!=",a1 != a2)
# Out:
# < True
# > False
# <= True
# >= False
# == False
# != True

# %%
# Bitwise operators (& and |)

print(2 & 3)
print(2 | 3)
print(2 ^ 3)
# Out:
# 2
# 3
# 1

# %%
# Assignment operators
name = "Goku"

num1 = 5

# num1 = num1 + 1
num1 /= 2

print(num1)
# Out:
# 2.5

# %%
# Membership operators (in and not in)

"P" in  "Python"
# Out:
# True

# %%
"P" not in  "Python"
# Out:
# False

# %%
# container types
# 1. list

elements = [1,2,3,4,5]

# 2. tuples
tuples = (1,2,3,4)

# 3. set
set1 = {1,2,3,4}

# %%
elements = [1,2,3,4,5]

1 in elements
# Out:
# True

# %%
2
# Out:
# 2

# %%
a = 5

a = "Apple"

a = 5.6

a = True

print(a)
# Out:
# True

# %%
a = 5

# %%
a , b = 1 ,5

print(a,b)
# Out:
# 1 5

# %%
a = 3 ; b = 6 ; c = 10

print(a,b,c,sep="*")
# Out:
# 3*6*10

# %%
print("Line 1",end="")
print("Line 2")
# Out:
# Line 1Line 2

# %%
import keyword

print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
frist_name = "Anand"
last_name = "Menat"

frist_name + " " + last_name
# Out:
# 'Anand Menat'

# %%
num1 = input("Enter Your First  Number :-")
num2 = input("Enter Your Second NUmber :-")

int(num1) + int(num2)
# Out:
# Enter Your First  Number :- 25
# Enter Your Second NUmber :- 5
# 30

# %%
bool(1)
# Out:
# True

# %%
"Anand 24".split()
# Out:
# ['Anand', '2', '4']

# %%
# one line name and age

# %%
name , age = input("Enter Your name and Age").split()
print(name,age)
# Out:
# Enter Your name and Age Anand 24
# Anand 24

# %%
"Anand,24".split(",")
# Out:
# ['Anand', '24']

# %%
a = "Python"
a[2]
# Out:
# 't'

# %%
len(a)
# Out:
# 6

# %%
# [start,end,step]

a[0:]
# Out:
# 'Python'

# %%
a[1:]
# Out:
# 'ython'

# %%
a[0:3]
# Out:
# 'Pyt'

# %%
a[0:6:2]
# Out:
# 'Pto'
