# %% [markdown]
# Here are 20 exercises that involve `if` and `else` statements in Python:
#
# ### 1. Check Positive or Negative
# Write a program that takes an integer input and checks whether it is positive, negative, or zero.
#
# **Input:**
# `5`
# **Output:**
# `Positive`
#
# ---

# %% [markdown]
# ### 2. Check Even or Odd
# Write a program that checks if a number is even or odd.
#
# **Input:**
# `4`
# **Output:**
# `Even`
#
# ---

# %% [markdown]
# ### 3. Check Leap Year
# Write a program that checks whether a given year is a leap year.
#
# **Input:**
# `2024`
# **Output:**
# `Leap Year`
#
# ---

# %% [markdown]
# ### 4. Compare Two Numbers
# Write a program that compares two numbers and prints which one is greater, or if they are equal.
#
# **Input:**
# `5`, `10`
# **Output:**
# `10 is greater`
#
# ---

# %% [markdown]
# ### 5. Grade Checker
# Write a program that takes a score and outputs a grade (A, B, C, D, or F) based on the score.
#
# **Input:**
# `85`
# **Output:**
# `B`
#
# ---

# %% [markdown]
# ### 6. Check Divisibility
# Write a program that checks if a number is divisible by both 5 and 7.
#
# **Input:**
# `35`
# **Output:**
# `Divisible by both`
#
# ---

# %% [markdown]
# ### 7. Largest of Three Numbers
# Write a program that takes three numbers and prints the largest one.
#
# **Input:**
# `12`, `45`, `32`
# **Output:**
# `45 is the largest`
#
# ---

# %% [markdown]
# ### 8. Check Alphabet or Not
# Write a program that checks if a character is an alphabet.
#
# **Input:**
# `'A'`
# **Output:**
# `Alphabet`
#
# ---

# %% [markdown]
# ### 9. Check Vowel or Consonant
# Write a program that checks if a character is a vowel or a consonant.
#
# **Input:**
# `'e'`
# **Output:**
# `Vowel`
#
# ---

# %% [markdown]
# ### 10. Check for Palindrome
# Write a program that checks if a string is a palindrome.
#
# **Input:**
# `"madam"`
# **Output:**
# `Palindrome`
#
# ---

# %% [markdown]
# ### 11. Eligible for Voting
# Write a program that checks if a person is eligible to vote based on their age.
#
# **Input:**
# `19`
# **Output:**
# `Eligible`
#
# ---

# %% [markdown]
# ### 12. Check Multiple Conditions
# Write a program that takes a number and prints if it’s positive and even, negative and odd, or zero.
#
# **Input:**
# `-3`
# **Output:**
# `Negative and odd`
#
# ---

# %% [markdown]
# ### 13. Simple Calculator
# Write a program that takes two numbers and an operator (`+`, `-`, `*`, `/`) and performs the corresponding operation.
#
# **Input:**
# `10, 5, '+'`
# **Output:**
# `15`
#
# ---

# %% [markdown]
# ### 14. Check Triangle Validity
# Write a program that checks if three given side lengths can form a triangle.
#
# **Input:**
# `3, 4, 5`
# **Output:**
# `Valid triangle`
#
# ---

# %% [markdown]
# ### 15. Check Temperature
# Write a program that takes a temperature and checks whether it’s cold, warm, or hot.
#
# **Input:**
# `32`
# **Output:**
# `Cold`
#
# ---

# %% [markdown]
# ### 16. Check Divisibility by 3 or 5
# Write a program that checks if a number is divisible by 3, 5, or both.
#
# **Input:**
# `15`
# **Output:**
# `Divisible by both 3 and 5`
#
# ---

# %% [markdown]
# ### 17. Find Smallest of Three Numbers
# Write a program that takes three numbers and prints the smallest one.
#
# **Input:**
# `12, 7, 19`
# **Output:**
# `7 is the smallest`
#
# ---

# %% [markdown]
# ### 18. Traffic Light System
# Write a program that simulates a traffic light system by taking input as "red", "yellow", or "green" and printing the appropriate action.
#
# **Input:**
# `"red"`
# **Output:**
# `Stop`
#
# ---

# %% [markdown]
# ### 19. Calculate Discount
# Write a program that calculates the final price after applying a discount. If the price is above 1000, apply a 10% discount.
#
# **Input:**
# `1500`
# **Output:**
# `1350.0`
#
# ---

# %% [markdown]
# ### 20. Check if Number is Prime
# Write a program that checks if a given number is prime.
#
# **Input:**
# `7`
# **Output:**
# `Prime`
#
# ---
