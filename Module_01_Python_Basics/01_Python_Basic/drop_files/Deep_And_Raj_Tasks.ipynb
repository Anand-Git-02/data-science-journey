# %%
print('Hello World')
# Out:
# Hello World

# %%
print("Hello world")
# Out:
# Hello world

# %%
print(5 + 4)
# Out:
# 9

# %%
print(5-4)
# Out:
# 1

# %%
print(5*2)
# Out:
# 10

# %%
print("hello " world " ")
# Out:
#   Cell In[8], line 1
#     print("hello " world " ")
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print("Hello \"World\" ")
# Out:
# Hello "World"

# %%
print("Hello \"world\" ")
# Out:
# Hello "world"

# %% [markdown]
# #  heading 1

# %% [markdown]
# ## heading 2

# %% [markdown]
# ### heading 3

# %%
# output function

print('hello')
# Out:
# hello

# %%
### Print following lines
# this is \\ double backslash
# this /\/\/\/\ mountain
# he is    awesome (use escape sequence insted of manual space)
# \" \n \t \"
# print this  as an output

# %%
print("this is \\\\ double backslash")
# Out:
# this is \\ double backslash

# %%
print("this /\\/\\/\\/\\ mountain")
# Out:
# this /\/\/\/\ mountain

# %%
print("he is\t awesome")
# Out:
# he is	 awesome

# %%
print("\"
# Out:
# \"
#  	 \"

# %%
print("print"
# Out:
# print

# %%
print("\\n \\t")
# Out:
# \n \t

# %%
print("print this  as an output ")
# Out:
# print this  as an output

# %%
print('\\" \\n \\t \\" ')
# Out:
# \" \n \t \"

# %%
print('\\" \\n \\t \\"')
# Out:
# \" \n \t \"

# %%
a = 10
b = 20

if a == b:
    print('hello')
else:
    pass

# %%
for i in range(1,2):
    print(i)
    
    pass
# Out:
# 1

# %%
sequence = {"Python", "Pass", "Statement", "Placeholder"}  
for value in sequence:  
    if value == "Pass":  
        pass
        print("not found pass key")
    else:  
        print("Not reached pass keyword: ", value)
# Out:
# Not reached pass keyword:  Python
# hello
# Not reached pass keyword:  Placeholder
# Not reached pass keyword:  Statement

# %%
sequence = {"Python", "Pass", "Statement", "Placeholder"}  
for value in sequence:  
    if value == "Pass":  
        continue
        print("Hello")
    else:  
        print("Not reached pass keyword: ", value)
# Out:
# Not reached pass keyword:  Python
# Not reached pass keyword:  Placeholder
# Not reached pass keyword:  Statement

# %%
a = [ 1, 2, "Ram", 3.50, "Rahul", 5, 6 ]    
b = [ 1, 2, "Ram", 3.50, "Rahul", 5, 6 ]    
a == b
# Out:
# True

# %%
a[::-1]
# Out:
# [6, 5, 'Rahul', 3.5, 'Ram', 2, 1]

# %%
print('hello',end=' ')
print('world')
# Out:
# hello world

# %%
list = [0,1,2,3,4]       
print("printing original list: ");      
for i in list:      
    print(i,end=" ")      
list.remove(4)      
print("\nprinting the list after the removal of first element...")      
for i in list:      
    print(i,end=" ")
# Out:
# printing original list:
# 0 1 2 3 4
# printing the list after the removal of first element...
# 0 1 2 3

# %%
list_1 = [65,34,26,76,534,23,52,5]
ver = list_1[0]
for i in list_1:
    if(ver > i):
        ver = i
    else:
        pass
#         print("efhiwe")

print(ver)
# Out:
# 5

# %%
list_1 = [65,34,26,76,534,23,52,5]
temp = None
for i in list_1:
    for j in range(1,8):
        if(i > list_1[j]):
            temp = list_1[i]
            list_1[i] = list_1[j]
            list_1[j] = temp
        
        
print(list_1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 6
#       4 for j in range(1,8):
#       5     if(i > list_1[j]):
# ----> 6         temp = list_1[i]
#       7         list_1[i] = list_1[j]
#       8         list_1[j] = temp
#
# IndexError: list index out of range

# %%
list_1 = [65,34,26,76,534,23,52,5]

temp = None
for i in range(0,len(list_1)):
    for j in range(i+0,len(list_1)):
        
        if list_1[i] > list_1[j]:
            
            temp = list_1[i]
            
            list_1[i] = list_1[j]
            
            list_1[j] = temp
            
print(list_1)
# Out:
# [5, 23, 26, 34, 52, 65, 76, 534]
