# %% [markdown]
# ### 1. **Sort a List of Dictionaries by Multiple Keys**
#    - **What to Do:** Given a list of dictionaries, sort them first by one key and then by another key if the first keys are the same.
#    - **Input Example:** ` [{'name': 'Alice', 'age': 25}, {'name': 'Bob', 'age': 20}, {'name': 'Alice', 'age': 30}]`, sort by `name` and then by `age`.
#    - **Output Example:** ` [{'name': 'Alice', 'age': 25}, {'name': 'Alice', 'age': 30}, {'name': 'Bob', 'age': 20}]`

# %%
data = [
    {'name': 'Alice', 'age': 25},
    {'name': 'Bob', 'age': 20},
    {'name': 'Alice', 'age': 30}
]

# %% [markdown]
# ### 2. **Filter a List of Dictionaries Based on a Key Value**
#    - **What to Do:** Given a list of dictionaries, filter out those that do not meet a certain condition for a key.
#    - **Input Example:** ` [{'name': 'Alice', 'age': 25}, {'name': 'Bob', 'age': 20}, {'name': 'Charlie', 'age': 30}]`, keep only those with `age > 25`.
#    - **Output Example:** ` [{'name': 'Charlie', 'age': 30}]`

# %%
Input = [{'name': 'Alice', 'age': 25}, {'name': 'Bob', 'age': 20}, {'name': 'Charlie', 'age': 30}]

# %% [markdown]
# ### 3. **Extract Unique Values from a List of Dictionaries**
#    - **What to Do:** Given a list of dictionaries, extract all unique values for a specific key.
#    - **Input Example:** ` [{'name': 'Alice', 'age': 25}, {'name': 'Bob', 'age': 20}, {'name': 'Charlie', 'age': 25}]`, extract unique ages.
#    - **Output Example:** `[25, 20]`

# %%
dic_3 = [{'name': 'Alice', 'age': 25}, {'name': 'Bob', 'age': 20}, {'name': 'Charlie', 'age': 25}]

# %% [markdown]
# ### 4. **Group Dictionaries by a Key Value**
#    - **What to Do:** Given a list of dictionaries, group them by a specific key.
#    - **Input Example:** ` [{'name': 'Alice', 'age': 25}, {'name': 'Bob', 'age': 20}, {'name': 'Alice', 'age': 30}]`, group by `name`.
#    - **Output Example:** ` {'Alice': [{'name': 'Alice', 'age': 25}, {'name': 'Alice', 'age': 30}], 'Bob': [{'name': 'Bob', 'age': 20}]}`

# %% [markdown]
# ### 5. **Update a List of Dictionaries**
#    - **What to Do:** Given a list of dictionaries, update the value of a specific key for all dictionaries that meet a condition.
#    - **Input Example:** ` [{'name': 'Alice', 'age': 25}, {'name': 'Bob', 'age': 20}], update `age` to `age + 1` for those with `name` == 'Alice'.
#    - **Output Example:** ` [{'name': 'Alice', 'age': 26}, {'name': 'Bob', 'age': 20}]`

# %% [markdown]
# ### 6. **Calculate the Average of a Key's Values**
#    - **What to Do:** Given a list of dictionaries, calculate the average of the values for a specific key.
#    - **Input Example:** ` [{'name': 'Alice', 'age': 25}, {'name': 'Bob', 'age': 20}, {'name': 'Charlie', 'age': 30}]`, calculate the average age.
#    - **Output Example:** `25`

# %% [markdown]
# ### 7. **Sort a List of Dictionaries by Nested Key**
#    - **What to Do:** Given a list of dictionaries, sort them by a nested key.
#    - **Input Example:** ` [{'person': {'name': 'Alice', 'age': 25}}, {'person': {'name': 'Bob', 'age': 20}}, {'person': {'name': 'Charlie', 'age': 30}}]`, sort by `person.age`.
#    - **Output Example:** ` [{'person': {'name': 'Bob', 'age': 20}}, {'person': {'name': 'Alice', 'age': 25}}, {'person': {'name': 'Charlie', 'age': 30}}]`

# %% [markdown]
# ### 8. **Merge Two Lists of Dictionaries by Key**
#    - **What to Do:** Given two lists of dictionaries, merge them based on a common key.
#    - **Input Example:** ` [{'name': 'Alice', 'age': 25}], [{'name': 'Alice', 'city': 'New York'}]`, merge by `name`.
#    - **Output Example:** ` [{'name': 'Alice', 'age': 25, 'city': 'New York'}]`

# %% [markdown]
# ### 9. **Create a Summary Dictionary from a List of Dictionaries**
#    - **What to Do:** Given a list of dictionaries, create a summary dictionary that combines values based on a key.
#    - **Input Example:** ` [{'name': 'Alice', 'age': 25}, {'name': 'Bob', 'age': 20}, {'name': 'Alice', 'age': 30}]`, summarize by `name`.
#    - **Output Example:** ` {'Alice': 55, 'Bob': 20}` (summing ages)

# %% [markdown]
# ### 10. **Flatten a List of Dictionaries**
#    - **What to Do:** Given a list of dictionaries with nested structures, flatten them into a single dictionary.
#    - **Input Example:** ` [{'name': 'Alice', 'details': {'age': 25, 'city': 'New York'}}, {'name': 'Bob', 'details': {'age': 20, 'city': 'Los Angeles'}}]`.
#    - **Output Example:** ` [{'name': 'Alice', 'age': 25, 'city': 'New York'}, {'name': 'Bob', 'age': 20, 'city': 'Los Angeles'}]`
