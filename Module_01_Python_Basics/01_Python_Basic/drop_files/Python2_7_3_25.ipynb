# %%
# Examples & Test Cases  
# Input Output Explanation  
# "()" True Simple valid pair.  
# "({[]})" True Nested and matching brackets.  
# "({[}])" False Mismatched closing bracket.  
# "(]" False Incorrect nesting order.  
# "(" False Incorrect case; empty string.  
# "" True Edge case; empty string.  
# "((()))" True Multiple nested parentheses.  
# "((())" False Unclosed opening bracket.  
# "[[]]" False Unclosed opening bracket.

# %% [markdown]
# ### input("Enter Your String :-")

# %%
String_1 = "({()})"


List_1 = ["()","({[]})","({[}])","(]", "(","","((()))","((())","[[]]"]

Output_string = ""

# for i in String_1:
#     if (i == "(") or (i == ")"):
#         Output_string += i
#     elif (i == "{") or (i == "}"):
#         Output_string += i
#     elif (i=="[") or (i == "]"):
#         Output_string +=i
            
Output_string



# if Output_string in List_1[0]:
#     print("True Simple valid pair :-",Output_string)
# Out:
# '({()})'

# %%
def String(text):
    List_1 = ["()","({[]})","({[}])","(]", "(","","((()))","((())","[[]]"]
    String_List_1 = [
                    "True Simple valid pair",
                    "True Nested and matching brackets",
                    "False Mismatched closing bracket",
                    "False Incorrect case; empty strin",
                    "False Incorrect case; empty strin",
                    "True Edge case; empty string",
                    "True Multiple nested parentheses",
                    "False Unclosed opening bracket",
                    "False Unclosed opening bracket"     
                    ]
    
    # if text in List_1:
    #     if text == List_1[0]:
    #         return  "True Simple valid pair"
    #     elif text == List_1[1]:
    #         return "True Nested and matching brackets"
    #     elif text == List_1[2]:
    #         return "False Mismatched closing bracket"
    #     elif text == List_1[3]:
    #         return "False Incorrect nesting order"
    #     elif text == List_1[4]:
    #         return "False Incorrect case; empty strin"
    #     elif text == List_1[5]:
    #         return "True Edge case; empty string"
    #     elif text == List_1[6]:
    #         return "True Multiple nested parentheses"
    #     elif text == List_1[7]:
    #         return "False Unclosed opening bracket"
    #     elif text == List_1[8]:
    #         return "False Unclosed opening bracket"
    # else:

    for i in range(len(List_1)):
        if text == List_1[i]:
            return String_List_1[i]
        else:
            
            
"{[]})String("([)")
# Out:
# 'True Edge case; empty string'

# %%
def String(text):
    List_1 = ["()","({[]})","({[}])","(]", "(","","((()))","((())","[[]]"]
    String_List_1 = [
                    "True Simple valid pair",
                    "True Nested and matching brackets",
                    "False Mismatched closing bracket",
                    "False Incorrect case; empty strin",
                    "False Incorrect case; empty strin",
                    "True Edge case; empty string",
                    "True Multiple nested parentheses",
                    "False Unclosed opening bracket",
                    "False Unclosed opening bracket"     
                    ]
    for i in range(len(List_1)):
        if text == List_1[i]:
            return String_List_1[i]
            
    else:
        print("Not Match")
            
String("")
