# %% [markdown]
# ### 1. **Categorize Numbers as Even or Odd**
# Write a program that takes a list of integers and categorizes them into two sets: one for even numbers and one for odd numbers.
#
# **Input**:
# ```python
# [5, 2, 9, 1, 7, 8, 6]
# ```
# **Output**:
# ```python
# Even: {2, 8, 6}
# Odd: {1, 5, 9, 7}
# ```
#
# ---

# %% [markdown]
# ### 2. **Sum of Numbers at Even Indices**
# Write a program that sums the numbers present at even indices of a list.
#
# **Input**:
# ```python
# [5, 1, 3, 7, 8, 2, 9]
# ```
# **Output**:
# ```python
# Sum = 25
# ```
#
# ---

# %% [markdown]
# ### 3. **Filter Words by Length**
# Write a program that filters words from a list based on a given length. Only include words longer than 4 characters.
#
# **Input**:
# ```python
# ["apple", "is", "a", "fruit"]
# ```
# **Output**:
# ```python
# ['apple', 'fruit']
# ```
#
# ---

# %% [markdown]
# ### 4. **Check If Tuples Are All Positive**
# Write a program that checks if all the integers in a list of tuples are positive.
#
# **Input**:
# ```python
# [(1, 2), (3, 0), (-1, 4)]
# ```
# **Output**:
# ```python
# False
# ```
#
# ---

# %% [markdown]
# ### 5. **Remove Duplicates from Tuple**
# Write a program that removes duplicates from a tuple and converts it back to a tuple.
#
# **Input**:
# ```python
# (1, 2, 3, 1, 2, 4)
# ```
# **Output**:
# ```python
# (1, 2, 3, 4)
# ```
#
# ---

# %% [markdown]
# ### 6. **Create a Set of Tuple Differences**
# Write a program to create a set where each element is the difference between elements of the tuples in a list.
#
# **Input**:
# ```python
# [(5, 2), (8, 3), (10, 6)]
# ```
# **Output**:
# ```python
# {3, 5, 4}
# ```
#
# ---

# %% [markdown]
# ### 7. **Find Common Characters in Strings**
# Write a program that finds common characters among a list of strings.
#
# **Input**:
# ```python
# ["apple", "apricot", "grape"]
# ```
# **Output**:
# ```python
# {'a', 'p'}
# ```
#
# ---

# %% [markdown]
# ### 8. **Divide List into Two Halves**
# Write a program that divides a list of integers into two halves. If the list has an odd number of elements, the first half should contain the extra element.
#
# **Input**:
# ```python
# [1, 2, 3, 4, 5]
# ```
# **Output**:
# ```python
# First half: [1, 2, 3]
# Second half: [4, 5]
# ```
#
# ---

# %% [markdown]
# ### 9. **Convert List of Tuples to Dictionary**
# Write a program that converts a list of tuples into a dictionary, using the first element as the key and the second element as the value.
#
# **Input**:
# ```python
# [('apple', 3), ('banana', 2), ('grape', 5)]
# ```
# **Output**:
# ```python
# {'apple': 3, 'banana': 2, 'grape': 5}
# ```
#
# ---

# %% [markdown]
# ### 10. **Find the Longest Word in List**
# Write a program that finds the longest word in a list of strings.
#
# **Input**:
# ```python
# ["apple", "banana", "grape"]
# ```
# **Output**:
# ```python
# 'banana'
# ```
#
# ---

# %% [markdown]
# ### 11. **Check if All Elements Are Unique**
# Write a program that checks if all the elements in a list of tuples are unique.
#
# **Input**:
# ```python
# [(1, 2), (2, 3), (1, 2)]
# ```
# **Output**:
# ```python
# False
# ```
#
# ---

# %% [markdown]
# ### 12. **Sum of First N Natural Numbers**
# Write a program that computes the sum of the first `n` natural numbers using an if-else loop.
#
# **Input**:
# ```python
# n = 5
# ```
# **Output**:
# ```python
# Sum = 15
# ```
#
# ---

# %% [markdown]
# ### 13. **Find Maximum and Minimum in Tuple List**
# Write a program that finds the maximum and minimum values from a list of tuples, where each tuple contains two elements.
#
# **Input**:
# ```python
# [(3, 5), (2, 8), (7, 1)]
# ```
# **Output**:
# ```python
# Max = 8, Min = 1
# ```
#
# ---

# %% [markdown]
# ### 14. **Remove All Empty Strings**
# Write a program to remove all empty strings from a list of strings.
#
# **Input**:
# ```python
# ['apple', '', 'banana', 'grape', '']
# ```
# **Output**:
# ```python
# ['apple', 'banana', 'grape']
# ```
#
# ---

# %% [markdown]
# ### 15. **Create List of Tuple Sums**
# Write a program that converts a list of tuples into a list where each element is the sum of the tuple elements.
#
# **Input**:
# ```python
# [(1, 2), (3, 4), (5, 6)]
# ```
# **Output**:
# ```python
# [3, 7, 11]
# ```
#
# ---

# %% [markdown]
# ### 16. **Check Sublist Within List**
# Write a program that checks if a sublist exists within a list.
#
# **Input**:
# ```python
# list1 = [1, 2, 3, 4, 5]
# sublist = [2, 3]
# ```
# **Output**:
# ```python
# True
# ```
#
# ---

# %% [markdown]
# ### 17. **Find Words with Specific Letter**
# Write a program that finds all words from a list that contain a specific letter.
#
# **Input**:
# ```python
# words = ['apple', 'banana', 'grape']
# letter = 'a'
# ```
# **Output**:
# ```python
# ['apple', 'banana', 'grape']
# ```
#
# ---

# %% [markdown]
# ### 18. **Sum of Squares of Even Numbers**
# Write a program that calculates the sum of squares of even numbers from a list.
#
# **Input**:
# ```python
# [1, 2, 3, 4, 5]
# ```
# **Output**:
# ```python
# Sum = 20
# ```
#
# ---

# %% [markdown]
# ### 19. **Check for Substring in List**
# Write a program that checks if a specific substring exists in any of the strings in a list.
#
# **Input**:
# ```python
# list = ['apple', 'banana', 'grape']
# substring = 'ap'
# ```
# **Output**:
# ```python
# True
# ```
#
# ---

# %% [markdown]
# ### 20. **Find Elements Greater than Average**
# Write a program that finds all elements in a list that are greater than the average of the list.
#
# **Input**:
# ```python
# [1, 2, 3, 4, 5, 6]
# ```
# **Output**:
# ```python
# [4, 5, 6]
# ```
#
# ---
