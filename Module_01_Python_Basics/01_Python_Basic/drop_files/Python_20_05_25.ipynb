# %%
print("Hello")
# Out:
# Hello

# %%
print('Hello ,"World"')
# Out:
# Hello ,"World"

# %%
print("Hello ,"World"")
# Out:
#   Cell In[3], line 1
#     print("Hello ,"World"")
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# ### Escape Sequence

# %%
print("Hello \"World\"")
# Out:
# Hello "World"

# %%
print(" \" ")
# Out:
#  "

# %%
print(" \ ")
# Out:
#  \
# <>:1: SyntaxWarning: invalid escape sequence '\ '
# <>:1: SyntaxWarning: invalid escape sequence '\ '
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_17340\259158425.py:1: SyntaxWarning: invalid escape sequence '\ '
#   print(" \ ")

# %%
print(" \\\\\\\\ ")
# Out:
#  \\\\

# %%
print("Hello\b ")
# Out:
# Hell

# %%
print("Hello\tA")
# Out:
# Hello	A

# %%
print("Line1")
print("Line2")
# Out:
# Line1
# Line2

# %%
print("Line1\nLine2")
# Out:
# Line1
# Line2

# %%
print("this is \\ double backslash")
# Out:
# this is \ double backslash

# %%
print(r"\" \n \t \"")
# Out:
# \" \n \t \"

# %%
print("\U0001F600")
# Out:
# 😀

# %%
# number
print(type(2))
print(type(2.5))
# Out:
# <class 'int'>
# <class 'float'>

# %%
bool(55)
# Out:
# True
