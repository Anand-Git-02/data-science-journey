# %%
L = [1,2,3]
L.upper()

# %%
string = "Hello"
string.append()

# %% [markdown]
# In Pythom string , list are called object.

# %% [markdown]
# ### Procedural Approach in Programming
# The procedural approach in programming is a paradigm centered around procedures or routines (functions) to perform tasks. It is one of the oldest programming paradigms and is still widely used in many contexts today. This approach is well-suited for solving problems that can be broken down into a sequence of steps or instructions.

# %%
# Calculator functions
def add(a, b):
    return a + b

def subtract(a, b):
    return a - b

def multiply(a, b):
    return a * b

def divide(a, b):
    return a / b if b != 0 else "Error: Division by zero"

# Main function
def main():
    operations = {
        1: ("Addition", add),
        2: ("Subtraction", subtract),
        3: ("Multiplication", multiply),
        4: ("Division", divide)
    }

    print("Simple Calculator")
    for key, (name, _) in operations.items():
        print(f"{key}. {name}")

    try:
        choice = int(input("Enter your choice (1-4): "))
        if choice not in operations:
            print("Invalid choice! Please select a number between 1 and 4.")
            return

        num1 = float(input("Enter the first number: "))
        num2 = float(input("Enter the second number: "))

        operation_name, operation_func = operations[choice]
        result = operation_func(num1, num2)

        print(f"The result of {operation_name.lower()} is: {result}")
    except ValueError:
        print("Invalid input! Please enter numeric values.")

# Execute the program
if __name__ == "__main__":
    main()
# Out:
# Simple Calculator
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# Enter your choice (1-4):  1
# Enter the first number:  25
# Enter the second number:  65
# The result of addition is: 90.0

# %% [markdown]
# #### Generality to Specificity
# - Kali Linux

# %% [markdown]
# ### OOP
# - OOP allows the programmer to create their own datatypes.

# %% [markdown]
# ### What is An Object And What is OOP ?
#
# An **object** is a specific instance of a class in object-oriented programming (OOP). It combines data (called attributes) and actions (called methods) that represent a real-world thing.
#
# **Object-Oriented Programming (OOP)** is a way of writing software that focuses on using objects to design and organize code. It has four main ideas:
#
# 1. **Encapsulation**: Keeps data safe by grouping it with the functions that work on it, so other parts of the program can't change it directly.
# 2. **Inheritance**: Allows one class (child) to use features from another class (parent), making it easier to share code.
# 3. **Polymorphism**: Lets different classes use the same function name in different ways, providing flexibility.
# 4. **Abstraction**: Hides complex details and shows only what is necessary to use an object.
#
# ![Picture1.jpg](attachment:c53866a9-f581-44c1-bcb8-05079e5b5193.jpg)

# %% [markdown]
# ### 1. Class
# **A class is a blueprint or template** in object-oriented programming (OOP) that is used to create objects. It defines the attributes (data) and methods (functions) that the objects will possess, `establishing their structure and behavior`. By using a class, you can create multiple instances (objects) with the same characteristics and functionalities, making it easier to model real-world entities and organize code. Classes promote reusability, encapsulation, and modularity, allowing developers to write clearer and more efficient programs.
#
# ![Screenshot 2025-01-02 154318.png](attachment:fa568f35-3573-4573-b103-f3c8e5d601cb.png)

# %% [markdown]
# Example:
#
# For instance, a Car class may have attributes like color, make, and model, and methods like start() and stop(). Here’s a simple implementation in Python:

# %%
L = [1,2,3,4.5]
print(type(L))
# Out:
# <class 'list'>

# %%
L.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 L.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %% [markdown]
# List is Class
#
# L variable is a object

# %% [markdown]
# **`How to Create Class`**

# %%
"""
Create a Class
To create a class, use the keyword class:
"""
class MyClass:
  name = "Jadu"

# %% [markdown]
# **`How to Create Object`**

# %%
"""
Create Object
#Now we can use the class named MyClass to create objects:
"""
p1 = MyClass()
print(p1.name)
# Out:
# Jadu

# %% [markdown]
# ### Constructor $ self
#
# - `__ init __ ( )`
# - Whenever we Create / Construct an object of a class, there is an inbuilt method (__ init __) which is called Known as Constructor.
# - `Special method Called itself`

# %% [markdown]
# #### What is True benefit Constructor
# 1. **Automatic Initialization**:
#    - When `person1 = Person("Alice", 25)` is executed, the `__init__()` method initializes the `name` and `age` attributes for `person1`.
#
# 2. **Simplified Object Creation**:
#    - The attributes are set during object creation, so you don’t need a separate method to set them manually.
#
# 3. **Consistency**:
#    - Every `Person` object is guaranteed to have its attributes (`name` and `age`) initialized properly.

# %%
class Student:

    def __init__():
        print("Mai Run Ho gaya!")

# %%
student1 = Student()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 student1 = Student()
#
# TypeError: Student.__init__() takes 0 positional arguments but 1 was given

# %%
def hello():
    print("Hello Python")
hello("Anand")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 def hello():
#       2     print("Hello Python")
# ----> 3 hello("Anand")
#
# TypeError: hello() takes 0 positional arguments but 1 was given

# %%
def hello(arg1):
    print(arg1)
    print("Hello Python")

N = "Anand"
hello(N)
# Out:
# Anand
# Hello Python

# %%
class Student:
    
    # constructor(special function) --> superpower --> this function don't need call explicitly 
    def __init__(self):
        print("Mai tho Run hogaya !!")

# %%
s1 = Student()
# Out:
# Mai tho Run hogaya !!

# %% [markdown]
# ### Parameterized constructor

# %% [markdown]
# ### Class Attributes and object Attributes

# %%
class Student:
    college_name = "ABC University"  # this class attribut

    def __init__(self,Id,Name,Course):
        self.Id = Id
        self.Name = Name
        self.Course = Course

s1 = Student(1,"Jadu","Data Science")
s2 = Student(2,"Ramu","Python ML")
s3 = Student(3,"Magun","Data analytics")

print(Student.college_name)

print(f"""
        Student Id :- {s1.Id}
        Name       :- {s1.Name}
        Course     :- {s1.Course}
        """
     )
# Out:
# ABC University
#
#         Student Id :- 1
#         Name       :- Jadu
#         Course     :- Data Science

# %%
print(Student.college_name)
print()
print(f"""Student Id :- {s2.Id} \nName       :- {s2.Name}\nCourse     :- {s2.Course}""")
print(f"""\nStudent Id :- {s3.Id} \nName       :- {s3.Name}\nCourse     :- {s3.Course}""")
# Out:
# ABC University
#
# Student Id :- 2
# Name       :- Ramu
# Course     :- Python ML
#
# Student Id :- 3
# Name       :- Magun
# Course     :- Data analytics

# %% [markdown]
# #### Methods
# #### Car
# - Data / Attributes / Property
#
#     - Name
#     - Color
#     - Brand
#     - Top Speed
#
# - Behaviour / Methods
#     - Accelerate()
#     - Brake()
#     - Start()

# %%
class Car:
    def __init__(self,name,brand,color,topSpeed):
        self.name = name
        self.color = color
        self.brand = brand
        self.topSpeed = topSpeed

    
    def Start(self):
        return f"{self.name} is Started"

    def Accelerate(self):
        return f"Your speed is {self.topSpeed//3} kms"

    def Breke(self):
        return f"{self.name} is stopped"

# %%
car1 = Car("Model S", "Tesla", "Red", 250)
car2 = Car("Civic", "Honda", "Blue", 220)
car3 = Car("Mustang", "Ford", "Black", 240)
car4 = Car("911 Carrera", "Porsche", "White", 290)
car5 = Car("Camry", "Toyota", "Silver", 210)

# %%
# Displaying car details
cars = [car1, car2, car3, car4, car5]
for i in range(0,len(cars)):
    print(f"Car {i+1} Name :- {cars[i].name,cars[i].brand}")
# Out:
# Car 1 Name :- ('Model S', 'Tesla')
# Car 2 Name :- ('Civic', 'Honda')
# Car 3 Name :- ('Mustang', 'Ford')
# Car 4 Name :- ('911 Carrera', 'Porsche')
# Car 5 Name :- ('Camry', 'Toyota')

# %%
car1.Start()
# Out:
# 'Model S is Started'

# %% [markdown]
# ### Passing List in object

# %%
class Student:

    def __init__(self,name,marks):
        self.name = name
        self.marks = marks

    def avg_marks(self):
        Sum = 0
        for i in self.marks:
            Sum += i
        return f"Hi {self.name} your avg score is :- {Sum/3}"

s1 = Student("Jadu",[95,65,91])
s1.avg_marks()

# Changing Values in Attributes
# s1.name = "Anand"
# s1.avg_marks()
# Out:
# 'Hi Jadu your avg score is :- 83.66666666666667'

# %% [markdown]
# ### Advantages / Application of Constructor
# - Background check in companies
# - Internet check for apps
# - Configuration reloted checks before starting
#
# Its like a receptionist which add / gives all information required
#
# ### Self
# - Self is the reference to the object created of our class
# - It is passed whenever we are calling any method
# - Only an object can access or helpful in connecting attributes and inside our class.

# %% [markdown]
# ### Static Methods
# - Methods that don't use the self parameter (work at class level)
# - Decorators allow us to wrap another function in order to extend behaviour of the wrapped function, without permanently modifying it

# %%
class Student:
    @staticmethod # decorator
    def college():
        print("XYZ College")

cs1 = Student()
cs1.college()

# %% [markdown]
# ### Abstraction
# - Hiding the implementation details of a class and only showing the essential feature to the user

# %%
class Car:
    def __init__(self):
        self.start = False
        self.accelerate = False
        
    def started(self):
        self.start = True
        self.accelerate = True
        print("Car is Running")

car1 = Car()
car1.started()
# Out:
# Car is Running

# %% [markdown]
# # Encapsulation
# - Wrapping data and function into a single unit (object)
# - In Simple Words if we create capsule of (data + function) is called Encapsulation

# %% [markdown]
# ### Exericse :
# - Create Account class with 2 attributes - balance & account no.
# - Create methods for debit,credit & printing the balance.

# %%
class Car:
    def __init__(self,Name,Color):
        self.Name = Name
        self.Color = Color

    def Start(self):
        return f"{self.Name} is Running"

Car1 = Car("Toyota",'Red')

print(Car1.Name)
print(Car1.Color)
Car1.Start()

# %%
class Account:
    def __init__(self,balance,acc_no):
        self.balance = balance
        self.acc_no = acc_no

    # Debit Method
    def debit(self,amount):
        if amount < self.balance:
            self.balance -= amount
            return f"Debit with amount {amount} \nAccount Balance is :- {self.get_balance()}"
        else:
            return f"Insufficient balance"
            
    # Credit Method    
    def credit(self,amount):
        self.balance += amount
        return f"Credit with amount {amount} \nAccount Balance is :- {self.get_balance()}"
    
    # Check balance Method
    def get_balance(self):
        return self.balance

acc1 = Account(10000,1234)
print(f"Your Account Balance is :- {acc1.balance}")
print(f"Account Number :- {acc1.acc_no}")
print()

print(acc1.credit(200))
print()
print(acc1.debit(200))

# %% [markdown]
# ### Methods vs Functions
#
# 1. Function Under Class its called Method.
# 2. Outside of Class is Called Function.
#
# ![Screenshot 2025-01-17 152307.png](attachment:ccb29f60-d904-4a52-998d-b528aaa0b435.png)

# %%
class Atm:
    
    # constructor(special function) --> superpower --> this function don't need call explicitly 
    def __init__(self):
        self.pin = ''
        self.balance = 0
        self.menu()

    def menu(self):
        User_input = input("""
        Hi How can I help you?
        1. Press 1 to Create Pin
        2. Press 2 to Change Pin
        3. Press 3 to Check Balance
        4. Press 4 to Withdraw
        5. Anything else to exit
        """)

        if User_input == '1':
            # Creating Pin
            self.creat_Pin()
        elif User_input == '2':
            # Change Pin
            self.change_pin()
        elif User_input == '3':
            # Check Balance
            self.check_balance()
        elif User_input == '4':
            # Withdraw Money
            self.withdraw()
        else:
            exit()

    def creat_Pin(self):
        # Pin Variable
        User_pin = input('Enter Your Pin')
        self.pin = User_pin

        # Balance Vaialbe
        User_Balance = int(input("Enter Balance :-"))
        self.balance = User_Balance

        print("Pin Created Successfilly")
        self.menu()

    def change_pin(self):
        old_pin = input("Enter Your Old Pin :-")

        if old_pin == self.pin:
            new_pin = input('Enter Your New Pin :-')
            self.pin = new_pin
            print('Pin Change Successfilly')
            self.menu()

        else:
            print('Nahi Hoga ree !!')
            self.menu()

    def check_balance(self):
        User_pin = input("Enter Your Pin")

        if User_pin == self.pin:
            print("Your Balance is",self.balance)

        else:
            print("Chal nikal yahan se !!")
        self.menu()

    def withdraw(self):
        User_pin = input("Enter Your Pin")

        if User_pin == self.pin:
            amount = int(input("Enter Your Amount :-"))

            if amount < self.balance:
                self.balance = self.balance - amount
                print(f"Withdrawl Successful... Your Balance is {self.balance}")
                
            else:
                print("Ek kaam Kar Bank loot le ......")
        else:
            print("Chor ho kaya !!")
        self.menu()

Atm1 = Atm()
Atm1

# %% [markdown]
# ### del keyword
# - Used to delete object properties or object itself

# %%
class Student:
    def __init__(self,name):
        self.name = name

s1 = Student("Jadu")
s2 = Student("Anand")

print(s1.name)
del s1.name
print(s1.name)

# del s2
# print(s2)
# Out:
# Jadu
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 10
#       8 print(s1.name)
#       9 del s1.name
# ---> 10 print(s1.name)
#
# AttributeError: 'Student' object has no attribute 'name'

# %% [markdown]
# ### Private(like) attributes & Methods
# **`Conceptual Implementation in Python`**
# - Private attributes & methods are meant to be used only within the class and are not accessible from outside the class.

# %%
class Account:
    def __init__(self,account_number,account_password):
        self.account_number = account_number
        self.account_password = account_password

acc1 = Account(98765,123)
print(acc1.account_number)
print(acc1.account_password)
# Out:
# 98765
# 123

# %% [markdown]
# #### Now we private the password

# %%
class Account:
    def __init__(self,account_number,account_password):
        self.account_number = account_number
        self.__account_password = account_password

acc1 = Account(98765,123)
print(acc1.account_number)
print(acc1.account_password)
# Out:
# 98765
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 8
#       6 acc1 = Account(98765,123)
#       7 print(acc1.account_number)
# ----> 8 print(acc1.account_password)
#
# AttributeError: 'Account' object has no attribute 'account_password'

# %%
class Account:
    def __init__(self,account_number,account_password):
        self.account_number = account_number
        self.__account_password = account_password

    def reset_pass(self):
        return self.__account_password

acc1 = Account(98765,123)

print(acc1.account_number)
print(acc1.reset_pass())
# Out:
# 98765
# 123

# %%
class Person:
    def __init__(self, name="unknown"):
        self.__name = name

    def __hello(self):
        return "Hello, how are you?"

    def welcome(self):
        return self.__hello()

p1 = Person("Anand")
# print(p1.name)

p2 = Person()
# print(p2.name)


print(p1.welcome())
# Out:
# Hello, how are you?

# %%
### Encapsulation  with Getter and Setter MEthods
### Public,protected,private variables or access modifiers

class Person:
    def __init__(self,name,age):
        self.name=name    ## public variables
        self.age=age      ## public variables

    def hello(self):
        pass

def get_name(person):
    return person.name

person1=Person("Tony",34)
person2 = Person("Jadu",40)

get_name(person2)
# Out:
# 'Jadu'

# %%
dir(Person)

# %%
## Encapsulation With Getter And Setter
class Person:
    def __init__(self,name,age):
        self.__name=name  ## Private access modifier or variable
        self.__age=age ## Private variable

    ## getter method for name
    def get_name(self):
        return self.__name
    
    ## setter method for name
    def set_name(self,name):
        self.__name=name

    # Getter method for age
    def get_age(self):
        return self.__age
    
    # Setter method for age
    def set_age(self, age):
        if age > 0:
            self.__age = age
        else:
            print("Age cannot be negative.")


person=Person("Tony",34)

## Access and modify private variables using getter and setter

print(person.get_name())
print(person.get_age())

person.set_age(35)
print(person.get_age())

person.set_age(-5)

# %% [markdown]
# # Inheritance
# - When one class(child/derived) derives the properties & methods of another class(parent/base)

# %%
class Car:
    @staticmethod
    def start():
        return "Car started.."

    @staticmethod
    def stop():
        return "Car stopped."

class ToyotaCar(Car):
    def __init__(self, name):
        self.name = name

    def __str__(self):
        return f"Toyota Car: {self.name}"

# Example usage
car1 = ToyotaCar("Fortuner")
car2 = ToyotaCar("Prius")

print(car1.start())  
print(car2.stop())   
print(car1)
# Out:
# Car started..
# Car stopped.
# Toyota Car: Fortuner

# %% [markdown]
# ### Inheritance Types
# - Single Inheritance
# - Multi-level Inheritance
# - Multiple Inheritance
# - Hierarchical Inheritance
# - Hybrid Inheritance

# %%
## Inheritance (Single Inheritance)
## Parent class
class Car:
    def __init__(self,windows,doors,enginetype):
        self.windows=windows
        self.doors=doors
        self.enginetype=enginetype
    
    def drive(self):
        print(f"The person will drive the {self.enginetype} car ")

car1=Car(4,5,"petrol")
car1.drive()

# %% [markdown]
# ### Single Inheritance
# * In single inheritance, a child class inherits from a single-parent class. Here is one child class and one parent class.

# %%
class vehicle:             # base class
    def vehicle_info(self):
        print("inside vehicle class")
        
class car(vehicle):        # child class
    def car_info(self):
        print("Inside car class")
        
car = car()          # create object of child class
car.car_info()
car.vehicle_info()

# %% [markdown]
# ### Multiple Inheritance
# * In multiple inheritance, one child class can inherit from multiple parent classes. So here is one child class and multiple parent classes.

# %%
class person:                        # parent-1
    def person_info(self,name,age):
        print("Inside person class")
        print("Name :",name,"Age :",age)
    
class company:                      # parent-2
    def company_info(self,company_name,location):
        print("inside company class")
        print("Company_name :",company_name,"Location :",location)
        
class employee(person,company):     # child
    def employee_info(self,salary,skill):
        print("inside employee class")
        print("Salary :",salary,"Skill :",skill)
        
emp = employee()
emp.person_info("Helly",28)
emp.company_info("Google","Atalanta")
emp.employee_info(12000,"ML")

# %% [markdown]
# ### Multilevel inheritance
# * In multilevel inheritance, a class inherits from a child class or derived class. Suppose three classes A, B, C. A is the superclass, B is the child class of A, C is the child class of B. In other words, we can say a chain of classes is called multilevel inheritance.

# %%
class vehicle:             # super parent class
    def vehicle_info(self):
        print("inside vehicle class")
        
class car(vehicle):        # parent class
    def car_info(self):
        print("Inside car class")
        
class sportscar(car):      # child class
    def sportscar_info(self):
        print("Inside sportscar class")
        
s_car = sportscar()
s_car.vehicle_info()
s_car.car_info()
s_car.sportscar_info()

# %%
### Multiple Inheritance
## When a class inherits from more than one base class.
## Base class 1 --> Parent 
class Animal:
    def __init__(self,name):
        self.name=name

    def speak(self):
        print("Subclass must implement this method")

## BAse class 2 --> Parent
class Pet:
    def __init__(self, owner):
        self.owner = owner


##Derived class --> child
class Dog(Animal,Pet):
    def __init__(self,name,owner):
        Animal.__init__(self,name)
        Pet.__init__(self,owner)

    def speak(self):
        return f"{self.name} say woof"
    

## Create an object
dog=Dog("Blacky","Anand")
print(dog.speak())
print(f"Owner:{dog.owner}")

# %% [markdown]
# ### Hierarchical Inheritance
# * In Hierarchical inheritance, more than one child class is derived from a single parent class. In other words, we can say one parent class and multiple child classes.

# %%
class vehicle:
    def info(self):
        print("This is vehicle")

class car(vehicle):
    def car_info(self,name):
        print("Car name is ",name)

class truck(vehicle):
    def truck_info(self,name):
        print("Truck name is ",name)

obj1 = car()
obj1.info()
obj1.car_info("BMW")

obj2 = truck()
obj2.info()
obj2.truck_info("FORD")

# %% [markdown]
# ### Hybrid Inheritance
# * When inheritance is consists of multiple types or a combination of different inheritance is called hybrid inheritance.

# %%
class vehicle:           
    def vehicle_info(self):
        print("inside vehicle class")
        
class car(vehicle):      
    def car_info(self):
        print("Inside car class")
        
class truck(vehicle):      
    def truck(self):
        print("Inside truck class")
        
class sportscar(car,vehicle):   
    def sportscar_info(self):
        print("Inside sportscar class")
        
s_car = sportscar()
s_car.vehicle_info()
s_car.car_info()
s_car.sportscar_info()

# %% [markdown]
# ### **Super** method
# - super() method is used to access methods of the parent class.

# %%
## Parent class
class Car:
    def __init__(self,windows,doors,enginetype):
        self.windows=windows
        self.doors=doors
        self.enginetype=enginetype
    
    def drive(self):
        print(f"The person will drive the {self.enginetype} car ")

## Child Class
class Tesla(Car):
    def __init__(self,windows,doors,enginetype,is_selfdriving):
        super().__init__(windows,doors,enginetype)
        self.is_selfdriving=is_selfdriving

    def selfdriving(self):
        print(f"Tesla supports self driving : {self.is_selfdriving}")

tesla1=Tesla(4,5,"electric",True)
tesla1.selfdriving()
tesla1.drive()

# %% [markdown]
# ### Class Methos
# - A class methods is bound to the class & receives the class as an implicit first argument.
#
# **Note** :- static method can't access or modify class state & generally for utility.
#
# 1. static Methods
# 2. class Methods
# 3. instance Methods

# %%
class Person:
    name = "unknown"

    def changeName(self,name):
        self.name = name

p1 = Person()

print(p1.name)
p1.changeName("Raju")
print(p1.name)
print(Person.name)
# Out:
# unknown
# Raju
# unknown

# %%
class Person:
    name = "unknown"

    def changeName(self,name):
        Person.name = name

p1 = Person()

print(p1.name)
p1.changeName("Raju")
print(p1.name)
print(Person.name)

# %%
class Person:
    name = "unknown"

    def changeName(self,name):
        self.__class__.name = name

p1 = Person()

print(p1.name)
p1.changeName("Raju")
print(p1.name)
print(Person.name)
# Out:
# unknown
# Raju
# Raju

# %%
class Person:
    name = "unknown"

    @classmethod
    def changeName(cls,name):
        cls.name = name

p1 = Person()

print(p1.name)
p1.changeName("Raju")
print(p1.name)
print(Person.name)
# Out:
# unknown
# Raju
# Raju

# %% [markdown]
# ### Property
# - We use @property decorator on any method in the class to use the method as a property.

# %%
class Student:
    def __init__(self,phy,chem,math):
        self.phy = phy
        self.chem = chem
        self.math = math
        self.percentage = str((self.phy + self.chem + self.math)/3) + "%"

std1 = Student(98,97,99)
print(std1.percentage)

# If we want to change the marks it will change it but percentage not change

std1.math = 90
print(std1.math)
print(std1.percentage)
# Out:
# 98.0%
# 90
# 98.0%

# %%
class Student:
    def __init__(self,phy,chem,math):
        self.phy = phy
        self.chem = chem
        self.math = math

    @property
    def percentage(self):
        return f"{(self.phy + self.chem + self.math) / 3:.2f}%"

# Markrs in Percentages
std1 = Student(98,97,99)

print(std1.chem)
# Finding of Percentage Average
print(std1.percentage)


std1.chem = 85
print(std1.chem)
print(std1.percentage)

# %%
class Student:
    def __init__(self, name, phy, chem, math):
        self.name = name
        self.phy = phy
        self.chem = chem
        self.math = math

    @property
    def percentage(self):
        return f"{(self.phy + self.chem + self.math) / 3:.2f}%"

# Create a student object
std1 = Student("Jadu", 98, 97, 99)

# Print student percentage
print(f"Student: {std1.name}, Percentage: {std1.percentage}")
print()
print(std1.math)

std1.math = 90
print()
print(std1.math)

print()
print(f"Student: {std1.name}, Percentage: {std1.percentage}")

# %% [markdown]
# ### Polymorphism : Operator Overloading
# - When the same operator is allowed to have different meaning according to the context

# %% [markdown]
# ### Magic Methods --> A.K.A Dunder Methods
# 1. The Constructor __ inti __( )
# - Magic Methods are Special Methods every Magic method has superpower
# - They begin and end with double underscore ( __ name __ , __ init __)
# - They have a Special where in they get called themselves.
#     - Creation --> `__ init __`
#     - Print    --> `__ str __`
#     - '+'      --> `__add__`
#     - '-'      --> `__sub__`
#     - '*'      --> `__mul__`
#     - '/'      --> `__truediv__`
#     - '//'     --> `__floordiv__`
#     - '=='	   --> `__eq__`

# %%
print(1 + 2) 
print("Python" + " is" + " Simple")
print([1,2,3] + [4,5,6])

# %% [markdown]
# ### Method Overriding allows subclass methods to modify parent class behavior.

# %%
class Student: #student class
    def __init__(self,name,grade,percentage):
        self.name = name
        self.grade = grade
        self.percentage = percentage

    def student_details(self): #method
        return f"{self.name} is in class {self.grade} with {self.percentage}%"

class GraduateStudent(Student):
    def __init__(self,name,grade,percentage,stream):
        super().__init__(name,grade,percentage)
        self.stream = stream

    def student_details(self): #method
        print(f"{self.name} is in class {self.grade} with {self.percentage}%")
        return f"This is Same Method but different Class"

s1 = Student("Jadu",11,96)

Gs1 = GraduateStudent("Raju",12,95,"PCM")

print(s1.student_details())
print()
print(Gs1.student_details())

# %%
## Base Class
class Animal:
    def speak(self):
        return "Sound of the animal"
    
## Derived Class 1
class Dog(Animal):
    def speak(self):
        return "Dog speak Woof!"
    
## Derived class
class Cat(Animal):
    def speak(self):
        return "Cat speak Meow!"
    
## Function that demonstrates polymorphism
def animal_speak(animal):
    print(animal.speak())
    
dog=Dog()
cat=Cat()
print(dog.speak())
print(cat.speak())

animal_speak(dog)
# Out:
# Dog speak Woof!
# Cat speak Meow!
# Dog speak Woof!

# %% [markdown]
# ### Method Overloading

# %%
class Shape:

    def area(self,radius):
        return (22/7) * (radius * 2)

    def area(self,l,b):
        return l * b

s = Shape()

s.area(2)

# %%
class Shape:

    def area(self,a,b=0):
        if b == 0:
            return (22/7) * (a * 2)
        else:
            return a * b

s = Shape()

print(s.area(2))
print(s.area(4,3))

# %%
### Polymorphissm with Functions and MEthods
## base class
class Shape:
    def area(self):
        return "The area of the figure"
    
## Derived class 1
class Rectangle(Shape):
    def __init__(self,width,height):
        self.width=width
        self.height=height

    def area(self):
        return self.width * self.height
    
##DErived class 2

class Circle(Shape):
    def __init__(self,radius):
        self.radius=radius

    def area(self):
        return 3.14*self.radius *self.radius
    
## Fucntion that demonstrates polymorphism

def print_area(shape):
    print(f"the area is {shape.area()}")


rectangle=Rectangle(4,3)
circle=Circle(2)

print_area(rectangle)
print_area(circle)

# %%
from abc import ABC,abstractmethod

## Define an abstract class
class Vehicle(ABC):
    @abstractmethod
    def start_engine(self):
        pass

## Derived class 1
class Car(Vehicle):
    def start_engine(self):
        return "Car enginer started"
    
## Derived class 2
class Motorcycle(Vehicle):
    def start_engine(self):
        return "Motorcycle enginer started"
    
# Function that demonstrates polymorphism
def start_vehicle(vehicle):
    print(vehicle.start_engine())

## create objects of cAr and Motorcycle

car = Car()
motorcycle = Motorcycle()

start_vehicle(car)
