# %% [markdown]
# ### Question 1: Class for Complex Numbers
#
# Create a Python class named `ComplexNumber` to represent complex numbers.
#
# **Theory:**
# A complex number is a number that comprises a real part and an imaginary part. It is typically written in the form `a + bi`, where `a` is the real part, and `b` is the imaginary part, and `i` is the imaginary unit (√-1).
#
# **Operations:**
# 1. Addition (+)
# 2. Subtraction (−)
# 3. Multiplication (×)
# 4. Division (÷)
# 5. Comparison (==, !=)

# %%
c1 = 2 + 3j
c2 = 5 + 4j

# %%
type(5 + 6j)
# Out:
# complex

# %%
type(c1) , type(c2)
# Out:
# (complex, complex)

# %%
c1.real , c1.imag
# Out:
# (2.0, 3.0)

# %%
print(f"{c1} + {c2}            = {c1+c2}")
print(f"{c1} - {c2}            = {c1-c2}")
print(f"{c1} * {c2}            = {c1*c2}")
print(f"{c1} / {c2}            = {(c1/c2).real:.2f} + {(c1/c2).imag:.2f}j")
print(f"{c1} equal to     {c2} = {c1==c2}")
print(f"{c1} not equal to {c2} = {c1==c2}")
# Out:
# (2+3j) + (5+4j)            = (7+7j)
# (2+3j) - (5+4j)            = (-3-1j)
# (2+3j) * (5+4j)            = (-2+23j)
# (2+3j) / (5+4j)            = 0.54 + 0.17j
# (2+3j) equal to     (5+4j) = False
# (2+3j) not equal to (5+4j) = False

# %%
c1.conjugate()
# Out:
# (2-3j)

# %%
class ComplexNumber:
    def __init__(self,real=0.0,imag=0.0):
        self.imag = imag
        self.real = real
    def conjugate(self):
        imag = self.imag * -1
        print(f"{self.real}  {imag}j")

# %%
cn = ComplexNumber(3,5)

# %%
cn.real , cn.imag
# Out:
# (3, 5)

# %%
cn.conjugate()
# Out:
# 3  -5j

# %%
class ComplexNumber:
    def __init__(self,real=0.0,imag=0.0):
        self.imag = imag
        self.real = real

    def __str__(self):
        if self.real == 0:
            return f"{self.imag}j"
        elif self.imag < 0:
            s = f"({self.real} - {self.imag}j)"
        else:
            s = f"({self.real} + {self.imag}j)"
        return s

    def conjugate(self):
        imag = self.imag * -1
        print(f"{self.real}  {imag}j")

# %%
cn1 = ComplexNumber(0,5)
cn2 = ComplexNumber(2,5)

# %%
print(cn1)
print(cn2)
# Out:
# 5j
# (2 + 5j)

# %%
cn1 + cn2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 cn1 + cn2
#
# TypeError: unsupported operand type(s) for +: 'ComplexNumber' and 'ComplexNumber'

# %%
1 + [1,2,3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 1 + [1,2,3]
#
# TypeError: unsupported operand type(s) for +: 'int' and 'list'

# %% [markdown]
# ### Magic Methods (dunder)
# - They are Special methods in Python which are define inside class
# - They begin and end with double underscore (__ init __( ))
# - They have a Special where in they get called themselves.
#     - Creation --> `__ init __`
#     - Print    --> `__ str __`
#     - '+'      --> `__add__`
#     - '-'      --> `__sub__`
#     - '*'      --> `__mul__`
#     - '/'      --> `__truediv__`
#     - '//'     --> `__floordiv__`
#     - '=='	   --> `__eq__`

# %%
class ComplexNumber:
    def __init__(self,real=0.0,imag=0.0):
        self.imag = imag
        self.real = real

    def __str__(self):
        if self.real == 0:
            return f"{self.imag}j"
        elif self.imag < 0:
            s = f"({self.real} {self.imag}j)"
        else:
            s = f"({self.real} + {self.imag}j)"
        return s

    def conjugate(self):
        return ComplexNumber(self.real,-1*self.imag)


        
    def __add__(self,other):
        resultReal = 0
        resultImag = 0

        resultReal = self.real + other.real
        resultImag = self.imag + other.imag
        ans = ComplexNumber(resultReal,resultImag)
        
        return ans
        
    def __sub__(self,other):
        resultReal = 0
        resultImag = 0

        resultReal = self.real - other.real
        resultImag = self.imag - other.imag
        ans = ComplexNumber(resultReal,resultImag)
        
        return ans

# %%
cn1 = ComplexNumber(7,5)
cn2 = ComplexNumber(2,5)

# %%
print(cn1 - cn2)
# Out:
# (5 + 0j)

# %%
print(cn1.conjugate())
# Out:
# (7 -5j)

# %% [markdown]
# ![image.png](attachment:7fb182e0-3501-4ffa-9f31-2d71eec8d344.png)

# %%
class ComplexNumber:
    def __init__(self,real=0.0,imag=0.0):
        self.imag = imag
        self.real = real

    def __str__(self):
        if self.real == 0:
            return f"{self.imag}j"
        elif self.imag < 0:
            s = f"({self.real} {self.imag}j)"
        else:
            s = f"({self.real} + {self.imag}j)"
        return s

    def conjugate(self):
        return ComplexNumber(self.real,-1*self.imag)


        
    def __add__(self,other):
        resultReal = 0
        resultImag = 0

        resultReal = self.real + other.real
        resultImag = self.imag + other.imag
        ans = ComplexNumber(resultReal,resultImag)
        
        return ans
        
    def __sub__(self,other):
        resultReal = 0
        resultImag = 0

        resultReal = self.real - other.real
        resultImag = self.imag - other.imag
        ans = ComplexNumber(resultReal,resultImag)
        
        return ans

        
    def __mul__(self,other):
        resultReal = 0
        resultImag = 0

        resultReal = (self.real * other.real) - (self.imag * other.imag)
        resultImag = (self.real * other.imag) + (self.imag * other.real)
        ans = ComplexNumber(resultReal,resultImag)

        return ans

# %%
cn1 = ComplexNumber(7,5)
cn2 = ComplexNumber(2,5)

# %%
print(cn1 * cn2)
# Out:
# (-11 + 45j)

# %% [markdown]
# ![image.png](attachment:80808a99-ce31-44db-b5d0-03e7ac19b670.png)

# %%
class ComplexNumber:
    def __init__(self,real=0.0,imag=0.0):
        self.imag = imag
        self.real = real

    def __str__(self):
        if self.real == 0:
            return f"{self.imag}j"
        elif self.imag < 0:
            s = f"({self.real} {self.imag}j)"
        else:
            s = f"({self.real} + {self.imag}j)"
        return s

    def conjugate(self):
        return ComplexNumber(self.real,-1*self.imag)


        
    def __add__(self,other):
        resultReal = 0
        resultImag = 0

        resultReal = self.real + other.real
        resultImag = self.imag + other.imag
        ans = ComplexNumber(resultReal,resultImag)
        
        return ans
        
    def __sub__(self,other):
        resultReal = 0
        resultImag = 0

        resultReal = self.real - other.real
        resultImag = self.imag - other.imag
        ans = ComplexNumber(resultReal,resultImag)
        
        return ans

        
    def __mul__(self,other):
        resultReal = 0
        resultImag = 0

        resultReal = (self.real * other.real) - (self.imag * self.imag)
        resultImag = (self.real * other.imag) + (self.imag * other.real)
        ans = ComplexNumber(resultReal,resultImag)

        return ans

    def __truediv__(self,other):
        resultReal = 0
        resultImag = 0

        resultReal = ((self.real * other.real) + (self.imag * self.imag))/((other.real ** 2) + (other.imag ** 2))
        resultImag = ((self.imag * other.real) - (self.real * other.imag))/((other.real ** 2) + (other.imag ** 2))

        ans = ComplexNumber(resultReal,resultImag)

        return ans

# %%
cn1 = ComplexNumber(7,5)
cn2 = ComplexNumber(2,5)

# %%
print(cn1 / cn2)
# Out:
# (1.3448275862068966 -0.8620689655172413j)

# %%
print(cn1)
print(cn2)
# Out:
# (7 + 5j)
# (2 + 5j)

# %%
print((7 + 5j)/(2 + 5j))
# Out:
# (1.3448275862068968-0.8620689655172414j)

# %% [markdown]
# ### Using __ mul __( )

# %%
class ComplexNumber:
    def __init__(self, real=0.0, imag=0.0):
        self.real = real
        self.imag = imag

    def __str__(self):
        if self.real == 0:
            return f"{self.imag}j"
        elif self.imag < 0:
            return f"({self.real} - {-self.imag}j)"
        else:
            return f"({self.real} + {self.imag}j)"

    def conjugate(self):
        return ComplexNumber(self.real, -self.imag)

    def __add__(self, other):
        return ComplexNumber(self.real + other.real, self.imag + other.imag)

    def __sub__(self, other):
        return ComplexNumber(self.real - other.real, self.imag - other.imag)

    def __mul__(self, other):
        real_part = (self.real * other.real) - (self.imag * other.imag)
        imag_part = (self.real * other.imag) + (self.imag * other.real)
        return ComplexNumber(real_part, imag_part)

    def __truediv__(self, other):
        denominator = other.real ** 2 + other.imag ** 2
        if denominator == 0:
            raise ZeroDivisionError("Cannot divide by zero in complex numbers.")
        
        real_part = (self.real * other.real + self.imag * other.imag) / denominator
        imag_part = (self.imag * other.real - self.real * other.imag) / denominator
        return ComplexNumber(real_part, imag_part)

# %%
cn1 = ComplexNumber(7,5)
cn2 = ComplexNumber(2,5)

# %%
print(cn1/cn2)
# Out:
# (1.3448275862068966 - 0.8620689655172413j)

# %%
print(cn1)
print(cn1.conjugate())
# Out:
# (7 + 5j)
# (7 - 5j)

# %% [markdown]
# ### Equal

# %%
class ComplexNumber:
    def __init__(self, real=0.0, imag=0.0):
        self.real = real
        self.imag = imag

    def __str__(self):
        if self.real == 0:
            return f"{self.imag}j"
        elif self.imag < 0:
            return f"({self.real} - {-self.imag}j)"
        else:
            return f"({self.real} + {self.imag}j)"

    def conjugate(self):
        return ComplexNumber(self.real, -self.imag)

    def __add__(self, other):
        return ComplexNumber(self.real + other.real, self.imag + other.imag)

    def __sub__(self, other):
        return ComplexNumber(self.real - other.real, self.imag - other.imag)

    def __mul__(self, other):
        real_part = (self.real * other.real) - (self.imag * other.imag)
        imag_part = (self.real * other.imag) + (self.imag * other.real)
        return ComplexNumber(real_part, imag_part)

    def __truediv__(self, other):
        denominator = other.real ** 2 + other.imag ** 2
        if denominator == 0:
            raise ZeroDivisionError("Cannot divide by zero in complex numbers.")
        
        real_part = (self.real * other.real + self.imag * other.imag) / denominator
        imag_part = (self.imag * other.real - self.real * other.imag) / denominator
        return ComplexNumber(real_part, imag_part)

    def __eq__(self,other):
        return (self.real == other.real) and (self.imag == other.imag)

# %%
cn1 = ComplexNumber(7,5)
cn2 = ComplexNumber(7,5)

# %%
print(cn1 == cn2)
# Out:
# True

# %%
a = 1 - 2j
b = 2 + 5j
a * b
# Out:
# (12+1j)
