# %%
import numpy as np

# %%
# python

# 1. list
# 2. tuples
# 3. set
# 4. dict

# %%
List_1 = [1,2,4,5]
List_1

# %%
# 64 and 32

np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
# dimesion
# 1d arrays
arr1 = np.array([1,2,3,4])

# 2d arrays
arr2 = np.array([[1,2],[3,4]])

# %%
# 3d arrays
arr3 = np.array([[[1,2],[3,4],[5,6]]])

# %%
arr1.ndim
# Out:
# 1

# %%
arr2.ndim
# Out:
# 2

# %%
arr3.ndim
# Out:
# 3
