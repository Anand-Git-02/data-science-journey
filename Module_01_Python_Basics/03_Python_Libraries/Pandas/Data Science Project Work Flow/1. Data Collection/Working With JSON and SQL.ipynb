# %% [markdown]
# #### Data Collection :- https://www.kaggle.com/datasets/kaggle/recipe-ingredients-dataset/data?select=train.json

# %% [markdown]
# #### 1. Import Pandas

# %%
import pandas as pd

# %%
pd.read_json('Data/train.json')
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
df = pd.read_json('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US@page=1')

# %%
df['results'][0]
# Out:
# {'adult': False,
#  'backdrop_path': '/zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg',
#  'genre_ids': [18, 80],
#  'id': 278,
#  'original_language': 'en',
#  'original_title': 'The Shawshank Redemption',
#  'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#  'popularity': 178.508,
#  'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg',
#  'release_date': '1994-09-23',
#  'title': 'The Shawshank Redemption',
#  'video': False,
#  'vote_average': 8.708,
#  'vote_count': 27341}

# %% [markdown]
# ### Working With SQL

# %%
# !pip install mysql.connector
# Out:
# ...
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      --------------------------------------- 0.0/11.9 MB 330.3 kB/s eta 0:00:36
#      --------------------------------------- 0.1/11.9 MB 544.7 kB/s eta 0:00:22
#       --------------------------------------- 0.3/11.9 MB 1.8 MB/s eta 0:00:07
#      -- ------------------------------------- 0.6/11.9 MB 3.5 MB/s eta 0:00:04
#      -- ------------------------------------- 0.7/11.9 MB 3.2 MB/s eta 0:00:04
#      --- ------------------------------------ 1.1/11.9 MB 4.0 MB/s eta 0:00:03
#      ---- ----------------------------------- 1.3/11.9 MB 4.2 MB/s eta 0:00:03
#      ---- ----------------------------------- 1.4/11.9 MB 3.9 MB/s eta 0:00:03
#      ----- ---------------------------------- 1.6/11.9 MB 4.0 MB/s eta 0:00:03
#      ------ --------------------------------- 1.8/11.9 MB 4.2 MB/s eta 0:00:03
#      ------ --------------------------------- 2.0/11.9 MB 4.1 MB/s eta 0:00:03
# ...

# %%
import mysql.connector

# %%
import mysql.connector

mydb  = mysql.connector.connect(host='localhost',user='root',password='peace@321')
