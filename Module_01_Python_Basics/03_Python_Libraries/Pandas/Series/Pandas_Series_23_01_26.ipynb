# %% [markdown]
# ---

# %% [markdown]
# ### Pandas Series

# %% [markdown]
# ---

# %%
# Pandas 
# - Series --> 1d
# - Dataframe --> 2d
# - panel data --> multi dimesion

# %% [markdown]
# #### How to Create Series

# %%
import pandas as pd

# %%
marks = [67,57,89,100]
subjects = ['maths','english','science','hindi']

# %%
# 

S4 =pd.Series(data=marks,index=subjects)
S4
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# dtype: int64

# %%
Subs = pd.read_csv('Data/subs.csv').squeeze("columns")
Subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
type(Subs)
# Out:
# pandas.core.series.Series

# %%
vk = pd.read_csv("Data/kohli_ipl.csv",index_col='match_no').squeeze("columns")
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
movies = pd.read_excel("Data/bollywood.xlsx",index_col='movie').squeeze('columns')
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# ### Series methods

# %%
# head , tail , sample , value_counts() ,sort_values,sort_index

# %%
movies.head(10)
# Out:
# movie
# Uri: The Surgical Strike                       Vicky Kaushal
# Battalion 609                                    Vicky Ahuja
# The Accidental Prime Minister (film)             Anupam Kher
# Why Cheat India                                Emraan Hashmi
# Evening Shadows                             Mona Ambegaonkar
# Soni (film)                             Geetika Vidya Ohlyan
# Fraud Saiyaan                                   Arshad Warsi
# Bombairiya                                      Radhika Apte
# Manikarnika: The Queen of Jhansi              Kangana Ranaut
# Thackeray (film)                         Nawazuddin Siddiqui
# Name: lead, dtype: object

# %%
movies.tail()
# Out:
# movie
# Hum Tumhare Hain Sanam      Shah Rukh Khan
# Aankhen (2002 film)       Amitabh Bachchan
# Saathiya (film)               Vivek Oberoi
# Company (film)                  Ajay Devgn
# Awara Paagal Deewana          Akshay Kumar
# Name: lead, dtype: object

# %%
vk.head()
# Out:
# match_no
# 1     1
# 2    23
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int64

# %%
vk.sample(5)
# Out:
# match_no
# 41     71
# 118    33
# 97     67
# 83     17
# 95     10
# Name: runs, dtype: int64

# %%
movies.value_counts()
# Out:
# lead
# Akshay Kumar            48
# Amitabh Bachchan        45
# Ajay Devgn              38
# Salman Khan             31
# Sanjay Dutt             26
#                         ..
# Tanishaa Mukerji         1
# Tanuja                   1
# Ankit                    1
# Rakhee Gulzar            1
# Geetika Vidya Ohlyan     1
# Name: count, Length: 566, dtype: int64

# %%
movies.sort_values().head(10)
# Out:
# movie
# Qaidi Band                           Aadar Jain
# Roar: Tigers of the Sundarbans     Aadil Chahal
# Lipstick Under My Burkha           Aahana Kumra
# Raat Gayi Baat Gayi?               Aamir Bashir
# Talaash: The Answer Lies Within      Aamir Khan
# Fanaa (2006 film)                    Aamir Khan
# 3 Idiots                             Aamir Khan
# Ghajini (2008 film)                  Aamir Khan
# Rang De Basanti                      Aamir Khan
# Mangal Pandey: The Rising            Aamir Khan
# Name: lead, dtype: object

# %%
movies.sort_index().head(10)
# Out:
# movie
# 1920 (film)               Rajniesh Duggall
# 1920: London                 Sharman Joshi
# 1920: The Evil Returns         Vicky Ahuja
# 1971 (2007 film)            Manoj Bajpayee
# 2 States (2014 film)          Arjun Kapoor
# 22 Yards                       Barun Sobti
# 3 A.M. (2014 film)           Salil Acharya
# 3 Deewarein               Naseeruddin Shah
# 3 Idiots                        Aamir Khan
# 3 Storeys                      Aisha Ahmed
# Name: lead, dtype: object

# %%
S4
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# dtype: int64

# %%
S4.index
# Out:
# Index(['maths', 'english', 'science', 'hindi'], dtype='object')

# %%
S4.values
# Out:
# array([ 67,  57,  89, 100])

# %%
S4['english'] = 100

# %%
S4
# Out:
# maths       67
# english    100
# science     89
# hindi      100
# dtype: int64

# %%
# use read_csv

# %%
# vk --> highest scores in which match
# moives --> top actors
# subs -->

# %%
m2 = movies.copy()
m2.sort_values(ascending=False,inplace=True)

# %%
m2
# Out:
# movie
# Taj Mahal: An Eternal Love Story     Zulfi Sayed
# Dil Toh Deewana Hai                  Zeenat Aman
# Strings of Passion                   Zeenat Aman
# Sallu Ki Shaadi                      Zeenat Aman
# Dunno Y... Na Jaane Kyon             Zeenat Aman
#                                         ...
# Fanaa (2006 film)                     Aamir Khan
# Raat Gayi Baat Gayi?                Aamir Bashir
# Lipstick Under My Burkha            Aahana Kumra
# Roar: Tigers of the Sundarbans      Aadil Chahal
# Qaidi Band                            Aadar Jain
# Name: lead, Length: 1500, dtype: object

# %%
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# ### Series Maths Methods

# %%
# count() , sum , min , max , mean , mode ,median , var ,std

# %%
Subs.count()
# Out:
# np.int64(365)

# %%
Subs.sum()
# Out:
# np.int64(49510)

# %%
vk.sum()
# Out:
# np.int64(6634)

# %%
# movies.sum()

# %%
Subs.min()
# Out:
# 33

# %%
Subs.max()
# Out:
# 396

# %%
vk.min() , vk.max()
# Out:
# (0, 113)

# %%
Subs.mean()
# Out:
# np.float64(135.64383561643837)

# %%
Subs.median()
# Out:
# 123.0

# %%
movies.value_counts()[:5]
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Name: count, dtype: int64

# %%
movies.mode()
# Out:
# 0    Akshay Kumar
# Name: lead, dtype: object

# %%
Subs.var()
# Out:
# 3928.1585127201556

# %%
vk.var() # --> more
# Out:
# 688.0024777222344

# %%
vk.std()
# Out:
# 26.22980132830278

# %%
import numpy as np

# %%
List = np.random.randint(1,20,10)
List
# Out:
# array([ 1,  3, 12, 15, 14,  9,  7, 12,  5,  4], dtype=int32)

# %%
# mean and variance example
S1 = pd.Series(List)
S1
# Out:
# 0     1
# 1     3
# 2    12
# 3    15
# 4    14
# 5     9
# 6     7
# 7    12
# 8     5
# 9     4
# dtype: int32

# %%
S1.mean()
# Out:
# np.float64(8.2)

# %%
S1.std()
# Out:
# 4.917090377222873

# %%
sorted(S1)
# Out:
# [1, 3, 4, 5, 7, 9, 12, 12, 14, 15]

# %%
# mean + std ()
8.2 + 4.917090377222873  # postive side
# Out:
# 13.117090377222873

# %%
# mean - std()
8.2 - 4.917090377222873  # negative
# Out:
# 3.282909622777126

# %% [markdown]
# ### Series Indexing

# %%
# integer indexing
x = pd.Series([12,13,14,35,46,57,58,79,9])
x
# Out:
# 0    12
# 1    13
# 2    14
# 3    35
# 4    46
# 5    57
# 6    58
# 7    79
# 8     9
# dtype: int64

# %%
# start . end , step

x[0:4:2]
# Out:
# 0    12
# 2    14
# dtype: int64

# %%
List = [2,3,5,7,8]
List[1,2,3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[70], line 2
#       1 List = [2,3,5,7,8]
# ----> 2 List[1,2,3]
#
# TypeError: list indices must be integers or slices, not tuple

# %%
x
# Out:
# 0    12
# 1    13
# 2    14
# 3    35
# 4    46
# 5    57
# 6    58
# 7    79
# 8     9
# dtype: int64

# %%
x[[4,6,8,1]]
# Out:
# 4    46
# 6    58
# 8     9
# 1    13
# dtype: int64

# %%
movies["2 States (2014 film)"]
# Out:
# 'Arjun Kapoor'

# %%
movies["2 States (2014 film)"] = 'Alia Bhatt'

# %%
movies["2 States (2014 film)"]
# Out:
# 'Alia Bhatt'

# %%
x
# Out:
# 0    12
# 1    13
# 2    14
# 3    35
# 4    46
# 5    57
# 6    58
# 7    79
# 8     9
# dtype: int64

# %%
x[8] = 90

# %%
x
# Out:
# 0    12
# 1    13
# 2    14
# 3    35
# 4    46
# 5    57
# 6    58
# 7    79
# 8    90
# dtype: int64

# %%
# len/type/dir/sorted

len(x)
# Out:
# 9

# %%
type(x)
# Out:
# pandas.core.series.Series

# %%
print(dir(x))
# Out:
# ['T', '_AXIS_LEN', '_AXIS_ORDERS', '_AXIS_TO_AXIS_NUMBER', '_HANDLED_TYPES', '__abs__', '__add__', '__and__', '__annotations__', '__array__', '__array_priority__', '__array_ufunc__', '__bool__', '__class__', '__column_consortium_standard__', '__contains__', '__copy__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__divmod__', '__doc__', '__eq__', '__finalize__', '__firstlineno__', '__float__', '__floordiv__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__iand__', '__ifloordiv__', '__imod__', '__imul__', '__init__', '__init_subclass__', '__int__', '__invert__', '__ior__', '__ipow__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pandas_priority__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__
# ...

# %%
x
# Out:
# 0    12
# 1    13
# 2    14
# 3    35
# 4    46
# 5    57
# 6    58
# 7    79
# 8    90
# dtype: int64

# %%
46 in x.values
# Out:
# True

# %%
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
movies.index
# Out:
# Index(['Uri: The Surgical Strike', 'Battalion 609',
#        'The Accidental Prime Minister (film)', 'Why Cheat India',
#        'Evening Shadows', 'Soni (film)', 'Fraud Saiyaan', 'Bombairiya',
#        'Manikarnika: The Queen of Jhansi', 'Thackeray (film)',
#        ...
#        'Raaz (2002 film)', 'Zameen (2003 film)', 'Waisa Bhi Hota Hai Part II',
#        'Devdas (2002 Hindi film)', 'Kaante', 'Hum Tumhare Hain Sanam',
#        'Aankhen (2002 film)', 'Saathiya (film)', 'Company (film)',
#        'Awara Paagal Deewana'],
#       dtype='object', name='movie', length=1500)

# %%
# for i in movies.index:
#     print(i)

# %%
x
# Out:
# 0    12
# 1    13
# 2    14
# 3    35
# 4    46
# 5    57
# 6    58
# 7    79
# 8    90
# dtype: int64

# %%
x + 100
# Out:
# 0    112
# 1    113
# 2    114
# 3    135
# 4    146
# 5    157
# 6    158
# 7    179
# 8    190
# dtype: int64

# %%
x
# Out:
# 0    12
# 1    13
# 2    14
# 3    35
# 4    46
# 5    57
# 6    58
# 7    79
# 8    90
# dtype: int64

# %%
x >= 35
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# dtype: bool

# %%
x[x > 35]
# Out:
# 4    46
# 5    57
# 6    58
# 7    79
# 8    90
# dtype: int64

# %%
x.describe()
# Out:
# count     9.000000
# mean     44.888889
# std      28.872324
# min      12.000000
# 25%      14.000000
# 50%      46.000000
# 75%      58.000000
# max      90.000000
# dtype: float64

# %%
vk.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 215 entries, 1 to 215
# Series name: runs
# Non-Null Count  Dtype
# --------------  -----
# 215 non-null    int64
# dtypes: int64(1)
# memory usage: 3.4 KB

# %%
# Find no of 50's and 100's scored by kohli
# find number of ducks
# Count number of day when I had more than 200 subs a day
# find actors who have done more than 20 movies

# %%
vk.head()
# Out:
# match_no
# 1     1
# 2    23
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int64

# %%
vk[vk == 50]
# Out:
# match_no
# 15     50
# 182    50
# Name: runs, dtype: int64

# %%
# and --> &
# or --> |
vk[(vk == 50) | (vk==100)]
# Out:
# match_no
# 15      50
# 120    100
# 164    100
# 182     50
# Name: runs, dtype: int64

# %%
# Find no of 50's and 100's scored by kohli


vk[(vk >= 50) | (vk == 100)].size
# Out:
# 50

# %%
# find number of ducks

vk[vk == 0].size
# Out:
# 9

# %%
# Count number of day when I had more than 200 subs a day
# find actors who have done more than 20 movies


Subs[Subs > 200].count()
# Out:
# np.int64(59)

# %%
movie_counts = movies.value_counts()

movie_counts[movie_counts > 20]
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: count, dtype: int64

# %% [markdown]
# ### Plotting Graphs on Series

# %%
# plot(line) --> parameter ---> kind ('bar','pie')

Subs.plot()
# Out:
# <Axes: >

# %%
df = pd.DataFrame(Subs)
df.head()
# Out:
#    Subscribers gained
# 0                  48
# 1                  57
# 2                  40
# 3                  43
# 4                  44

# %%
df.reset_index()
# Out:
#      index  Subscribers gained
# 0        0                  48
# 1        1                  57
# 2        2                  40
# 3        3                  43
# 4        4                  44
# ..     ...                 ...
# 360    360                 231
# 361    361                 226
# 362    362                 155
# 363    363                 144
# 364    364                 172
#
# [365 rows x 2 columns]

# %%
df.reset_index().columns[0]
# Out:
# 'index'

# %%
df.reset_index().plot(kind='scatter', x='index', y=df.columns[0])
# Out:
# <Axes: xlabel='index', ylabel='Subscribers gained'>

# %%
# bar  , pie

movies.value_counts().head(5).plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
movies.value_counts().head(5).plot(kind='bar')
# Out:
# <Axes: xlabel='lead'>
