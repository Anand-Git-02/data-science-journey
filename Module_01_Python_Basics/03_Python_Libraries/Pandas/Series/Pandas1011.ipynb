# %%
import pandas as pd
import numpy as np

# %%
x = pd.Series([12,13,14,35,46,57,58,79,9])
x
# Out:
# 0    12
# 1    13
# 2    14
# 3    35
# 4    46
# 5    57
# 6    58
# 7    79
# 8     9
# dtype: int64

# %%
x[5]
# Out:
# 57

# %%
x[x > 20]
# Out:
# 3    35
# 4    46
# 5    57
# 6    58
# 7    79
# dtype: int64

# %%
vk = pd.read_csv('Data/kohli_ipl.csv',index_col='match_no').squeeze('columns')
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
# Find no of 50's and 100's scored by kohli
vk[(vk == 50) | (vk==100)].shape[0]
# Out:
# 4

# %%
# Count number of day when I had more than 200 subs a day
Sub = pd.read_csv('Data/subs.csv')

Sub
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
# find actors who have done more than 20 movies

df = pd.read_csv('Data/bollywood.csv',index_col='movie').squeeze('columns')

df.value_counts()[df.value_counts() > 20]
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: count, dtype: int64

# %%
df.value_counts()[df.value_counts() > 20].plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df.value_counts().head(5).plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
x
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Diganth              1
# Parveen Kaur         1
# Seema Azmi           1
# Akanksha Puri        1
# Edwin Fernandes      1
# Name: count, Length: 566, dtype: int64

# %%
x = pd.Series([12,13,14,35,46,57,58,79,9])
x
# Out:
# 0    12
# 1    13
# 2    14
# 3    35
# 4    46
# 5    57
# 6    58
# 7    79
# 8     9
# dtype: int64

# %%
x[x.between(10,30)]
# Out:
# 0    12
# 1    13
# 2    14
# dtype: int64

# %%
Ser1 = x.clip(13,36)
Ser1
# Out:
# 0    13
# 1    13
# 2    14
# 3    35
# 4    36
# 5    36
# 6    36
# 7    36
# 8    13
# dtype: int64

# %%
Ser1.duplicated()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# 5     True
# 6     True
# 7     True
# 8     True
# dtype: bool

# %%
Ser1.drop_duplicates()
# Out:
# 0    13
# 2    14
# 3    35
# 4    36
# dtype: int64

# %%
Ser1[7] = np.nan

# %%
Ser1[3:9:2] = np.nan

# %%
Ser1
# Out:
# 0    13.0
# 1    13.0
# 2    14.0
# 3     NaN
# 4    36.0
# 5     NaN
# 6    36.0
# 7     NaN
# 8    13.0
# dtype: float64

# %%
(Ser1.isnull().sum()/Ser1.shape[0]) * 100
# Out:
# 33.33333333333333

# %%
# 0 - 10 drop
# 20 - 70 inputation (fillna)
# 70 - 90 columns drop

# %%
x
# Out:
# 0    12
# 1    13
# 2    14
# 3    35
# 4    46
# 5    57
# 6    58
# 7    79
# 8     9
# dtype: int64

# %%
x.isin([12])
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# dtype: bool

# %%
df
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
lambda x:x.upper()

# %%
df.apply(lambda x:x.upper())
# Out:
# movie
# Uri: The Surgical Strike                   VICKY KAUSHAL
# Battalion 609                                VICKY AHUJA
# The Accidental Prime Minister (film)         ANUPAM KHER
# Why Cheat India                            EMRAAN HASHMI
# Evening Shadows                         MONA AMBEGAONKAR
#                                               ...
# Hum Tumhare Hain Sanam                    SHAH RUKH KHAN
# Aankhen (2002 film)                     AMITABH BACHCHAN
# Saathiya (film)                             VIVEK OBEROI
# Company (film)                                AJAY DEVGN
# Awara Paagal Deewana                        AKSHAY KUMAR
# Name: lead, Length: 1500, dtype: object

# %%
Sub['Subscribers gained'].mean()
# Out:
# 135.64383561643837

# %%
Sub
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
days = lambda x: "Good Day" if x > Sub['Subscribers gained'].mean() else "Bad Day"


Sub['Subscribers gained'].apply(days)
# Out:
# 0       Bad Day
# 1       Bad Day
# 2       Bad Day
# 3       Bad Day
# 4       Bad Day
#          ...
# 360    Good Day
# 361    Good Day
# 362    Good Day
# 363    Good Day
# 364    Good Day
# Name: Subscribers gained, Length: 365, dtype: object

# %%
Sub['Subscribers gained'].apply(days).value_counts()
# Out:
# Subscribers gained
# Bad Day     202
# Good Day    163
# Name: count, dtype: int64
