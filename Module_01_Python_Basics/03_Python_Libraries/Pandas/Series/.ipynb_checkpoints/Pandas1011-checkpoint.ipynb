# %%
import numpy as np
import pandas as pd

# %%
# empty Series

pd.Series()
# Out:
# Series([], dtype: object)

# %%
pd.Series([i for i in range(1,5)])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
pd.Series([i for i in "abcd"])
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: object

# %%
country = ['India','Pakistan','USA','Nepal','Srilanka']

a = [i for i in "IPUNS"]


pd.Series(data=country , index=a)
# Out:
# I       India
# P    Pakistan
# U         USA
# N       Nepal
# S    Srilanka
# dtype: object

# %%
marks = [67,57,89,100]
subjects = ['maths','english','science','hindi']


pd.Series(data=marks,index=subjects)
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# dtype: int64

# %%
marks = [67,57,89,100]
subjects = ['maths','english','science','hindi']


pd.Series(data=marks,index=subjects,name='Jadu ke Marks')
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# Name: Jadu ke Marks, dtype: int64

# %%
marks = {
    'maths':67,
    'english':57,
    'science':60,
    'hindi':100
}

S1 = pd.Series(marks,dtype='int32')

# %%
# size
# index
# is_unique
# name
# values
# dtype

# %%
S1.size
# Out:
# 4

# %%
S1.index
# Out:
# Index(['maths', 'english', 'science', 'hindi'], dtype='object')

# %%
S1.is_unique
# Out:
# True

# %%
S1.values
# Out:
# array([ 67,  57,  60, 100])

# %%
S1.dtypes
# Out:
# dtype('int32')

# %%
ipl = pd.read_csv('Data/kohli_ipl.csv',index_col='match_no').squeeze('columns')
ipl
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
movies = pd.read_csv('Data/bollywood.csv',index_col='movie').squeeze('columns')
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
# head()
# taile()
# sample()
# values_count()
# sort_values()

# %%
ipl.head(10)
# Out:
# match_no
# 1      1
# 2     23
# 3     13
# 4     12
# 5      1
# 6      9
# 7     34
# 8      0
# 9     21
# 10     3
# Name: runs, dtype: int64

# %%
ipl.tail(10)
# Out:
# match_no
# 206     0
# 207     0
# 208     9
# 209    58
# 210    30
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
ipl.sample(5)
# Out:
# match_no
# 129    54
# 33     13
# 192     5
# 102    18
# 11     10
# Name: runs, dtype: int64

# %%
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
movies.value_counts()
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Diganth              1
# Parveen Kaur         1
# Seema Azmi           1
# Akanksha Puri        1
# Edwin Fernandes      1
# Name: count, Length: 566, dtype: int64

# %%
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
movies.sort_values()
# Out:
# movie
# Qaidi Band                            Aadar Jain
# Roar: Tigers of the Sundarbans      Aadil Chahal
# Lipstick Under My Burkha            Aahana Kumra
# Raat Gayi Baat Gayi?                Aamir Bashir
# Talaash: The Answer Lies Within       Aamir Khan
#                                         ...
# Dil Toh Deewana Hai                  Zeenat Aman
# Sallu Ki Shaadi                      Zeenat Aman
# Strings of Passion                   Zeenat Aman
# Dunno Y... Na Jaane Kyon             Zeenat Aman
# Taj Mahal: An Eternal Love Story     Zulfi Sayed
# Name: lead, Length: 1500, dtype: object

# %%
ipl2 = ipl.copy()
ipl2.sort_values(inplace=True)

# %%
ipl2
# Out:
# match_no
# 87       0
# 211      0
# 207      0
# 206      0
# 91       0
#       ...
# 164    100
# 120    100
# 123    108
# 126    109
# 128    113
# Name: runs, Length: 215, dtype: int64

# %%
ipl
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
ipl.describe()
# Out:
# count    215.000000
# mean      30.855814
# std       26.229801
# min        0.000000
# 25%        9.000000
# 50%       24.000000
# 75%       48.000000
# max      113.000000
# Name: runs, dtype: float64

# %%
ipl
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
ipl[1]
# Out:
# 1

# %%
ipl[0:10]
# Out:
# match_no
# 1      1
# 2     23
# 3     13
# 4     12
# 5      1
# 6      9
# 7     34
# 8      0
# 9     21
# 10     3
# Name: runs, dtype: int64

# %%
ipl[2:10]
# Out:
# match_no
# 3     13
# 4     12
# 5      1
# 6      9
# 7     34
# 8      0
# 9     21
# 10     3
# Name: runs, dtype: int64

# %%
ipl[-5:]
# Out:
# match_no
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
ipl
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
ipl[[1,3,212,124]]
# Out:
# match_no
# 1       1
# 3      13
# 212    20
# 124    20
# Name: runs, dtype: int64

# %%
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
movies['Hum Tumhare Hain Sanam']
# Out:
# 'Shah Rukh Khan'

# %%
S1
# Out:
# maths       67
# english     57
# science     60
# hindi      100
# dtype: int32

# %%
S1['science'] = 70

# %%
S1
# Out:
# maths       67
# english     57
# science     70
# hindi      100
# dtype: int32

# %%
ipl[1:4] = [100,200,300]

# %%
ipl
# Out:
# match_no
# 1        1
# 2      100
# 3      200
# 4      300
# 5        1
#       ...
# 211      0
# 212     20
# 213     73
# 214     25
# 215      7
# Name: runs, Length: 215, dtype: int64

# %%
movies['2 States (2014 film)'] = 'Alia Bhatt'

# %%
movies['2 States (2014 film)']
# Out:
# 'Alia Bhatt'

# %%
type(movies)
# Out:
# pandas.core.series.Series

# %%
print(dir(movies))
# Out:
# ['Aiyaary', 'Amavas', 'Bombairiya', 'Hichki', 'Jhalki', 'Kaalakaandi', 'Kalank', 'Marjaavaan', 'Mukkabaaz', 'Nirdosh', 'Padmaavat', 'Pranaam', 'Prassthanam', 'Risknamaa', 'Saaho', 'Sonchiriya', 'T', '_AXIS_LEN', '_AXIS_ORDERS', '_AXIS_TO_AXIS_NUMBER', '_HANDLED_TYPES', '__abs__', '__add__', '__and__', '__annotations__', '__array__', '__array_priority__', '__array_ufunc__', '__bool__', '__class__', '__column_consortium_standard__', '__contains__', '__copy__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__divmod__', '__doc__', '__eq__', '__finalize__', '__float__', '__floordiv__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__iand__', '__ifloordiv__', '__imod__', '__imul__', '__init__', '__init_subclass__', '__int__', '__invert__', '__ior__', '__ipow__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul
# ...

# %%
print(sorted(movies))
# Out:
# ['Aadar Jain', 'Aadil Chahal', 'Aahana Kumra', 'Aamir Bashir', 'Aamir Khan', 'Aamir Khan', 'Aamir Khan', 'Aamir Khan', 'Aamir Khan', 'Aamir Khan', 'Aamir Khan', 'Aamir Khan', 'Aamir Khan', 'Aamir Khan', 'Aanchal Dwivedi', 'Aarav Khanna', 'Aarti Chhabria', 'Aashish Bhatt', 'Abhay Deol', 'Abhay Deol', 'Abhay Deol', 'Abhay Deol', 'Abhay Deol', 'Abhay Deol', 'Abhay Deol', 'Abhimanyu Dasani', 'Abhishek Bachchan', 'Abhishek Bachchan', 'Abhishek Bachchan', 'Abhishek Bachchan', 'Abhishek Bachchan', 'Abhishek Bachchan', 'Abhishek Bachchan', 'Abhishek Bachchan', 'Abhishek Bachchan', 'Abhishek Bachchan', 'Abhishek Bharate', 'Adhvik Mahajan', 'Adhyayan Suman', 'Adhyayan Suman', 'Adhyayan Suman', 'Adil Hussain', 'Adil Hussain', 'Aditya Narayan', 'Aditya Roy Kapoor', 'Aditya Roy Kapoor', 'Aditya Roy Kapoor', 'Aditya Srivastava', 'Aftab Shivdasani', 'Aftab Shivdasani', 'Aftab Shivdasani', 'Aftab Shivdasani', 'Aftab Shivdasani', 'Aftab Shivdasani', 'Aftab Shivdasani', 'Aftab Shivdasani', 'Aftab Shiv
# ...

# %%
print(dir(list(ipl)))
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %%
ipl.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 215 entries, 1 to 215
# Series name: runs
# Non-Null Count  Dtype
# --------------  -----
# 215 non-null    int64
# dtypes: int64(1)
# memory usage: 11.5 KB

# %%
ipl3 = ipl.astype('int32')
ipl3
# Out:
# match_no
# 1        1
# 2      100
# 3      200
# 4      300
# 5        1
#       ...
# 211      0
# 212     20
# 213     73
# 214     25
# 215      7
# Name: runs, Length: 215, dtype: int32

# %%
ipl3.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 215 entries, 1 to 215
# Series name: runs
# Non-Null Count  Dtype
# --------------  -----
# 215 non-null    int32
# dtypes: int32(1)
# memory usage: 10.6 KB

# %%
ipl.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 215 entries, 1 to 215
# Series name: runs
# Non-Null Count  Dtype
# --------------  -----
# 215 non-null    int64
# dtypes: int64(1)
# memory usage: 11.5 KB

# %%
S1
# Out:
# maths       67
# english     57
# science     70
# hindi      100
# dtype: int32

# %%
S1['computer'] = "A"

# %%
S1
# Out:
# maths        67
# english      57
# science      70
# hindi       100
# computer      A
# dtype: object

# %%
del S1['computer']

# %%
S1
# Out:
# maths       67
# english     57
# science     70
# hindi      100
# dtype: object

# %%
# Find no of 50's and 100's scored by kohli


ipl[(ipl > 50) | (ipl == 100)].size
# Out:
# 51

# %%
ipl[ipl == 0].size
# Out:
# 9

# %%
Subs = pd.read_csv('Data/subs.csv').squeeze('columns')
Subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
Subs[Subs > 200].size
# Out:
# 59

# %%
# find actors who have done more than 20 movies

new_moive = movies.value_counts()

new_moive[new_moive > 20]
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: count, dtype: int64

# %%
Subs.plot()
# Out:
# <Axes: >

# %%
new_moive = movies.value_counts()

new_moive[new_moive > 20].plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
# astype
# between
# clip
# drop_duplicates
# isnull
# dropna
# fillna
# isin
# apply
# copy

# %%
# ipl[ipl.between(0,10)]

# %%
S2 = pd.Series(np.random.randint(1,100,20))

# %%
S2.clip(20,60)
# Out:
# 0     60
# 1     35
# 2     60
# 3     60
# 4     20
# 5     60
# 6     35
# 7     54
# 8     60
# 9     20
# 10    60
# 11    25
# 12    20
# 13    60
# 14    60
# 15    26
# 16    60
# 17    60
# 18    60
# 19    60
# dtype: int32

# %%
ipl.clip(50,100)

# %%
S1['maths'] = 67

# %%
S1['maths2'] = 67

# %%
S1
# Out:
# maths       67
# english     57
# science     70
# hindi      100
# maths2      67
# dtype: object

# %%
S1.duplicated().sum()
# Out:
# 1

# %%
S1.drop_duplicates(inplace=True)

# %%
S1
# Out:
# maths       67
# english     57
# science     70
# hindi      100
# dtype: object

# %%
# isnull
# dropna
# fillna


S1['Subject2'] = None

# %%
S1
# Out:
# maths         67
# english       57
# science       70
# hindi        100
# Subject1     NaN
# Subject2    None
# dtype: object

# %%
S1.isna().sum()
# Out:
# 2

# %%
S1.isnull()
# Out:
# maths       False
# english     False
# science     False
# hindi       False
# Subject1     True
# Subject2     True
# dtype: bool

# %%
S1.dropna()
# Out:
# maths       67
# english     57
# science     70
# hindi      100
# dtype: object

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
S1['Subject1'] = 100

# %%
S1
# Out:
# maths         67
# english       57
# science       70
# hindi        100
# Subject1     100
# Subject2    None
# dtype: object

# %%
# isin
# apply


S1.isin([67,70])
# Out:
# maths        True
# english     False
# science      True
# hindi       False
# Subject1    False
# Subject2    False
# dtype: bool

# %%
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
movies.apply(len)
# Out:
# movie
# Uri: The Surgical Strike                13
# Battalion 609                           11
# The Accidental Prime Minister (film)    11
# Why Cheat India                         13
# Evening Shadows                         16
#                                         ..
# Hum Tumhare Hain Sanam                  14
# Aankhen (2002 film)                     16
# Saathiya (film)                         12
# Company (film)                          10
# Awara Paagal Deewana                    12
# Name: lead, Length: 1500, dtype: int64

# %%
Upper = lambda x : x.upper()

# %%
movies.apply(Upper)
# Out:
# movie
# Uri: The Surgical Strike                   VICKY KAUSHAL
# Battalion 609                                VICKY AHUJA
# The Accidental Prime Minister (film)         ANUPAM KHER
# Why Cheat India                            EMRAAN HASHMI
# Evening Shadows                         MONA AMBEGAONKAR
#                                               ...
# Hum Tumhare Hain Sanam                    SHAH RUKH KHAN
# Aankhen (2002 film)                     AMITABH BACHCHAN
# Saathiya (film)                             VIVEK OBEROI
# Company (film)                                AJAY DEVGN
# Awara Paagal Deewana                        AKSHAY KUMAR
# Name: lead, Length: 1500, dtype: object

# %%
# Subs

# step find mean
# if
