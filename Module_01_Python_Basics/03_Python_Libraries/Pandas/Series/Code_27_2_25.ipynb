# %%
import pandas as pd
import numpy as np

# %%
vk = pd.read_csv('Data/kohli_ipl.csv',index_col='match_no').squeeze('columns')
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
movie = pd.read_csv('Data/bollywood.csv',index_col='movie').squeeze('columns')
movie
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
new_series = movie.value_counts()
new_series[new_series > 20]
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: count, dtype: int64

# %%
new_series[new_series > 20].plot(kind='bar')
# Out:
# <Axes: xlabel='lead'>

# %%
new_series[new_series > 20].plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
vk[vk >= 50].plot(kind='line')
# Out:
# <Axes: xlabel='match_no'>

# %%
# astype
# between
# clip
# drop_duplicates
# isnull
# dropna
# fillna
# isin
# apply
# copy

# %%
List_1 = ["Java","Python","C++","C"]

S1 = pd.Series(List_1)
S1
# Out:
# 0      Java
# 1    Python
# 2       C++
# 3         C
# dtype: object

# %%
List_2 =  np.random.randint(5,20,6)

S2 = pd.Series(List_2)
S2
# Out:
# 0     8
# 1    17
# 2    16
# 3    18
# 4    11
# 5    10
# dtype: int32

# %%
S2[3] = 17

# %%
S2
# Out:
# 0     8
# 1    17
# 2    16
# 3    17
# 4    11
# 5    10
# dtype: int32

# %%
S2.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 6 entries, 0 to 5
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 6 non-null      int32
# dtypes: int32(1)
# memory usage: 156.0 bytes

# %%
S2.astype('int64').info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 6 entries, 0 to 5
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 6 non-null      int64
# dtypes: int64(1)
# memory usage: 180.0 bytes

# %%
vk[vk.between(50,100)]
# Out:
# match_no
# 15      50
# 34      58
# 41      71
# 44      56
# 45      67
# 52      70
# 57      57
# 68      73
# 71      51
# 73      58
# 74      65
# 80      57
# 81      93
# 82      99
# 85      56
# 97      67
# 99      73
# 103     51
# 104     62
# 110     82
# 116     75
# 117     79
# 119     80
# 120    100
# 122     52
# 127     75
# 129     54
# 131     54
# 132     62
# 134     64
# 137     55
# 141     58
# 144     57
# 145     92
# 148     68
# 152     70
# 160     84
# 162     67
# 164    100
# 175     72
# 178     90
# 182     50
# 188     72
# 197     51
# 198     53
# 209     58
# 213     73
# Name: runs, dtype: int64

# %%
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
vk.clip(50,70)
# Out:
# match_no
# 1      50
# 2      50
# 3      50
# 4      50
# 5      50
#        ..
# 211    50
# 212    50
# 213    70
# 214    50
# 215    50
# Name: runs, Length: 215, dtype: int64

# %%
# drop_duplicates
# isnull
# dropna
# fillna
# isin
# apply
# copy

# %%
S2[S2.duplicated()]
# Out:
# 3    17
# dtype: int32

# %%
S2.duplicated().sum()
# Out:
# 1

# %%
S2.drop_duplicates(inplace=True)

# %%
S2.reset_index(drop=True,inplace=True)

# %%
S2
# Out:
# 0     8
# 1    17
# 2    16
# 3    11
# 4    10
# dtype: int32

# %%
S2[3] = np.nan

# %%
S2
# Out:
# 0     8.0
# 1    17.0
# 2    16.0
# 3     NaN
# 4    10.0
# dtype: float64

# %%
S2.isnull().sum()
# Out:
# 1

# %%
S2.dropna()
# Out:
# 0     8.0
# 1    17.0
# 2    16.0
# 4    10.0
# dtype: float64

# %%
S2.fillna(S2.mean())
# Out:
# 0     8.00
# 1    17.00
# 2    16.00
# 3    12.75
# 4    10.00
# dtype: float64

# %%
S3 = S2.copy()
S3
# Out:
# 0     8.0
# 1    17.0
# 2    16.0
# 3     NaN
# 4    10.0
# dtype: float64

# %%
vk[vk.isin([50,100])]
# Out:
# match_no
# 15      50
# 120    100
# 164    100
# 182     50
# Name: runs, dtype: int64

# %%
# apply


S1.apply(len)
# Out:
# 0    4
# 1    6
# 2    3
# 3    1
# dtype: int64

# %%
S1
# Out:
# 0      Java
# 1    Python
# 2       C++
# 3         C
# dtype: object

# %%
S1.apply(print)
# Out:
# Java
# Python
# C++
# C
# 0    None
# 1    None
# 2    None
# 3    None
# dtype: object

# %%
Subs = pd.read_csv('Data/subs.csv').squeeze('columns')
Subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
S2
# Out:
# 0     8.0
# 1    17.0
# 2    16.0
# 3     NaN
# 4    10.0
# dtype: float64

# %%
flt = lambda x : "Higher" if x >= 10 else "Lower"


S2.apply(flt)
# Out:
# 0     Lower
# 1    Higher
# 2    Higher
# 3     Lower
# 4    Higher
# dtype: object

# %%
Subs.mean()
# Out:
# 135.64383561643837

# %%
Subs.size
# Out:
# 365

# %%
G_B = lambda x : "Good Day" if x > Subs.mean() else "Bad Day"

Subs.apply(G_B).value_counts()
# Out:
# Subscribers gained
# Bad Day     202
# Good Day    163
# Name: count, dtype: int64
