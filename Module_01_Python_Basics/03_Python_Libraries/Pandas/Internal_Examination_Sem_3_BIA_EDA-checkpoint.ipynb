# %% [markdown]
# ### Subject Name: *Exploratory Data Analysis*
# ### Code: BIAMSC13
# ### Time: 90 min
# #### Max marks: 30

# %% [markdown]
# **Instructions**
#
#  - 1) Download the required Packages according to need
#  - 2) Load the Irish Dataset
#  - 3) Rename the file before submission as "EnrollmentNo_Student_Name_BIA_Sem3_EDA"

# %%
# Run this code to add the dataset.
import pandas as pd
df = pd.read_csv("iris_csv.csv ")

# %% [markdown]
# # Code any 15

# %% [markdown]
# ##### 1.Get the information about the data set, check for missing values and check for duplicate values and drop them (2 Marks)

# %%
# Code Here

# %% [markdown]
# ##### Q2.Check for the data set is balanced or not and give your conclusions based on results (2 Marks)

# %%
# Code Here

# %% [markdown]
# **3.Draw the visualization for the target column as per dataset and conclude results  (2 Marks)**

# %%
# Code Here

# %% [markdown]
# **4.Develop the relationship between sepal length and sepal width and conclude the results (2 Marks)**

# %%
# Code Here

# %% [markdown]
# **5.Develop the relationship between petal length and petal width and conclude the results (2 Marks)**

# %%
# Code Here

# %% [markdown]
# **6.plot all the columns relationship using pairplot by using the reference of multivariate analysis and conclude the results (2 Marks)**

# %%
# Code Here

# %% [markdown]
# **7.Demonstrate the visualization as a part of univariate and bivariate analysis using histogram and conclude the results (2 Marks)**

# %%
# Code Here

# %% [markdown]
# **8.Demonstrate the univariate analysis using distplot and conclude the results (2 Marks)**

# %%
# Code Here

# %% [markdown]
# **9.Demonstrate with respect to given data set how do you handle the correlation (2 Marks)**

# %%
# Code Here

# %% [markdown]
# **10.Develop the correlation between all the numerical variables in the dataset and conclude the results (2 Marks)**

# %%
# Code Here

# %% [markdown]
# **11.With the help of visualization ploting show case how categorical values are distributed with other numerical values (2 Marks)**

# %%
# Code Here

# %% [markdown]
# **12.Demonstrate with visualizations how one can handle and remove the outliers and also conclude the results(use sepal width column as reference) (2 Marks)**

# %%
# Code Here

# %% [markdown]
# **13.With example demonstrate how one can convert a column to row name /index in pandas (2 Marks)**

# %%
# Code Here

# %% [markdown]
# **14.Access the element on first row second column (use 2D array with 10 elements) (2 Marks)**

# %%
# Code Here

# %% [markdown]
# **15.Create 1d 2d 3d numpy arrays and check the dimensions for the same (2 Marks)**

# %%
# Code Here

# %% [markdown]
# **16.Draw the pie chart using matplotlib and show case following features  (2 Marks)**
#  -  a.labels
#  -  b.explode
#  -  c.shadow
#  -  d.legend

# %%
# Code Here

# %% [markdown]
# **17.Draw the line chart using matplotlib and show case following features (2 Marks)**
#  - a.keep marker size as 20
#  - b.set the edge color to red
#  - c.set the face color as hotpink
#  - d.keep the line style as dotted

# %%
# Code Here

# %% [markdown]
# # END
