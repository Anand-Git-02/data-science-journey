# %% [markdown]
# ### Rebuilding Pandas Series Methods (Using Pure Python)

# %% [markdown]
# ### Rules
#
# - Do not use Pandas in this worksheet **`except last exercise 11`**
# - Write clean functions with proper naming and return values.
# - Avoid printing inside functions unless the question specifically asks.
# - Handle edge cases where relevant (empty list, n larger than length, etc.).

# %% [markdown]
# #### Exercise 1 — `my_head(data, n=5)`
#
# **Task:** Return the first `n` elements from the list.
#
# **Input**
#
# * `data = [10, 20, 30, 40, 50, 60]`
# * `n = 3`
#
# **Expected Output**
#
# ```
# [10, 20, 30]
# ```

# %% [markdown]
# #### Exercise 2 — `my_tail(data, n=5)`
#
# **Task:** Return the last `n` elements from the list.
#
# **Input**
#
# * `data = [10, 20, 30, 40, 50, 60]`
# * `n = 2`
#
# **Expected Output**
#
# ```
# [50, 60]
# ```

# %% [markdown]
# #### Exercise 3 — `my_value_counts(data)`
#
# **Task:** Count the frequency of each unique value and return a dictionary.
#
# **Input**
#
# * `data = ['a', 'b', 'a', 'c', 'b', 'a']`
#
# **Expected Output**
#
# ```
# {'a': 3, 'b': 2, 'c': 1}
# ```

# %% [markdown]
# #### Exercise 4 — `my_value_counts_sorted(data)`
#
# **Task:** Return counts sorted by frequency (descending).
# Return format: list of tuples `(value, count)`.
#
# **Input**
#
# * `data = ['apple', 'banana', 'apple', 'orange', 'banana', 'apple']`
#
# **Expected Output**
#
# ```
# [('apple', 3), ('banana', 2), ('orange', 1)]
# ```

# %% [markdown]
# #### Exercise 5 — `my_sort_values(data, ascending=True)`
#
# **Task:** Sort values and return a new sorted list.
#
# **Input**
#
# * `data = [45, 12, 89, 33]`
# * `ascending = True`
#
# **Expected Output**
#
# ```
# [12, 33, 45, 89]
# ```
#
# **Input (Case 2)**
#
# * `ascending = False`
#
# **Expected Output (Case 2)**
#
# ```
# [89, 45, 33, 12]
# ```

# %% [markdown]
# #### Exercise 6 — `my_sort_values_with_index(values, index, ascending=True)`
#
# **Task:** Sort by `values` while keeping correct `(index, value)` pairing.
#
# **Input**
#
# * `values = [40, 10, 30, 20]`
# * `index  = ['d', 'a', 'c', 'b']`
# * `ascending = True`
#
# **Expected Output**
#
# ```
# [('a', 10), ('b', 20), ('c', 30), ('d', 40)]
# ```

# %% [markdown]
# #### Exercise 7 — `my_isnull(data)`
#
# **Task:** Return a list of booleans where `True` indicates missing value (`None`).
#
# **Input**
#
# * `data = [10, None, 25, None, 40]`
#
# **Expected Output**
#
# ```
# [False, True, False, True, False]
# ```

# %% [markdown]
# #### Exercise 8 — `my_fillna(data, fill_value)`
#
# **Task:** Replace `None` values with `fill_value` and return the updated list.
#
# **Input**
#
# * `data = [20, None, 30, None, 50]`
# * `fill_value = 0`
#
# **Expected Output**
#
# ```
# [20, 0, 30, 0, 50]
# ```

# %% [markdown]
# #### Exercise 9 — `my_filter(values, operator, threshold)`
#
# **Task:** Return values that satisfy a condition.
# Supported operators: `">"`, `"<"`, `">="`, `"<="`, `"=="`.
#
# **Input**
#
# * `values = [10, 25, 30, 15, 40]`
# * `operator = ">"`, `threshold = 20`
#
# **Expected Output**
#
# ```
# [25, 30, 40]
# ```

# %% [markdown]
# #### Exercise 10 — `my_read_csv_column(csv_text, column_name)`
#
# **Task:** Extract one column from CSV text and return it as a list.
# Assumptions:
#
# * First row is header
# * Comma-separated values
# * No commas inside fields
#
# **Input**
#
# ```
# csv_text = "Name,Marks\nAmit,85\nNeha,92\nRahul,78"
# column_name = "Marks"
# ```
#
# **Expected Output**
#
# ```
# [85, 92, 78]
# ```

# %% [markdown]
# #### EX - 11. Write code to create Series object using the python sequence[4,6,8,10]
# - EX - 2. Write code to create Series object using the python sequence(11,21,31,41)
# - EX - 3. Write code to create Series object using individual character "o","h" and "o"
# - EX - 4. Write code to create Series object using a string : "So funny"
# - EX - 5. Write code to create Series object using three differt words: "I","am","laughing".
