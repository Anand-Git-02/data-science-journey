# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Data/movies.csv')
df
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %% [markdown]
# ### Moives with rating higher than 8 and votes less 1000

# %%
df[(df['imdb_rating'] > 8) & (df['imdb_votes'] < 1000)][['original_title','imdb_rating','imdb_votes']]
# Out:
#                      original_title  imdb_rating  imdb_votes
# 41             Family of Thakurganj          9.4         895
# 207                      G Kutta Se          8.3          45
# 216   YADVI: The Dignified Princess          8.2          28
# 219                       Raag Desh          8.3         341
# 1060                 Blood Brothers          8.2         187
# 1435                 Final Solution          8.7         333
# 1540                  Jang Aur Aman          8.3         113

# %% [markdown]
# ### Action Movies with rating higher than 6.5

# %%
df[(df['genres'] == 'Action') & (df['imdb_rating'] > 6.5)]
# Out:
#              title_x     imdb_id  \
# 367   Gabbar Is Back   tt2424988
# 368   Gabbar Is Back   tt2424988
# 1627           Daaka  tt10833860
#
#                                             poster_path  \
# 367   https://upload.wikimedia.org/wikipedia/en/thum...
# 368   https://upload.wikimedia.org/wikipedia/en/thum...
# 1627  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                          wiki_link         title_y  \
# 367   https://en.wikipedia.org/wiki/Gabbar_Is_Back  Gabbar is Back
# 368   https://en.wikipedia.org/wiki/Gabbar_is_Back  Gabbar is Back
# 1627           https://en.wikipedia.org/wiki/Daaka           Daaka
#
#       original_title  is_adult  year_of_release runtime  genres  imdb_rating  \
# 367   Gabbar is Back         0             2015     128  Action          7.1
# 368   Gabbar is Back         0             2015     128  Action          7.1
# 1627           Daaka         0             2019     136  Action          7.4
#
# ...

# %%
df[(df['genres'].str.contains('Action',case=True)) & (df['imdb_rating'] > 6.5)][['original_title','genres','imdb_rating']]
# Out:
#                   original_title                  genres  imdb_rating
# 0       Uri: The Surgical Strike        Action|Drama|War          8.4
# 14                    Sonchiriya      Action|Crime|Drama          7.5
# 16       Mard Ko Dard Nahin Hota           Action|Comedy          7.4
# 22                        Kesari    Action|Drama|History          7.4
# 38    One Day: Justice Delivered   Action|Crime|Thriller          6.8
# ...                          ...                     ...          ...
# 1554  The Legend of Bhagat Singh  Action|Biography|Drama          8.1
# 1569        Gadar: Ek Prem Katha    Action|Drama|Romance          7.2
# 1575                 Aalavandhan         Action|Thriller          7.1
# 1607        Nayak: The Real Hero   Action|Drama|Thriller          7.8
# 1627                       Daaka                  Action          7.4
#
# [104 rows x 3 columns]

# %%
df['genres'].split
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21280\2120312482.py in ?()
# ----> 1 df['genres'].split
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'split'

# %%
df['genres'].str.split('|')
# Out:
# 0       [Action, Drama, War]
# 1                      [War]
# 2         [Biography, Drama]
# 3             [Crime, Drama]
# 4                    [Drama]
#                 ...
# 1624                 [Drama]
# 1625                 [Drama]
# 1626         [Comedy, Drama]
# 1627                [Action]
# 1628        [Drama, Romance]
# Name: genres, Length: 1629, dtype: object

# %%
'Action' in ['Action','Drama','War']
# Out:
# True

# %%
action_flt = lambda x : "Action" in x

df['genres'].str.split('|').apply(action_flt)
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1624    False
# 1625    False
# 1626    False
# 1627     True
# 1628    False
# Name: genres, Length: 1629, dtype: bool

# %%
df[(df['genres'].str.split('|').apply(action_flt)) & (df['imdb_rating'] > 6.5)]
# Out:
#                          title_x     imdb_id  \
# 0       Uri: The Surgical Strike   tt8291224
# 14                    Sonchiriya   tt8108200
# 16        Mard Ko Dard Nahi Hota   tt8055888
# 22                 Kesari (film)   tt6264938
# 38    One Day: Justice Delivered   tt8130558
# ...                          ...         ...
# 1554  The Legend of Bhagat Singh   tt0319736
# 1569        Gadar: Ek Prem Katha   tt0284137
# 1575                 Aalavandhan   tt0294264
# 1607     Nayak (2001 Hindi film)   tt0291376
# 1627                       Daaka  tt10833860
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 14    https://upload.wikimedia.org/wikipedia/en/thum...
# 16    https://upload.wikimedia.org/wikipedia/en/thum...
# 22    https://upload.wikimedia.org/wikipedia/en/thum...
# 38    https://upload.wikimedia.org/wikipedia/en/f/f7...
# ...                                                 ...
# ...

# %%
path = r"C:\Users\Lenovo\Data Science\Classroom\Module_1\Python_Libraries\Pandas\DataFrame\Data\imdb_movie_data_2023.csv"

# %%
pd.read_csv(path,nrows=10,skiprows=[2,3,4],usecols=['Moive Name','Genre','Year'])
# Out:
#                                           Moive Name  \
# 0                             Leave the World Behind
# 1                                       May December
# 2   The Hunger Games: The Ballad of Songbirds & S...
# 3                                           Napoleon
# 4                                        Oppenheimer
# 5                                      Love Actually
# 6                                    Candy Cane Lane
# 7                                           Saltburn
# 8                                             Barbie
# 9              National Lampoon's Christmas Vacation
#
#                           Genre  Year
# 0      Drama, Mystery, Thriller  2023
# 1                 Comedy, Drama  2023
# 2      Action, Adventure, Drama  2023
# 3  Action, Adventure, Biography  2023
# 4     Biography, Drama, History  2023
# 5        Comedy, Drama, Romance  2003
# 6       Comedy, Family, Fantasy  2023
# 7       Comedy, Drama, Thriller  2023
# ...

# %%
pd.read_csv(path,nrows=10,usecols=[1,2,3,4])
# Out:
#                                           Moive Name  Rating     Votes  \
# 0                             Leave the World Behind     6.5   90000.0
# 1                                              Wonka     7.4   24000.0
# 2                                        Poor Things     8.5    6700.0
# 3                         Killers of the Flower Moon     7.8  128000.0
# 4                                       May December     7.0   21000.0
# 5   The Hunger Games: The Ballad of Songbirds & S...     7.1   56000.0
# 6                                           Napoleon     6.6   66000.0
# 7                                        Oppenheimer     8.4  553000.0
# 8                                      Love Actually     7.6  517000.0
# 9                                    Candy Cane Lane     5.6   13000.0
#
#    Meta Score
# 0        67.0
# 1        66.0
# 2        86.0
# 3        89.0
# 4        85.0
# 5        54.0
# 6        64.0
# 7        89.0
# 8        55.0
# 9        47.0

# %%
df = pd.read_csv(path,nrows=10,usecols=[0,1,2,3,4],index_col=['Rating'])
df
# Out:
#         User_Id                                         Moive Name     Votes  \
# Rating
# 6.5           1                             Leave the World Behind   90000.0
# 7.4           2                                              Wonka   24000.0
# 8.5           3                                        Poor Things    6700.0
# 7.8           4                         Killers of the Flower Moon  128000.0
# 7.0           5                                       May December   21000.0
# 7.1           6   The Hunger Games: The Ballad of Songbirds & S...   56000.0
# 6.6           7                                           Napoleon   66000.0
# 8.4           8                                        Oppenheimer  553000.0
# 7.6           9                                      Love Actually  517000.0
# 5.6          10                                    Candy Cane Lane   13000.0
#
#         Meta Score
# Rating
# 6.5           67.0
# 7.4           66.0
# 8.5           86.0
# 7.8           89.0
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#    Rating  User_Id                                         Moive Name  \
# 0     6.5        1                             Leave the World Behind
# 1     7.4        2                                              Wonka
# 2     8.5        3                                        Poor Things
# 3     7.8        4                         Killers of the Flower Moon
# 4     7.0        5                                       May December
# 5     7.1        6   The Hunger Games: The Ballad of Songbirds & S...
# 6     6.6        7                                           Napoleon
# 7     8.4        8                                        Oppenheimer
# 8     7.6        9                                      Love Actually
# 9     5.6       10                                    Candy Cane Lane
#
#       Votes  Meta Score
# 0   90000.0        67.0
# 1   24000.0        66.0
# 2    6700.0        86.0
# 3  128000.0        89.0
# 4   21000.0        85.0
# 5   56000.0        54.0
# ...

# %%
df.iloc[0,2]
# Out:
# ' Leave the World Behind'

# %%
df.loc[0,'Moive Name']
# Out:
# ' Leave the World Behind'

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5]

y = [i**2 for i in x]

plt.plot(x,y,marker='o',linestyle='-',color='b',label='y=x^2')
plt.title('Simple Plot')
plt.xlabel('X - axis')
plt.ylabel('Y - axis')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA, KernelPCA

# Generate random data
X = np.random.rand(20, 2) * 10
y = np.random.randint(0, 2, 20)

# Apply PCA and Kernel PCA
x_pca = PCA(2).fit_transform(X)
x_kpca = KernelPCA(2, kernel='rbf').fit_transform(X)

# Plotting
fig, axes = plt.subplots(1, 3, figsize=(10, 3))
titles = ['Original', 'PCA', 'Kernel PCA']

for ax, data, title in zip(axes, [X, x_pca, x_kpca], titles):
    ax.scatter(data[:, 0], data[:, 1], c=y, cmap='coolwarm')
    ax.set_title(title)

plt.show()

# %%
import numpy as np
import scipy.sparse as sp
import matplotlib.pyplot as plt
from sklearn.decomposition import TruncatedSVD

# Reproducibility
np.random.seed(42)

# Generate sparse random data
X_sparse = sp.random(100, 10, density=0.2, format='csr')

# Apply Truncated SVD
svd = TruncatedSVD(n_components=2)
X_reduced = svd.fit_transform(X_sparse)

# Plotting the reduced dimensions
plt.scatter(X_reduced[:, 0], X_reduced[:, 1],
            color='blue', edgecolors='k', alpha=0.7)

plt.xlabel("Component 1")
plt.ylabel("Component 2")
plt.title("Dimensionality Reduction using Truncated SVD")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Sample data
X = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)
y = np.array([2, 4, 5, 4, 5])

# Create and train the model
model = LinearRegression()
model.fit(X, y)

# Predict using the model
y_pred = model.predict(X)

# Plotting the results
plt.scatter(X, y, color='blue', label='Actual Data')
plt.plot(X, y_pred, color='black', label='Regression Line')

plt.xlabel("X")
plt.ylabel("y")
plt.title("Linear Regression Example")
plt.legend()
plt.show()
