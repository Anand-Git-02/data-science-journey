# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Data/survey_results_public.csv")
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df_schema = pd.read_csv("Data/survey_results_schema.csv")

# %%
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
df.describe()
# Out:
#        Respondent            CompTotal  ConvertedComp  WorkWeekHrs  \
# count    88883.00             55945.00       55823.00     64503.00
# mean     44442.00      551901414118.76      127110.74        42.13
# std      25658.46    73319262253434.70      284152.30        37.29
# min          1.00                 0.00           0.00         1.00
# 25%      22221.50             20000.00       25777.50        40.00
# 50%      44442.00             62000.00       57287.00        40.00
# 75%      66662.50            120000.00      100000.00        44.75
# max      88883.00 10000000000000000.00     2000000.00      4850.00
#
#        CodeRevHrs      Age
# count    49790.00 79210.00
# mean         5.08    30.34
# std          5.51     9.18
# min          0.00     1.00
# 25%          2.00    24.00
# 50%          4.00    29.00
# 75%          6.00    35.00
# max         99.00    99.00

# %%
df['ConvertedComp'].count()
# Out:
# 55823

# %%
df['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df['Hobbyist'].value_counts()
# Out:
# Hobbyist
# Yes    71257
# No     17626
# Name: count, dtype: int64

# %%
df_schema[df_schema['Column'] == 'SocialMedia']['QuestionText']
# Out:
# 61    What social media site do you use the most?
# Name: QuestionText, dtype: object

# %%
df['SocialMedia'].value_counts()
# Out:
# SocialMedia
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# Name: count, dtype: int64

# %%
df['SocialMedia'].value_counts(normalize=True)
# Out:
# SocialMedia
# Reddit                     0.17
# YouTube                    0.16
# WhatsApp                   0.16
# Facebook                   0.16
# Twitter                    0.13
# Instagram                  0.07
# I don't use social media   0.07
# LinkedIn                   0.05
# WeChat 微信                  0.01
# Snapchat                   0.01
# VK ВКонта́кте              0.01
# Weibo 新浪微博                 0.00
# Youku Tudou 优酷             0.00
# Hello                      0.00
# Name: proportion, dtype: float64

# %%
# split
# Apply function
# combine Results

# %%
df['Country'].value_counts()
# Out:
# Country
# United States        20949
# India                 9061
# Germany               5866
# United Kingdom        5737
# Canada                3395
#                      ...
# Tonga                    1
# Timor-Leste              1
# North Korea              1
# Brunei Darussalam        1
# Chad                     1
# Name: count, Length: 179, dtype: int64

# %%
Country_grp = df.groupby(['Country'])
Country_grp

# %%
Country_grp.get_group('United States')
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_25992\640818647.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   Country_grp.get_group('United States')
#        Respondent                      MainBranch Hobbyist  \
# 3               4  I am a developer by profession       No
# 12             13  I am a developer by profession      Yes
# 21             22  I am a developer by profession      Yes
# 22             23  I am a developer by profession      Yes
# 25             26  I am a developer by profession      Yes
# ...           ...                             ...      ...
# 88818       78292                             NaN       No
# 88840       82717                             NaN       No
# 88844       83397                             NaN      Yes
# 88859       85642                             NaN       No
# ...

# %%
filt = df['Country'] == 'United States'
df.loc[filt]
# Out:
#        Respondent                      MainBranch Hobbyist  \
# 3               4  I am a developer by profession       No
# 12             13  I am a developer by profession      Yes
# 21             22  I am a developer by profession      Yes
# 22             23  I am a developer by profession      Yes
# 25             26  I am a developer by profession      Yes
# ...           ...                             ...      ...
# 88818       78292                             NaN       No
# 88840       82717                             NaN       No
# 88844       83397                             NaN      Yes
# 88859       85642                             NaN       No
# 88877       88282                             NaN      Yes
#
#                                              OpenSourcer  \
# 3                                                  Never
# 12     Less than once a month but more than once per ...
# 21                               Less than once per year
# ...

# %%
filt = df['Country'] == 'United States'
df.loc[filt]['SocialMedia'].value_counts()
# Out:
# SocialMedia
# Reddit                      5700
# Twitter                     3468
# Facebook                    2844
# YouTube                     2463
# I don't use social media    1851
# Instagram                   1652
# LinkedIn                    1020
# WhatsApp                     609
# Snapchat                     326
# WeChat 微信                     93
# VK ВКонта́кте                  9
# Weibo 新浪微博                     8
# Hello                          2
# Youku Tudou 优酷                 1
# Name: count, dtype: int64

# %%
filt = df['Country'] == 'India'
df.loc[filt]['SocialMedia'].value_counts()
# Out:
# SocialMedia
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# Hello                          5
# WeChat 微信                      5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: count, dtype: int64

# %%
Country_grp['SocialMedia'].value_counts().head(50)
# Out:
# Country              SocialMedia
# Afghanistan          Facebook                     15
#                      YouTube                       9
#                      I don't use social media      6
#                      WhatsApp                      4
#                      Instagram                     1
#                      LinkedIn                      1
#                      Twitter                       1
# Albania              WhatsApp                     18
#                      Facebook                     16
#                      Instagram                    13
#                      YouTube                      10
#                      Twitter                       8
#                      LinkedIn                      7
#                      Reddit                        6
#                      I don't use social media      4
#                      Snapchat                      1
#                      WeChat 微信                     1
# ...

# %%
Country_grp['SocialMedia'].value_counts().loc['India']
# Out:
# SocialMedia
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# Hello                          5
# WeChat 微信                      5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
Country_grp['ConvertedComp'].median()
# Out:
# Country
# Afghanistan                              6222.00
# Albania                                 10818.00
# Algeria                                  7878.00
# Andorra                                160931.00
# Angola                                   7764.00
#                                           ...
# Venezuela, Bolivarian Republic of...     6384.00
# Viet Nam                                11892.00
# Yemen                                   11940.00
# Zambia                                   5040.00
# Zimbabwe                                19200.00
# Name: ConvertedComp, Length: 179, dtype: float64

# %%
Country_grp['ConvertedComp'].median().loc['India']
# Out:
# 10080.0

# %%
# count , mean , median , std , sum

# %%
Country_grp['ConvertedComp'].agg(['median','mean'])
# Out:
#                                         median      mean
# Country
# Afghanistan                            6222.00 101953.33
# Albania                               10818.00  21833.70
# Algeria                                7878.00  34924.05
# Andorra                              160931.00 160931.00
# Angola                                 7764.00   7764.00
# ...                                        ...       ...
# Venezuela, Bolivarian Republic of...   6384.00  14581.63
# Viet Nam                              11892.00  17233.44
# Yemen                                 11940.00  16909.17
# Zambia                                 5040.00  10075.38
# Zimbabwe                              19200.00  34046.67
#
# [179 rows x 2 columns]

# %%
Country_grp['ConvertedComp'].agg(['median','mean']).loc['India']
# Out:
# median   10080.00
# mean     28057.66
# Name: India, dtype: float64

# %%
filt = df['Country'] == 'India'

df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 3105

# %%
Country_grp['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 Country_grp['LanguageWorkedWith'].str.contains('Python').sum()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\groupby\groupby.py:1363, in GroupBy.__getattr__(self, attr)
#    1360 if attr in self.obj:
#    1361     return self[attr]
# -> 1363 raise AttributeError(
#    1364     f"'{type(self).__name__}' object has no attribute '{attr}'"
#    1365 )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'str'

# %%
Country_grp['LanguageWorkedWith'].apply(lambda x:x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
# what % of people from each country know Python ?

# %%
filt = df['LanguageWorkedWith'].str.contains('Python',na=False)
df.loc[filt]['Country'].value_counts(normalize=True).head(50)
# Out:
# Country
# United States        0.28
# India                0.09
# Germany              0.07
# United Kingdom       0.07
# Canada               0.04
# France               0.03
# Australia            0.02
# Netherlands          0.02
# Brazil               0.02
# Poland               0.02
# Russian Federation   0.02
# Spain                0.02
# Italy                0.02
# Sweden               0.01
# Switzerland          0.01
# Israel               0.01
# Turkey               0.01
# Austria              0.01
# China                0.01
# Belgium              0.01
# Czech Republic       0.01
# Iran                 0.01
# Finland              0.01
# Romania              0.01
# Pakistan             0.01
# Ukraine              0.01
# Denmark              0.01
# Mexico               0.01
# New Zealand          0.01
# Norway               0.01
# Greece               0.01
# Ireland              0.01
# Bangladesh           0.01
# South Africa         0.01
# Hungary              0.01
# ...

# %%
country_respondents = df['Country'].value_counts()
country_respondents
# Out:
# Country
# United States        20949
# India                 9061
# Germany               5866
# United Kingdom        5737
# Canada                3395
#                      ...
# Tonga                    1
# Timor-Leste              1
# North Korea              1
# Brunei Darussalam        1
# Chad                     1
# Name: count, Length: 179, dtype: int64

# %%
country_uses_python = Country_grp['LanguageWorkedWith'].apply(lambda x:x.str.contains('Python').sum())

country_uses_python
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
python_df = pd.concat([country_respondents,country_uses_python],axis='columns',sort=False)
python_df
# Out:
#                    count  LanguageWorkedWith
# Country
# United States      20949               10083
# India               9061                3105
# Germany             5866                2451
# United Kingdom      5737                2384
# Canada              3395                1558
# ...                  ...                 ...
# Tonga                  1                   0
# Timor-Leste            1                   1
# North Korea            1                   0
# Brunei Darussalam      1                   0
# Chad                   1                   0
#
# [179 rows x 2 columns]

# %%
python_df.columns = ["NumRespodents","NumKnowsPython"]

# %%
python_df
# Out:
#                    NumRespodents  NumKnowsPython
# Country
# United States              20949           10083
# India                       9061            3105
# Germany                     5866            2451
# United Kingdom              5737            2384
# Canada                      3395            1558
# ...                          ...             ...
# Tonga                          1               0
# Timor-Leste                    1               1
# North Korea                    1               0
# Brunei Darussalam              1               0
# Chad                           1               0
#
# [179 rows x 2 columns]

# %%
python_df['PctKnowsPython'] = python_df['NumKnowsPython']/python_df['NumRespodents'] * 100
python_df
# Out:
#                    NumRespodents  NumKnowsPython  PctKnowsPython
# Country
# United States              20949           10083           48.13
# India                       9061            3105           34.27
# Germany                     5866            2451           41.78
# United Kingdom              5737            2384           41.55
# Canada                      3395            1558           45.89
# ...                          ...             ...             ...
# Tonga                          1               0            0.00
# Timor-Leste                    1               1          100.00
# North Korea                    1               0            0.00
# Brunei Darussalam              1               0            0.00
# Chad                           1               0            0.00
#
# [179 rows x 3 columns]

# %%
python_df.sort_values(by='PctKnowsPython',ascending=False,inplace=True)

# %%
python_df.head(50)
# Out:
#                                   NumRespodents  NumKnowsPython  \
# Country
# Sao Tome and Principe                         1               1
# Timor-Leste                                   1               1
# Dominica                                      1               1
# Niger                                         1               1
# Turkmenistan                                  7               6
# Mauritania                                    7               5
# Guinea                                        3               2
# Bahamas                                       3               2
# Guyana                                        3               2
# Uganda                                       72              47
# Iceland                                      49              30
# Haiti                                         5               3
# Benin                                         5               3
# ...

# %%
python_df.loc['India']
# Out:
# NumRespodents    9061.00
# NumKnowsPython   3105.00
# PctKnowsPython     34.27
# Name: India, dtype: float64
