# %% [markdown]
# ### 1. **Top 3 Cities by Revenue**
# ```
# Shipping_City
# Bangalore     ₹38850
# Mumbai        ₹30400
# Hyderabad     ₹14400
# ```

# %% [markdown]
# ### 2. **Top 3 States by Number of Orders**
# ```
# Maharashtra    4
# Karnataka      3
# Telangana      2
# ```

# %% [markdown]
# ### 3. **Monthly Sales Volume (March 2025)**
# ```
# 2025-03-31    27
# ```
#
# ### 4. **Average Shipping Time per Product**
# ```
# Dining Table            4.0 days
# Smartphone              4.0 days
# Office Chair            3.0 days
# Air Conditioner         2.5 days
# Smartwatch              2.0 days
# LED Monitor             2.0 days
# Laptop                  2.0 days
# Bluetooth Speaker       1.5 days
# Wireless Mouse          1.0 days
# Water Bottle            1.0 days
# ```
#
# ### 5. **Daily Revenue**
# Each date and total revenue:
# ```
# 2025-03-01    ₹19800
# 2025-03-02    ₹18200
# 2025-03-03    ₹14800
# 2025-03-04    ₹15000
# 2025-03-05    ₹10400
# 2025-03-06    ₹11800
# 2025-03-07    ₹15400
# 2025-03-08    ₹18650
# ```
#
# ### 6. **Products by Total Revenue**
# ```
# Laptop                ₹32000
# Smartphone            ₹19800
# Air Conditioner       ₹16800
# Office Chair          ₹15000
# Dining Table          ₹14400
# Smartwatch            ₹10400
# LED Monitor            ₹9900
# Bluetooth Speaker      ₹9600
# Wireless Mouse         ₹2600
# Water Bottle           ₹2400
# ```
#
# ### 7. **Most Ordered Product per State**
# ```
# Karnataka       Smartphone (5 units)
# Maharashtra     Laptop (4 units)
# Rajasthan       Office Chair (4 units)
# Tamil Nadu      LED Monitor (3 units)
# Telangana       Dining Table (3 units)
# ```
#
# ### 8. **Products Ordered More than Once in One Order**
# ```
# Smartphone            1
# Smartwatch            1
# Dining Table          1
# LED Monitor           1
# Office Chair          1
# Wireless Mouse        1
# Bluetooth Speaker     1
# ```
#
# ### 9. **Orders with Revenue > ₹20000**
# ```
# O1001   Alice Johnson       ₹19800
# O1003   Charlie Brown       ₹32000
# O1008   Henry Thomas        ₹24000
# ```
#
# ### 10. **Cumulative Revenue Over Time**
# ```
# Starts from ₹19800 and ends at ₹114050 across all dates.
# ```
#
# ### 11. **Average Unit Price per Product**
# ```
# Air Conditioner       ₹8400.00
# Bluetooth Speaker     ₹3200.00
# Dining Table          ₹4800.00
# LED Monitor           ₹3300.00
# Laptop                ₹8000.00
# Office Chair          ₹3750.00
# Smartphone            ₹6600.00
# Smartwatch            ₹5200.00
# Water Bottle          ₹600.00
# Wireless Mouse        ₹1300.00
# ```
#
# ### 12. **Orders with Longest Shipping Duration**
# ```
# O1004 – Shipping Days: 5 (Dining Table)
# ```
#
# ### 13. **Total Quantity Sold per Product**
# ```
# Smartphone           5
# Smartwatch           2
# Laptop               4
# Bluetooth Speaker    3
# Dining Table         3
# LED Monitor          3
# Office Chair         4
# Water Bottle         4
# Wireless Mouse       2
# Air Conditioner      2
# ```
#
# ### 14. **Daily Average Revenue**
# Each date's average revenue:
# ```
# ₹19800, ₹9100, ₹32000, ₹14400, ₹10400, ₹5900, ₹7700, ₹12000 (varies)
# ```
#
# ### 15. **Customers with Total Revenue > ₹20000**
# ```
# Charlie Brown    ₹32000
# Henry Thomas     ₹24000
# Alice Johnson    ₹19800
# ```
#
# ### 16. **Products Sold in Only One State**
# ```
# None – All products were sold in multiple states.
# ```
#
# ### 17. **Unique Customers per State**
# ```
# Maharashtra    4
# Karnataka      3
# Telangana      2
# Tamil Nadu     1
# Rajasthan      1
# ```
#
# ### 18. **Days with > 3 Orders**
# ```
# None – Max orders per day is 2.
# ```
#
# ### 19. **Average Revenue per Product**
# ```
# Laptop              ₹16000.0
# Smartphone           ₹9900.0
# Air Conditioner      ₹8400.0
# Office Chair         ₹7500.0
# Dining Table         ₹7200.0
# Smartwatch           ₹5200.0
# LED Monitor          ₹4950.0
# Bluetooth Speaker    ₹4800.0
# Wireless Mouse       ₹1300.0
# Water Bottle         ₹1200.0
# ```
#
# ### 20. **States with Avg Quantity > 2**
# ```
# Rajasthan       4.0
# Telangana       3.0
# Tamil Nadu      3.0
# Maharashtra     2.5
# ```
