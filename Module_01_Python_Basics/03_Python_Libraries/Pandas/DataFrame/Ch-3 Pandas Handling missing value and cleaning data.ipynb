# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Data/Movies_clean.csv')
df
# Out:
#           USER_ID  MOVIE_ID    MOVIE_TITLE PRODUCTION_YEAR       GENRES  \
# 0             101     201.0      Inception            2010       Sci-Fi
# 1             102     202.0        Titanic            1997      Romance
# 2             103     203.0         Avatar            2009       Action
# 3             104     204.0  The Godfather            1972        Crime
# 4             105     205.0            NaN            1994          NaN
# 5             NaN     206.0          Joker   not available     Thriller
# 6             107       NaN      Gladiator             NaN        Drama
# 7   not available     208.0      not value            2019  not mension
# 8             109     209.0   Interstellar            2014       Sci-Fi
# 9             110       NaN            NaN            2009          NaN
# 10            NaN     211.0         Frozen             NaN       Comedy
# 11            112     213.0         Matrix             NaN       Action
# ...

# %% [markdown]
# # na_values concept / na_values for fixed key

# %%
pd.read_csv('Data/Movies_clean.csv')
# Out:
#           USER_ID  MOVIE_ID    MOVIE_TITLE PRODUCTION_YEAR       GENRES  \
# 0             101     201.0      Inception            2010       Sci-Fi
# 1             102     202.0        Titanic            1997      Romance
# 2             103     203.0         Avatar            2009       Action
# 3             104     204.0  The Godfather            1972        Crime
# 4             105     205.0            NaN            1994          NaN
# 5             NaN     206.0          Joker   not available     Thriller
# 6             107       NaN      Gladiator             NaN        Drama
# 7   not available     208.0      not value            2019  not mension
# 8             109     209.0   Interstellar            2014       Sci-Fi
# 9             110       NaN            NaN            2009          NaN
# 10            NaN     211.0         Frozen             NaN       Comedy
# 11            112     213.0         Matrix             NaN       Action
# ...

# %%
df = pd.read_csv('Data/Movies_clean.csv',na_values = ['not available','not value','not mension'])
df
# Out:
#     USER_ID  MOVIE_ID    MOVIE_TITLE  PRODUCTION_YEAR    GENRES  RATING
# 0     101.0     201.0      Inception           2010.0    Sci-Fi     8.8
# 1     102.0     202.0        Titanic           1997.0   Romance     7.8
# 2     103.0     203.0         Avatar           2009.0    Action     NaN
# 3     104.0     204.0  The Godfather           1972.0     Crime     9.2
# 4     105.0     205.0            NaN           1994.0       NaN     8.5
# 5       NaN     206.0          Joker              NaN  Thriller     8.7
# 6     107.0       NaN      Gladiator              NaN     Drama     NaN
# 7       NaN     208.0            NaN           2019.0       NaN     9.0
# 8     109.0     209.0   Interstellar           2014.0    Sci-Fi     NaN
# 9     110.0       NaN            NaN           2009.0       NaN     8.2
# 10      NaN     211.0         Frozen              NaN    Comedy     NaN
# 11    112.0     213.0         Matrix              NaN    Action     7.9
# ...

# %%
df = pd.read_csv('Data/Movieratingdata1.csv',na_values = {"PRODUCTION_YEAR":"not available","GENRES":"not mension"})
df
# Out:
#     USER_ID   MOVIE_ID    MOVIE_TITLE PRODUCTION_YEAR  \
# 0         1    4642044          Riot             2015
# 1         2        NaN            NaN             NaN
# 2         3  not value            NaN            2014
# 3         4    1390411            NaN            2015
# 4         5    6306064            NaN             NaN
# 5         6    6306064            NaN     not mension
# 6         7    2719848            NaN            2015
# 7         8     462504            NaN            2006
# 8         9        NaN            NaN            2020
# 9        10     163225  The Revenant             2015
# 10       11    1663202            NaN            2015
# 11       12    1663202  The Revenant             2021
#
#                                                GENRES         RATING
# 0                                              Action            NaN
# 1                                                 NaN            NaN
# ...

# %% [markdown]
# # keep_default_na value to default setting

# %%
df = pd.read_csv('Data/Movies_clean.csv',keep_default_na=True)
df
# Out:
#           USER_ID  MOVIE_ID    MOVIE_TITLE PRODUCTION_YEAR       GENRES  \
# 0             101     201.0      Inception            2010       Sci-Fi
# 1             102     202.0        Titanic            1997      Romance
# 2             103     203.0         Avatar            2009       Action
# 3             104     204.0  The Godfather            1972        Crime
# 4             105     205.0            NaN            1994          NaN
# 5             NaN     206.0          Joker   not available     Thriller
# 6             107       NaN      Gladiator             NaN        Drama
# 7   not available     208.0      not value            2019  not mension
# 8             109     209.0   Interstellar            2014       Sci-Fi
# 9             110       NaN            NaN            2009          NaN
# 10            NaN     211.0         Frozen             NaN       Comedy
# 11            112     213.0         Matrix             NaN       Action
# ...

# %% [markdown]
# # Replace method and np.nan

# %%
df.dtypes
# Out:
# USER_ID             object
# MOVIE_ID           float64
# MOVIE_TITLE         object
# PRODUCTION_YEAR     object
# GENRES              object
# RATING              object
# dtype: object

# %%
pd.read_csv("Data/Movies_clean.csv")
# Out:
#           USER_ID  MOVIE_ID    MOVIE_TITLE PRODUCTION_YEAR       GENRES  \
# 0             101     201.0      Inception            2010       Sci-Fi
# 1             102     202.0        Titanic            1997      Romance
# 2             103     203.0         Avatar            2009       Action
# 3             104     204.0  The Godfather            1972        Crime
# 4             105     205.0            NaN            1994          NaN
# 5             NaN     206.0          Joker   not available     Thriller
# 6             107       NaN      Gladiator             NaN        Drama
# 7   not available     208.0      not value            2019  not mension
# 8             109     209.0   Interstellar            2014       Sci-Fi
# 9             110       NaN            NaN            2009          NaN
# 10            NaN     211.0         Frozen             NaN       Comedy
# 11            112     213.0         Matrix             NaN       Action
# ...

# %%
df.replace(to_replace='not available',value=None,inplace=True)

# %%
df
# Out:
#    USER_ID  MOVIE_ID    MOVIE_TITLE PRODUCTION_YEAR       GENRES RATING
# 0      101     201.0      Inception            2010       Sci-Fi    8.8
# 1      102     202.0        Titanic            1997      Romance    7.8
# 2      103     203.0         Avatar            2009       Action    NaN
# 3      104     204.0  The Godfather            1972        Crime    9.2
# 4      105     205.0            NaN            1994          NaN    8.5
# 5      NaN     206.0          Joker            None     Thriller    8.7
# 6      107       NaN      Gladiator             NaN        Drama   None
# 7     None     208.0      not value            2019  not mension    9.0
# 8      109     209.0   Interstellar            2014       Sci-Fi    NaN
# 9      110       NaN            NaN            2009          NaN    8.2
# 10     NaN     211.0         Frozen             NaN       Comedy    NaN
# 11     112     213.0         Matrix             NaN       Action    7.9
# ...

# %%
df.replace('not mension',np.nan,inplace=True)

# %%
df
# Out:
#    USER_ID  MOVIE_ID    MOVIE_TITLE PRODUCTION_YEAR    GENRES RATING
# 0      101     201.0      Inception            2010    Sci-Fi    8.8
# 1      102     202.0        Titanic            1997   Romance    7.8
# 2      103     203.0         Avatar            2009    Action    NaN
# 3      104     204.0  The Godfather            1972     Crime    9.2
# 4      105     205.0            NaN            1994       NaN    8.5
# 5      NaN     206.0          Joker            None  Thriller    8.7
# 6      107       NaN      Gladiator             NaN     Drama   None
# 7     None     208.0      not value            2019       NaN    9.0
# 8      109     209.0   Interstellar            2014    Sci-Fi    NaN
# 9      110       NaN            NaN            2009       NaN    8.2
# 10     NaN     211.0         Frozen             NaN    Comedy    NaN
# 11     112     213.0         Matrix             NaN    Action    7.9
# 12     NaN       NaN            NaN            2003       NaN    NaN

# %% [markdown]
# # Replace method with specific value

# %%
df.dtypes
# Out:
# USER_ID             object
# MOVIE_ID           float64
# MOVIE_TITLE         object
# PRODUCTION_YEAR     object
# GENRES              object
# RATING              object
# dtype: object

# %%
df['MOVIE_ID'].values
# Out:
# array([201., 202., 203., 204., 205., 206.,  nan, 208., 209.,  nan, 211.,
#        213.,  nan])

# %%
df.dtypes
# Out:
# USER_ID            object
# MOVIE_ID           object
# MOVIE_TITLE        object
# PRODUCTION_YEAR    object
# GENRES             object
# RATING             object
# dtype: object

# %%
df.dtypes
# Out:
# USER_ID            object
# MOVIE_ID           object
# MOVIE_TITLE        object
# PRODUCTION_YEAR    object
# GENRES             object
# RATING             object
# dtype: object

# %%
df['USER_ID'].values
# Out:
# array(['101', '102', '103', '104', '105', nan, '107', None, '109', '110',
#        nan, '112', nan], dtype=object)

# %%
df.replace('104',12,inplace=True)
df
# Out:
#    USER_ID MOVIE_ID    MOVIE_TITLE PRODUCTION_YEAR    GENRES RATING
# 0      101   batman      Inception            2010    Sci-Fi    8.8
# 1      102    202.0        Titanic            1997   Romance    7.8
# 2      103    203.0         Avatar            2009    Action    NaN
# 3       12    204.0  The Godfather            1972     Crime    9.2
# 4      105    205.0            NaN            1994       NaN    8.5
# 5      NaN    206.0          Joker            None  Thriller    8.7
# 6      107      NaN      Gladiator             NaN     Drama   None
# 7     None    208.0      not value            2019       NaN    9.0
# 8      109    209.0   Interstellar            2014    Sci-Fi    NaN
# 9      110      NaN            NaN            2009       NaN    8.2
# 10     NaN    211.0         Frozen             NaN    Comedy    NaN
# 11     112    213.0         Matrix             NaN    Action    7.9
# 12     NaN      NaN            NaN            2003       NaN    NaN

# %%
df['USER_ID'].values
# Out:
# array(['101', '102', '103', 12, '105', nan, '107', None, '109', '110',
#        nan, '112', nan], dtype=object)

# %%
df.replace(['101', '102', '103'],[1,1,1],inplace=True)
df
# Out:
#    USER_ID MOVIE_ID    MOVIE_TITLE PRODUCTION_YEAR    GENRES RATING
# 0        1   batman      Inception            2010    Sci-Fi    8.8
# 1        1    202.0        Titanic            1997   Romance    7.8
# 2        1    203.0         Avatar            2009    Action    NaN
# 3       12    204.0  The Godfather            1972     Crime    9.2
# 4      105    205.0            NaN            1994       NaN    8.5
# 5      NaN    206.0          Joker            None  Thriller    8.7
# 6      107      NaN      Gladiator             NaN     Drama   None
# 7     None    208.0      not value            2019       NaN    9.0
# 8      109    209.0   Interstellar            2014    Sci-Fi    NaN
# 9      110      NaN            NaN            2009       NaN    8.2
# 10     NaN    211.0         Frozen             NaN    Comedy    NaN
# 11     112    213.0         Matrix             NaN    Action    7.9
# 12     NaN      NaN            NaN            2003       NaN    NaN

# %%
df.dtypes
# Out:
# USER_ID            object
# MOVIE_ID           object
# MOVIE_TITLE        object
# PRODUCTION_YEAR    object
# GENRES             object
# RATING             object
# dtype: object

# %%
df.replace(213.0,'batman',inplace=True)
df
# Out:
#    USER_ID MOVIE_ID    MOVIE_TITLE PRODUCTION_YEAR    GENRES RATING
# 0        1   batman      Inception            2010    Sci-Fi    8.8
# 1        1    202.0        Titanic            1997   Romance    7.8
# 2        1    203.0         Avatar            2009    Action    NaN
# 3       12    204.0  The Godfather            1972     Crime    9.2
# 4      105    205.0            NaN            1994       NaN    8.5
# 5      NaN    206.0          Joker            None  Thriller    8.7
# 6      107      NaN      Gladiator             NaN     Drama   None
# 7     None    208.0      not value            2019       NaN    9.0
# 8      109    209.0   Interstellar            2014    Sci-Fi    NaN
# 9      110      NaN            NaN            2009       NaN    8.2
# 10     NaN    211.0         Frozen             NaN    Comedy    NaN
# 11     112   batman         Matrix             NaN    Action    7.9
# 12     NaN      NaN            NaN            2003       NaN    NaN

# %%
df.replace({"MOVIE_ID":"batman"},208.0,inplace=True)
df
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_7320\3124307013.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace({"MOVIE_ID":"batman"},208.0,inplace=True)
#    USER_ID  MOVIE_ID    MOVIE_TITLE PRODUCTION_YEAR    GENRES RATING
# 0        1     208.0      Inception            2010    Sci-Fi    8.8
# 1        1     202.0        Titanic            1997   Romance    7.8
# 2        1     203.0         Avatar            2009    Action    NaN
# 3       12     204.0  The Godfather            1972     Crime    9.2
# 4      105     205.0            NaN            1994       NaN    8.5
# 5      NaN     206.0          Joker            None  Thriller    8.7
# 6      107       NaN      Gladiator             NaN     Drama   None
# ...

# %% [markdown]
# # isnull() and sum()

# %%
df = pd.read_csv('Data/Movies_clean.csv')
df
# Out:
#           USER_ID  MOVIE_ID    MOVIE_TITLE PRODUCTION_YEAR       GENRES  \
# 0             101     201.0      Inception            2010       Sci-Fi
# 1             102     202.0        Titanic            1997      Romance
# 2             103     203.0         Avatar            2009       Action
# 3             104     204.0  The Godfather            1972        Crime
# 4             105     205.0            NaN            1994          NaN
# 5             NaN     206.0          Joker   not available     Thriller
# 6             107       NaN      Gladiator             NaN        Drama
# 7   not available     208.0      not value            2019  not mension
# 8             109     209.0   Interstellar            2014       Sci-Fi
# 9             110       NaN            NaN            2009          NaN
# 10            NaN     211.0         Frozen             NaN       Comedy
# 11            112     213.0         Matrix             NaN       Action
# ...

# %%
df.isnull()     # find empty cells
# Out:
#     USER_ID  MOVIE_ID  MOVIE_TITLE  PRODUCTION_YEAR  GENRES  RATING
# 0     False     False        False            False   False   False
# 1     False     False        False            False   False   False
# 2     False     False        False            False   False    True
# 3     False     False        False            False   False   False
# 4     False     False         True            False    True   False
# 5      True     False        False            False   False   False
# 6     False      True        False             True   False   False
# 7     False     False        False            False   False   False
# 8     False     False        False            False   False    True
# 9     False      True         True            False    True   False
# 10     True     False        False             True   False    True
# 11    False     False        False             True   False   False
# 12     True      True         True            False    True    True

# %%
df.isnull().sum()
# Out:
# USER_ID            3
# MOVIE_ID           3
# MOVIE_TITLE        3
# PRODUCTION_YEAR    3
# GENRES             3
# RATING             4
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 19

# %%
df.shape[0]
# Out:
# 13

# %%
# 20 - 15 ==> fill - number --> mean,median
# 20 < --> drop

# %%
df.isnull().sum()*100/(df.shape[0])
# Out:
# USER_ID            23.076923
# MOVIE_ID           23.076923
# MOVIE_TITLE        23.076923
# PRODUCTION_YEAR    23.076923
# GENRES             23.076923
# RATING             30.769231
# dtype: float64

# %% [markdown]
# # notnull() and sum()

# %%
df
# Out:
#           USER_ID  MOVIE_ID    MOVIE_TITLE PRODUCTION_YEAR       GENRES  \
# 0             101     201.0      Inception            2010       Sci-Fi
# 1             102     202.0        Titanic            1997      Romance
# 2             103     203.0         Avatar            2009       Action
# 3             104     204.0  The Godfather            1972        Crime
# 4             105     205.0            NaN            1994          NaN
# 5             NaN     206.0          Joker   not available     Thriller
# 6             107       NaN      Gladiator             NaN        Drama
# 7   not available     208.0      not value            2019  not mension
# 8             109     209.0   Interstellar            2014       Sci-Fi
# 9             110       NaN            NaN            2009          NaN
# 10            NaN     211.0         Frozen             NaN       Comedy
# 11            112     213.0         Matrix             NaN       Action
# ...

# %%
df.shape
# Out:
# (13, 6)

# %%
df.notnull()       # find non empty cells
# Out:
#     USER_ID  MOVIE_ID  MOVIE_TITLE  PRODUCTION_YEAR  GENRES  RATING
# 0      True      True         True             True    True    True
# 1      True      True         True             True    True    True
# 2      True      True         True             True    True   False
# 3      True      True         True             True    True    True
# 4      True      True        False             True   False    True
# 5     False      True         True             True    True    True
# 6      True     False         True            False    True    True
# 7      True      True         True             True    True    True
# 8      True      True         True             True    True   False
# 9      True     False        False             True   False    True
# 10    False      True         True            False    True   False
# 11     True      True         True            False    True    True
# 12    False     False        False             True   False   False

# %%
df.notnull().sum()
# Out:
# USER_ID            10
# MOVIE_ID           10
# MOVIE_TITLE        10
# PRODUCTION_YEAR    10
# GENRES             10
# RATING              9
# dtype: int64

# %%
df.notnull().sum().sum()
# Out:
# 59

# %% [markdown]
# # dropna and all inside function

# %%
df = pd.read_csv('Data/Movies_clean.csv')
df
# Out:
#           USER_ID  MOVIE_ID    MOVIE_TITLE PRODUCTION_YEAR       GENRES  \
# 0             101     201.0      Inception            2010       Sci-Fi
# 1             102     202.0        Titanic            1997      Romance
# 2             103     203.0         Avatar            2009       Action
# 3             104     204.0  The Godfather            1972        Crime
# 4             105     205.0            NaN            1994          NaN
# 5             NaN     206.0          Joker   not available     Thriller
# 6             107       NaN      Gladiator             NaN        Drama
# 7   not available     208.0      not value            2019  not mension
# 8             109     209.0   Interstellar            2014       Sci-Fi
# 9             110       NaN            NaN            2009          NaN
# 10            NaN     211.0         Frozen             NaN       Comedy
# 11            112     213.0         Matrix             NaN       Action
# ...

# %%
df.dropna()     # by default how = any
# Out:
#          USER_ID  MOVIE_ID    MOVIE_TITLE PRODUCTION_YEAR       GENRES RATING
# 0            101     201.0      Inception            2010       Sci-Fi    8.8
# 1            102     202.0        Titanic            1997      Romance    7.8
# 3            104     204.0  The Godfather            1972        Crime    9.2
# 7  not available     208.0      not value            2019  not mension    9.0

# %%
df_clean['MOVIE_TITLE'].values
# Out:
# array(['Inception', 'Titanic', 'The Godfather', 'not value'], dtype=object)

# %%
df_clean  = df.dropna()
df_clean.replace(['not available','not mension','not value'],np.nan,inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_14524\2951374895.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean.replace(['not available','not mension','not value'],np.nan,inplace=True)

# %%
# axis = 0 , axis = 1
df_clean
# Out:
#   USER_ID  MOVIE_ID    MOVIE_TITLE PRODUCTION_YEAR   GENRES RATING
# 0     101     201.0      Inception            2010   Sci-Fi    8.8
# 1     102     202.0        Titanic            1997  Romance    7.8
# 3     104     204.0  The Godfather            1972    Crime    9.2
# 7     NaN     208.0            NaN            2019      NaN    9.0

# %%
df_clean.dropna(how='any')      # if raw any one value is nan then it will drop
# Out:
#   USER_ID  MOVIE_ID    MOVIE_TITLE PRODUCTION_YEAR   GENRES RATING
# 0     101     201.0      Inception            2010   Sci-Fi    8.8
# 1     102     202.0        Titanic            1997  Romance    7.8
# 3     104     204.0  The Godfather            1972    Crime    9.2

# %%
df_clean.loc[7,['MOVIE_ID','PRODUCTION_YEAR','RATING']] = np.nan

# %%
df_clean.dropna(how='all')
# Out:
#   USER_ID  MOVIE_ID    MOVIE_TITLE PRODUCTION_YEAR   GENRES RATING
# 0     101     201.0      Inception            2010   Sci-Fi    8.8
# 1     102     202.0        Titanic            1997  Romance    7.8
# 3     104     204.0  The Godfather            1972    Crime    9.2

# %%
df.isna().sum()
# Out:
# USER_ID            3
# MOVIE_ID           3
# MOVIE_TITLE        3
# PRODUCTION_YEAR    3
# GENRES             3
# RATING             4
# dtype: int64

# %%
df.notnull().sum()
# Out:
# USER_ID            10
# MOVIE_ID           10
# MOVIE_TITLE        10
# PRODUCTION_YEAR    10
# GENRES             10
# RATING              9
# dtype: int64

# %%
df
# Out:
#           USER_ID  MOVIE_ID    MOVIE_TITLE PRODUCTION_YEAR       GENRES  \
# 0             101     201.0      Inception            2010       Sci-Fi
# 1             102     202.0        Titanic            1997      Romance
# 2             103     203.0         Avatar            2009       Action
# 3             104     204.0  The Godfather            1972        Crime
# 4             105     205.0            NaN            1994          NaN
# 5             NaN     206.0          Joker   not available     Thriller
# 6             107       NaN      Gladiator             NaN        Drama
# 7   not available     208.0      not value            2019  not mension
# 8             109     209.0   Interstellar            2014       Sci-Fi
# 9             110       NaN            NaN            2009          NaN
# 10            NaN     211.0         Frozen             NaN       Comedy
# 11            112     213.0         Matrix             NaN       Action
# ...

# %%
df.loc[12,'PRODUCTION_YEAR'] = np.nan

# %%
df.dropna(how='all')     # if raw all value is nan then drop
# Out:
#           USER_ID  MOVIE_ID    MOVIE_TITLE PRODUCTION_YEAR       GENRES  \
# 0             101     201.0      Inception            2010       Sci-Fi
# 1             102     202.0        Titanic            1997      Romance
# 2             103     203.0         Avatar            2009       Action
# 3             104     204.0  The Godfather            1972        Crime
# 4             105     205.0            NaN            1994          NaN
# 5             NaN     206.0          Joker   not available     Thriller
# 6             107       NaN      Gladiator             NaN        Drama
# 7   not available     208.0      not value            2019  not mension
# 8             109     209.0   Interstellar            2014       Sci-Fi
# 9             110       NaN            NaN            2009          NaN
# 10            NaN     211.0         Frozen             NaN       Comedy
# 11            112     213.0         Matrix             NaN       Action
#
#            RATING
# ...

# %%
df = pd.read_csv('Data/Movies_clean.csv')
df
# Out:
#           USER_ID  MOVIE_ID    MOVIE_TITLE PRODUCTION_YEAR       GENRES  \
# 0             101     201.0      Inception            2010       Sci-Fi
# 1             102     202.0        Titanic            1997      Romance
# 2             103     203.0         Avatar            2009       Action
# 3             104     204.0  The Godfather            1972        Crime
# 4             105     205.0            NaN            1994          NaN
# 5             NaN     206.0          Joker   not available     Thriller
# 6             107       NaN      Gladiator             NaN        Drama
# 7   not available     208.0      not value            2019  not mension
# 8             109     209.0   Interstellar            2014       Sci-Fi
# 9             110       NaN            NaN            2009          NaN
# 10            NaN     211.0         Frozen             NaN       Comedy
# 11            112     213.0         Matrix             NaN       Action
# ...

# %%
df.shape
# Out:
# (13, 6)

# %%
df.dropna(axis=0,thresh=2).shape
# Out:
# (12, 6)

# %%
df.dropna(axis=0,thresh=1)  #if one value in raw   thresh=1 
# thresh parameter value desides the minimum number of non-NAN values needed in a "RAW" not to drop.
# Out:
#           USER_ID  MOVIE_ID    MOVIE_TITLE PRODUCTION_YEAR       GENRES  \
# 0             101     201.0      Inception            2010       Sci-Fi
# 1             102     202.0        Titanic            1997      Romance
# 2             103     203.0         Avatar            2009       Action
# 3             104     204.0  The Godfather            1972        Crime
# 4             105     205.0            NaN            1994          NaN
# 5             NaN     206.0          Joker   not available     Thriller
# 6             107       NaN      Gladiator             NaN        Drama
# 7   not available     208.0      not value            2019  not mension
# 8             109     209.0   Interstellar            2014       Sci-Fi
# 9             110       NaN            NaN            2009          NaN
# 10            NaN     211.0         Frozen             NaN       Comedy
# 11            112     213.0         Matrix             NaN       Action
# ...

# %%
# for x in range(0,10):
#     print(df.dropna(axis=0,thresh=x))

# %%
df
# Out:
#           USER_ID  MOVIE_ID    MOVIE_TITLE PRODUCTION_YEAR       GENRES  \
# 0             101     201.0      Inception            2010       Sci-Fi
# 1             102     202.0        Titanic            1997      Romance
# 2             103     203.0         Avatar            2009       Action
# 3             104     204.0  The Godfather            1972        Crime
# 4             105     205.0            NaN            1994          NaN
# 5             NaN     206.0          Joker   not available     Thriller
# 6             107       NaN      Gladiator             NaN        Drama
# 7   not available     208.0      not value            2019  not mension
# 8             109     209.0   Interstellar            2014       Sci-Fi
# 9             110       NaN            NaN            2009          NaN
# 10            NaN     211.0         Frozen             NaN       Comedy
# 11            112     213.0         Matrix             NaN       Action
# ...

# %%
df.dropna(subset=['RATING'])
# Out:
#           USER_ID  MOVIE_ID    MOVIE_TITLE PRODUCTION_YEAR       GENRES  \
# 0             101     201.0      Inception            2010       Sci-Fi
# 1             102     202.0        Titanic            1997      Romance
# 3             104     204.0  The Godfather            1972        Crime
# 4             105     205.0            NaN            1994          NaN
# 5             NaN     206.0          Joker   not available     Thriller
# 6             107       NaN      Gladiator             NaN        Drama
# 7   not available     208.0      not value            2019  not mension
# 9             110       NaN            NaN            2009          NaN
# 11            112     213.0         Matrix             NaN       Action
#
#            RATING
# 0             8.8
# 1             7.8
# 3             9.2
# 4             8.5
# 5             8.7
# 6   not available
# 7             9.0
# 9             8.2
# 11            7.9

# %% [markdown]
# # how to drop column

# %%
df = pd.read_csv('Data/Movies_clean.csv')
df
# Out:
#           USER_ID  MOVIE_ID    MOVIE_TITLE PRODUCTION_YEAR       GENRES  \
# 0             101     201.0      Inception            2010       Sci-Fi
# 1             102     202.0        Titanic            1997      Romance
# 2             103     203.0         Avatar            2009       Action
# 3             104     204.0  The Godfather            1972        Crime
# 4             105     205.0            NaN            1994          NaN
# 5             NaN     206.0          Joker   not available     Thriller
# 6             107       NaN      Gladiator             NaN        Drama
# 7   not available     208.0      not value            2019  not mension
# 8             109     209.0   Interstellar            2014       Sci-Fi
# 9             110       NaN            NaN            2009          NaN
# 10            NaN     211.0         Frozen             NaN       Comedy
# 11            112     213.0         Matrix             NaN       Action
# ...

# %%
df.drop(columns='MOVIE_TITLE',inplace=True)
df
# Out:
#           USER_ID  MOVIE_ID PRODUCTION_YEAR       GENRES         RATING
# 0             101     201.0            2010       Sci-Fi            8.8
# 1             102     202.0            1997      Romance            7.8
# 2             103     203.0            2009       Action            NaN
# 3             104     204.0            1972        Crime            9.2
# 4             105     205.0            1994          NaN            8.5
# 5             NaN     206.0   not available     Thriller            8.7
# 6             107       NaN             NaN        Drama  not available
# 7   not available     208.0            2019  not mension            9.0
# 8             109     209.0            2014       Sci-Fi            NaN
# 9             110       NaN            2009          NaN            8.2
# 10            NaN     211.0             NaN       Comedy            NaN
# 11            112     213.0             NaN       Action            7.9
# ...

# %% [markdown]
# # how to drop column

# %%
df = pd.read_csv("Data/Movies_clean.csv")
df
# Out:
#           USER_ID  MOVIE_ID    MOVIE_TITLE PRODUCTION_YEAR       GENRES  \
# 0             101     201.0      Inception            2010       Sci-Fi
# 1             102     202.0        Titanic            1997      Romance
# 2             103     203.0         Avatar            2009       Action
# 3             104     204.0  The Godfather            1972        Crime
# 4             105     205.0            NaN            1994          NaN
# 5             NaN     206.0          Joker   not available     Thriller
# 6             107       NaN      Gladiator             NaN        Drama
# 7   not available     208.0      not value            2019  not mension
# 8             109     209.0   Interstellar            2014       Sci-Fi
# 9             110       NaN            NaN            2009          NaN
# 10            NaN     211.0         Frozen             NaN       Comedy
# 11            112     213.0         Matrix             NaN       Action
# ...

# %%
df.drop(columns='MOVIE_TITLE',inplace=True)
df
# Out:
#           USER_ID  MOVIE_ID PRODUCTION_YEAR       GENRES         RATING
# 0             101     201.0            2010       Sci-Fi            8.8
# 1             102     202.0            1997      Romance            7.8
# 2             103     203.0            2009       Action            NaN
# 3             104     204.0            1972        Crime            9.2
# 4             105     205.0            1994          NaN            8.5
# 5             NaN     206.0   not available     Thriller            8.7
# 6             107       NaN             NaN        Drama  not available
# 7   not available     208.0            2019  not mension            9.0
# 8             109     209.0            2014       Sci-Fi            NaN
# 9             110       NaN            2009          NaN            8.2
# 10            NaN     211.0             NaN       Comedy            NaN
# 11            112     213.0             NaN       Action            7.9
# ...

# %% [markdown]
# # filling data (fillna)

# %%
df = pd.read_csv("Data/Movies_clean.csv")
df
# Out:
#           USER_ID  MOVIE_ID    MOVIE_TITLE PRODUCTION_YEAR       GENRES  \
# 0             101     201.0      Inception            2010       Sci-Fi
# 1             102     202.0        Titanic            1997      Romance
# 2             103     203.0         Avatar            2009       Action
# 3             104     204.0  The Godfather            1972        Crime
# 4             105     205.0            NaN            1994          NaN
# 5             NaN     206.0          Joker   not available     Thriller
# 6             107       NaN      Gladiator             NaN        Drama
# 7   not available     208.0      not value            2019  not mension
# 8             109     209.0   Interstellar            2014       Sci-Fi
# 9             110       NaN            NaN            2009          NaN
# 10            NaN     211.0         Frozen             NaN       Comedy
# 11            112     213.0         Matrix             NaN       Action
# ...

# %%
# fillna with specific value

# %%
df.fillna(5)    # inplace = true   #fill the data where nan has
# Out:
#           USER_ID  MOVIE_ID    MOVIE_TITLE PRODUCTION_YEAR       GENRES  \
# 0             101     201.0      Inception            2010       Sci-Fi
# 1             102     202.0        Titanic            1997      Romance
# 2             103     203.0         Avatar            2009       Action
# 3             104     204.0  The Godfather            1972        Crime
# 4             105     205.0              5            1994            5
# 5               5     206.0          Joker   not available     Thriller
# 6             107       5.0      Gladiator               5        Drama
# 7   not available     208.0      not value            2019  not mension
# 8             109     209.0   Interstellar            2014       Sci-Fi
# 9             110       5.0              5            2009            5
# 10              5     211.0         Frozen               5       Comedy
# 11            112     213.0         Matrix               5       Action
# ...

# %%
# fillna with spacific value in perticuler column

# %%
df.fillna({'MOVIE_TITLE':'Batman','RATING':6})
# Out:
#           USER_ID  MOVIE_ID    MOVIE_TITLE PRODUCTION_YEAR       GENRES  \
# 0             101     201.0      Inception            2010       Sci-Fi
# 1             102     202.0        Titanic            1997      Romance
# 2             103     203.0         Avatar            2009       Action
# 3             104     204.0  The Godfather            1972        Crime
# 4             105     205.0         Batman            1994          NaN
# 5             NaN     206.0          Joker   not available     Thriller
# 6             107       NaN      Gladiator             NaN        Drama
# 7   not available     208.0      not value            2019  not mension
# 8             109     209.0   Interstellar            2014       Sci-Fi
# 9             110       NaN         Batman            2009          NaN
# 10            NaN     211.0         Frozen             NaN       Comedy
# 11            112     213.0         Matrix             NaN       Action
# ...

# %%
# ffill method   #f = forward

# %%
df
# Out:
#           USER_ID  MOVIE_ID    MOVIE_TITLE PRODUCTION_YEAR       GENRES  \
# 0             101     201.0      Inception            2010       Sci-Fi
# 1             102     202.0        Titanic            1997      Romance
# 2             103     203.0         Avatar            2009       Action
# 3             104     204.0  The Godfather            1972        Crime
# 4             105     205.0            NaN            1994          NaN
# 5             NaN     206.0          Joker   not available     Thriller
# 6             107       NaN      Gladiator             NaN        Drama
# 7   not available     208.0      not value            2019  not mension
# 8             109     209.0   Interstellar            2014       Sci-Fi
# 9             110       NaN            NaN            2009          NaN
# 10            NaN     211.0         Frozen             NaN       Comedy
# 11            112     213.0         Matrix             NaN       Action
# ...

# %%
df.fillna(method='ffill')
# it is must to have one value at top else as we can see rating has NAN value ramain
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_14524\4156025296.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill')
#           USER_ID  MOVIE_ID    MOVIE_TITLE PRODUCTION_YEAR       GENRES  \
# 0             101     201.0      Inception            2010       Sci-Fi
# 1             102     202.0        Titanic            1997      Romance
# 2             103     203.0         Avatar            2009       Action
# 3             104     204.0  The Godfather            1972        Crime
# 4             105     205.0  The Godfather            1994        Crime
# 5             105     206.0          Joker   not available     Thriller
# 6             107     206.0      Gladiator   not available        Drama
# 7   not available     208.0      not value            2019  not mension
# 8             109     209.0   Interstellar            2014       Sci-Fi
# ...

# %%
df.fillna(method='ffill',limit=2)    # axis also pass in fillna
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_14524\4275621378.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill',limit=2)    # axis also pass in fillna
#           USER_ID  MOVIE_ID    MOVIE_TITLE PRODUCTION_YEAR       GENRES  \
# 0             101     201.0      Inception            2010       Sci-Fi
# 1             102     202.0        Titanic            1997      Romance
# 2             103     203.0         Avatar            2009       Action
# 3             104     204.0  The Godfather            1972        Crime
# 4             105     205.0  The Godfather            1994        Crime
# 5             105     206.0          Joker   not available     Thriller
# 6             107     206.0      Gladiator   not available        Drama
# 7   not available     208.0      not value            2019  not mension
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# bfill method    #b = backward

# %%
df.fillna(method='bfill')
# Out:
#           USER_ID  MOVIE_ID    MOVIE_TITLE PRODUCTION_YEAR       GENRES  \
# 0             101     201.0      Inception            2010       Sci-Fi
# 1             102     202.0        Titanic            1997      Romance
# 2             103     203.0         Avatar            2009       Action
# 3             104     204.0  The Godfather            1972        Crime
# 4             105     205.0          Joker            1994     Thriller
# 5             107     206.0          Joker   not available     Thriller
# 6             107     208.0      Gladiator            2019        Drama
# 7   not available     208.0      not value            2019  not mension
# 8             109     209.0   Interstellar            2014       Sci-Fi
# 9             110     211.0         Frozen            2009       Comedy
# 10            112     211.0         Frozen            2003       Comedy
# 11            112     213.0         Matrix            2003       Action
# ...

# %%
df.fillna(method='bfill',limit=2)
# Out:
#           USER_ID  MOVIE_ID    MOVIE_TITLE PRODUCTION_YEAR       GENRES  \
# 0             101     201.0      Inception            2010       Sci-Fi
# 1             102     202.0        Titanic            1997      Romance
# 2             103     203.0         Avatar            2009       Action
# 3             104     204.0  The Godfather            1972        Crime
# 4             105     205.0          Joker            1994     Thriller
# 5             107     206.0          Joker   not available     Thriller
# 6             107     208.0      Gladiator            2019        Drama
# 7   not available     208.0      not value            2019  not mension
# 8             109     209.0   Interstellar            2014       Sci-Fi
# 9             110     211.0         Frozen            2009       Comedy
# 10            112     211.0         Frozen            2003       Comedy
# 11            112     213.0         Matrix            2003       Action
# ...

# %%
df['MOVIE_TITLE'].fillna(method='bfill',limit=2)
# Out:
# 0         Inception
# 1           Titanic
# 2            Avatar
# 3     The Godfather
# 4             Joker
# 5             Joker
# 6         Gladiator
# 7         not value
# 8      Interstellar
# 9            Frozen
# 10           Frozen
# 11           Matrix
# 12              NaN
# Name: MOVIE_TITLE, dtype: object

# %% [markdown]
# # replace method and its parameters

# %%
df
# Out:
#           USER_ID  MOVIE_ID    MOVIE_TITLE PRODUCTION_YEAR       GENRES  \
# 0             101     201.0      Inception            2010       Sci-Fi
# 1             102     202.0        Titanic            1997      Romance
# 2             103     203.0         Avatar            2009       Action
# 3             104     204.0  The Godfather            1972        Crime
# 4             105     205.0            NaN            1994          NaN
# 5             NaN     206.0          Joker   not available     Thriller
# 6             107       NaN      Gladiator             NaN        Drama
# 7   not available     208.0      not value            2019  not mension
# 8             109     209.0   Interstellar            2014       Sci-Fi
# 9             110       NaN            NaN            2009          NaN
# 10            NaN     211.0         Frozen             NaN       Comedy
# 11            112     213.0         Matrix             NaN       Action
# ...

# %%
# convert all string values in integer using Regex(regular expression) parameter
df.replace('[A-Za-z]',24,regex=True)    #24 is depends on you
# Out:
#    USER_ID  MOVIE_ID  MOVIE_TITLE PRODUCTION_YEAR  GENRES RATING
# 0      101     201.0         24.0            2010    24.0    8.8
# 1      102     202.0         24.0            1997    24.0    7.8
# 2      103     203.0         24.0            2009    24.0    NaN
# 3      104     204.0         24.0            1972    24.0    9.2
# 4      105     205.0          NaN            1994     NaN    8.5
# 5      NaN     206.0         24.0              24    24.0    8.7
# 6      107       NaN         24.0             NaN    24.0     24
# 7       24     208.0         24.0            2019    24.0    9.0
# 8      109     209.0         24.0            2014    24.0    NaN
# 9      110       NaN          NaN            2009     NaN    8.2
# 10     NaN     211.0         24.0             NaN    24.0    NaN
# 11     112     213.0         24.0             NaN    24.0    7.9
# 12     NaN       NaN          NaN            2003     NaN    NaN

# %%
df.replace({"MOVIE_TITLE":'[A-Za-z]'},50,regex=True)
# Out:
#           USER_ID  MOVIE_ID  MOVIE_TITLE PRODUCTION_YEAR       GENRES  \
# 0             101     201.0         50.0            2010       Sci-Fi
# 1             102     202.0         50.0            1997      Romance
# 2             103     203.0         50.0            2009       Action
# 3             104     204.0         50.0            1972        Crime
# 4             105     205.0          NaN            1994          NaN
# 5             NaN     206.0         50.0   not available     Thriller
# 6             107       NaN         50.0             NaN        Drama
# 7   not available     208.0         50.0            2019  not mension
# 8             109     209.0         50.0            2014       Sci-Fi
# 9             110       NaN          NaN            2009          NaN
# 10            NaN     211.0         50.0             NaN       Comedy
# 11            112     213.0         50.0             NaN       Action
# ...

# %%
df['USER_ID'] = range(1,14)

# %%
df
# Out:
#     USER_ID  MOVIE_ID    MOVIE_TITLE PRODUCTION_YEAR       GENRES  \
# 0         1     201.0      Inception            2010       Sci-Fi
# 1         2     202.0        Titanic            1997      Romance
# 2         3     203.0         Avatar            2009       Action
# 3         4     204.0  The Godfather            1972        Crime
# 4         5     205.0            NaN            1994          NaN
# 5         6     206.0          Joker   not available     Thriller
# 6         7       NaN      Gladiator             NaN        Drama
# 7         8     208.0      not value            2019  not mension
# 8         9     209.0   Interstellar            2014       Sci-Fi
# 9        10       NaN            NaN            2009          NaN
# 10       11     211.0         Frozen             NaN       Comedy
# 11       12     213.0         Matrix             NaN       Action
# 12       13       NaN            NaN            2003          NaN
#
#            RATING
# 0             8.8
# ...

# %%
# method in replace
df.replace("5",method="ffill")
# Out:
#     USER_ID  MOVIE_ID    MOVIE_TITLE PRODUCTION_YEAR       GENRES  \
# 0         1     201.0      Inception            2010       Sci-Fi
# 1         2     202.0        Titanic            1997      Romance
# 2         3     203.0         Avatar            2009       Action
# 3         4     204.0  The Godfather            1972        Crime
# 4         5     205.0            NaN            1994          NaN
# 5         6     206.0          Joker   not available     Thriller
# 6         7       NaN      Gladiator             NaN        Drama
# 7         8     208.0      not value            2019  not mension
# 8         9     209.0   Interstellar            2014       Sci-Fi
# 9        10       NaN            NaN            2009          NaN
# 10       11     211.0         Frozen             NaN       Comedy
# 11       12     213.0         Matrix             NaN       Action
# 12       13       NaN            NaN            2003          NaN
#
#            RATING
# 0             8.8
# ...

# %%
df.replace("9",method="ffill",limit=1)
# Out:
#     USER_ID  MOVIE_ID    MOVIE_TITLE PRODUCTION_YEAR       GENRES  \
# 0         1     201.0      Inception            2010       Sci-Fi
# 1         2     202.0        Titanic            1997      Romance
# 2         3     203.0         Avatar            2009       Action
# 3         4     204.0  The Godfather            1972        Crime
# 4         5     205.0            NaN            1994          NaN
# 5         6     206.0          Joker   not available     Thriller
# 6         7       NaN      Gladiator             NaN        Drama
# 7         8     208.0      not value            2019  not mension
# 8         9     209.0   Interstellar            2014       Sci-Fi
# 9        10       NaN            NaN            2009          NaN
# 10       11     211.0         Frozen             NaN       Comedy
# 11       12     213.0         Matrix             NaN       Action
# 12       13       NaN            NaN            2003          NaN
#
#            RATING
# 0             8.8
# ...

# %%
df.replace("9",method="bfill")
# Out:
#     USER_ID  MOVIE_ID    MOVIE_TITLE PRODUCTION_YEAR       GENRES  \
# 0         1     201.0      Inception            2010       Sci-Fi
# 1         2     202.0        Titanic            1997      Romance
# 2         3     203.0         Avatar            2009       Action
# 3         4     204.0  The Godfather            1972        Crime
# 4         5     205.0            NaN            1994          NaN
# 5         6     206.0          Joker   not available     Thriller
# 6         7       NaN      Gladiator             NaN        Drama
# 7         8     208.0      not value            2019  not mension
# 8         9     209.0   Interstellar            2014       Sci-Fi
# 9        10       NaN            NaN            2009          NaN
# 10       11     211.0         Frozen             NaN       Comedy
# 11       12     213.0         Matrix             NaN       Action
# 12       13       NaN            NaN            2003          NaN
#
#            RATING
# 0             8.8
# ...

# %%
df.replace("9",method="bfill",limit=1)
# Out:
#     USER_ID  MOVIE_ID    MOVIE_TITLE PRODUCTION_YEAR       GENRES  \
# 0         1     201.0      Inception            2010       Sci-Fi
# 1         2     202.0        Titanic            1997      Romance
# 2         3     203.0         Avatar            2009       Action
# 3         4     204.0  The Godfather            1972        Crime
# 4         5     205.0            NaN            1994          NaN
# 5         6     206.0          Joker   not available     Thriller
# 6         7       NaN      Gladiator             NaN        Drama
# 7         8     208.0      not value            2019  not mension
# 8         9     209.0   Interstellar            2014       Sci-Fi
# 9        10       NaN            NaN            2009          NaN
# 10       11     211.0         Frozen             NaN       Comedy
# 11       12     213.0         Matrix             NaN       Action
# 12       13       NaN            NaN            2003          NaN
#
#            RATING
# 0             8.8
# ...

# %% [markdown]
# # interpolation

# %%
df = pd.read_csv(r"Data/Movies_clean.csv")
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.read_csv(r"Data/Movies_clean.csv")
#       2 df
#
# NameError: name 'pd' is not defined

# %%
df['USER_ID'] = pd.to_numeric(df['USER_ID'], errors='coerce').astype('Int64')  # Nullable Integer
df['MOVIE_ID'] = pd.to_numeric(df['MOVIE_ID'], errors='coerce').astype('Int64')
df['RATING'] = pd.to_numeric(df['RATING'], errors='coerce').astype('float')

# %%
df.dtypes
# Out:
# USER_ID              Int64
# MOVIE_ID             Int64
# MOVIE_TITLE         object
# PRODUCTION_YEAR     object
# GENRES              object
# RATING             float64
# dtype: object

# %%
df.interpolate(method='linear')
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_20668\1321276365.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate(method='linear')
#     USER_ID  MOVIE_ID    MOVIE_TITLE PRODUCTION_YEAR       GENRES  RATING
# 0     101.0     201.0      Inception            2010       Sci-Fi    8.80
# 1     102.0     202.0        Titanic            1997      Romance    7.80
# 2     103.0     203.0         Avatar            2009       Action    8.50
# 3     104.0     204.0  The Godfather            1972        Crime    9.20
# 4     105.0     205.0            NaN            1994          NaN    8.50
# 5     106.0     206.0          Joker   not available     Thriller    8.70
# 6     107.0     207.0      Gladiator             NaN        Drama    8.85
# 7     108.0     208.0      not value            2019  not mension    9.00
# ...

# %%
df.interpolate(method='linear')   #average value between 2 data
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_20668\1326321047.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate(method='linear')   #average value between 2 data
#     USER_ID  MOVIE_ID    MOVIE_TITLE PRODUCTION_YEAR       GENRES  RATING
# 0     101.0     201.0      Inception            2010       Sci-Fi    8.80
# 1     102.0     202.0        Titanic            1997      Romance    7.80
# 2     103.0     203.0         Avatar            2009       Action    8.50
# 3     104.0     204.0  The Godfather            1972        Crime    9.20
# 4     105.0     205.0            NaN            1994          NaN    8.50
# 5     106.0     206.0          Joker   not available     Thriller    8.70
# 6     107.0     207.0      Gladiator             NaN        Drama    8.85
# 7     108.0     208.0      not value            2019  not mension    9.00
# ...

# %%
df = pd.read_csv(r"Data/Movieratingdata4.csv",parse_dates=["DATE"])
df
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_20668\2904213943.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df = pd.read_csv(r"Data/Movieratingdata4.csv",parse_dates=["DATE"])
#         DATE  USER_ID  MOVIE_ID  PRODUCTION_YEAR Section  RATING
# 0 2021-01-25      1.0   4642044           2015.0       A    10.0
# 1 2021-02-25      NaN   4642044              NaN     NaN     NaN
# 2 2021-03-25      3.0   1245897           2014.0     NaN     8.0
# 3 2021-04-25      NaN   1390411           2015.0     NaN     6.0
# 4 2021-05-25      NaN   6306064              NaN       B     NaN
# 5 2021-06-25      NaN   6306064           2020.0       D     4.0
# 6 2021-07-25      7.0   2719848           2015.0       E     4.0
# 7 2021-08-25      8.0    462504           2006.0       B     9.0
# 8 2021-09-25      9.0     25468           2015.0       F     NaN
# ...

# %%
df.dtypes
# Out:
# DATE               datetime64[ns]
# USER_ID                   float64
# MOVIE_ID                    int64
# PRODUCTION_YEAR           float64
# Section                    object
# RATING                    float64
# dtype: object

# %%
type(df.DATE[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df.set_index('DATE',inplace=True)
df
# Out:
#             USER_ID  MOVIE_ID  PRODUCTION_YEAR Section  RATING
# DATE
# 2021-01-25      1.0   4642044           2015.0       A    10.0
# 2021-02-25      NaN   4642044              NaN     NaN     NaN
# 2021-03-25      3.0   1245897           2014.0     NaN     8.0
# 2021-04-25      NaN   1390411           2015.0     NaN     6.0
# 2021-05-25      NaN   6306064              NaN       B     NaN
# 2021-06-25      NaN   6306064           2020.0       D     4.0
# 2021-07-25      7.0   2719848           2015.0       E     4.0
# 2021-08-25      8.0    462504           2006.0       B     9.0
# 2021-09-25      9.0     25468           2015.0       F     NaN
# 2021-10-25     10.0   2564789           2015.0       D     9.0

# %%
df.interpolate(method='time')
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_20668\722817345.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate(method='time')
#               USER_ID  MOVIE_ID  PRODUCTION_YEAR Section     RATING
# DATE
# 2021-01-25   1.000000   4642044      2015.000000       A  10.000000
# 2021-02-25   2.050847   4642044      2014.474576     NaN   8.949153
# 2021-03-25   3.000000   1245897      2014.000000     NaN   8.000000
# 2021-04-25   4.016393   1390411      2015.000000     NaN   6.000000
# 2021-05-25   5.000000   6306064      2017.459016       B   5.016393
# 2021-06-25   6.016393   6306064      2020.000000       D   4.000000
# 2021-07-25   7.000000   2719848      2015.000000       E   4.000000
# 2021-08-25   8.000000    462504      2006.000000       B   9.000000
# 2021-09-25   9.000000     25468      2015.000000       F   9.000000
# ...

# %%
df = pd.read_csv(r"Data/Movieratingdata4.csv",index_col=["MOVIE_ID"])
df
# Out:
#                 DATE  USER_ID  PRODUCTION_YEAR Section  RATING
# MOVIE_ID
# 4642044   25-01-2021      1.0           2015.0       A    10.0
# 4642044   25-02-2021      NaN              NaN     NaN     NaN
# 1245897   25-03-2021      3.0           2014.0     NaN     8.0
# 1390411   25-04-2021      NaN           2015.0     NaN     6.0
# 6306064   25-05-2021      NaN              NaN       B     NaN
# 6306064   25-06-2021      NaN           2020.0       D     4.0
# 2719848   25-07-2021      7.0           2015.0       E     4.0
# 462504    25-08-2021      8.0           2006.0       B     9.0
# 25468     25-09-2021      9.0           2015.0       F     NaN
# 2564789   25-10-2021     10.0           2015.0       D     9.0

# %%
df.interpolate(method='index')
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_20668\2515484856.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate(method='index')
#                 DATE    USER_ID  PRODUCTION_YEAR Section  RATING
# MOVIE_ID
# 4642044   25-01-2021   1.000000           2015.0       A    10.0
# 4642044   25-02-2021   1.000000           2015.0     NaN    10.0
# 1245897   25-03-2021   3.000000           2014.0     NaN     8.0
# 1390411   25-04-2021   3.767006           2015.0     NaN     6.0
# 6306064   25-05-2021   1.000000           2020.0       B     4.0
# 6306064   25-06-2021   1.000000           2020.0       D     4.0
# 2719848   25-07-2021   7.000000           2015.0       E     4.0
# 462504    25-08-2021   8.000000           2006.0       B     9.0
# 25468     25-09-2021   9.000000           2015.0       F     9.0
# ...

# %%
df.interpolate(method='nearest')
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_20668\1654062127.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate(method='nearest')
#                 DATE  USER_ID  PRODUCTION_YEAR Section  RATING
# MOVIE_ID
# 4642044   25-01-2021      1.0           2015.0       A    10.0
# 4642044   25-02-2021      1.0           2015.0     NaN    10.0
# 1245897   25-03-2021      3.0           2014.0     NaN     8.0
# 1390411   25-04-2021      3.0           2015.0     NaN     6.0
# 6306064   25-05-2021      NaN           2020.0       B     4.0
# 6306064   25-06-2021      NaN           2020.0       D     4.0
# 2719848   25-07-2021      7.0           2015.0       E     4.0
# 462504    25-08-2021      8.0           2006.0       B     9.0
# 25468     25-09-2021      9.0           2015.0       F     NaN
# ...

# %%
df = pd.read_csv(r"Data/Movieratingdata4.csv")
df
# Out:
#          DATE  USER_ID  MOVIE_ID  PRODUCTION_YEAR Section  RATING
# 0  25-01-2021      1.0   4642044           2015.0       A    10.0
# 1  25-02-2021      NaN   4642044              NaN     NaN     NaN
# 2  25-03-2021      3.0   1245897           2014.0     NaN     8.0
# 3  25-04-2021      NaN   1390411           2015.0     NaN     6.0
# 4  25-05-2021      NaN   6306064              NaN       B     NaN
# 5  25-06-2021      NaN   6306064           2020.0       D     4.0
# 6  25-07-2021      7.0   2719848           2015.0       E     4.0
# 7  25-08-2021      8.0    462504           2006.0       B     9.0
# 8  25-09-2021      9.0     25468           2015.0       F     NaN
# 9  25-10-2021     10.0   2564789           2015.0       D     9.0

# %%
df.interpolate(limit=1)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_20668\1270544217.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate(limit=1)
#          DATE  USER_ID  MOVIE_ID  PRODUCTION_YEAR Section  RATING
# 0  25-01-2021      1.0   4642044           2015.0       A    10.0
# 1  25-02-2021      2.0   4642044           2014.5     NaN     9.0
# 2  25-03-2021      3.0   1245897           2014.0     NaN     8.0
# 3  25-04-2021      4.0   1390411           2015.0     NaN     6.0
# 4  25-05-2021      NaN   6306064           2017.5       B     5.0
# 5  25-06-2021      NaN   6306064           2020.0       D     4.0
# 6  25-07-2021      7.0   2719848           2015.0       E     4.0
# 7  25-08-2021      8.0    462504           2006.0       B     9.0
# 8  25-09-2021      9.0     25468           2015.0       F     9.0
# ...

# %%
df.interpolate(limit_direction="backward",limit=2)  # default = forward
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_20668\3590120624.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate(limit_direction="backward",limit=2)  # default = forward
#          DATE  USER_ID  MOVIE_ID  PRODUCTION_YEAR Section  RATING
# 0  25-01-2021      1.0   4642044           2015.0       A    10.0
# 1  25-02-2021      2.0   4642044           2014.5     NaN     9.0
# 2  25-03-2021      3.0   1245897           2014.0     NaN     8.0
# 3  25-04-2021      NaN   1390411           2015.0     NaN     6.0
# 4  25-05-2021      5.0   6306064           2017.5       B     5.0
# 5  25-06-2021      6.0   6306064           2020.0       D     4.0
# 6  25-07-2021      7.0   2719848           2015.0       E     4.0
# 7  25-08-2021      8.0    462504           2006.0       B     9.0
# 8  25-09-2021      9.0     25468           2015.0       F     9.0
# ...

# %%
df.interpolate(limit_direction="both",limit=2)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_20668\167825398.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate(limit_direction="both",limit=2)
#          DATE  USER_ID  MOVIE_ID  PRODUCTION_YEAR Section  RATING
# 0  25-01-2021      1.0   4642044           2015.0       A    10.0
# 1  25-02-2021      2.0   4642044           2014.5     NaN     9.0
# 2  25-03-2021      3.0   1245897           2014.0     NaN     8.0
# 3  25-04-2021      4.0   1390411           2015.0     NaN     6.0
# 4  25-05-2021      5.0   6306064           2017.5       B     5.0
# 5  25-06-2021      6.0   6306064           2020.0       D     4.0
# 6  25-07-2021      7.0   2719848           2015.0       E     4.0
# 7  25-08-2021      8.0    462504           2006.0       B     9.0
# 8  25-09-2021      9.0     25468           2015.0       F     9.0
# ...

# %% [markdown]
# # main method

# %%
df = pd.read_csv(r"Data/Movieratingdata4.csv")
df
# Out:
#          DATE  USER_ID  MOVIE_ID  PRODUCTION_YEAR Section  RATING
# 0  25-01-2021      1.0   4642044           2015.0       A    10.0
# 1  25-02-2021      NaN   4642044              NaN     NaN     NaN
# 2  25-03-2021      3.0   1245897           2014.0     NaN     8.0
# 3  25-04-2021      NaN   1390411           2015.0     NaN     6.0
# 4  25-05-2021      NaN   6306064              NaN       B     NaN
# 5  25-06-2021      NaN   6306064           2020.0       D     4.0
# 6  25-07-2021      7.0   2719848           2015.0       E     4.0
# 7  25-08-2021      8.0    462504           2006.0       B     9.0
# 8  25-09-2021      9.0     25468           2015.0       F     NaN
# 9  25-10-2021     10.0   2564789           2015.0       D     9.0

# %%
df.isnull()
# Out:
#     DATE  USER_ID  MOVIE_ID  PRODUCTION_YEAR  Section  RATING
# 0  False    False     False            False    False   False
# 1  False     True     False             True     True    True
# 2  False    False     False            False     True   False
# 3  False     True     False            False     True   False
# 4  False     True     False             True    False    True
# 5  False     True     False            False    False   False
# 6  False    False     False            False    False   False
# 7  False    False     False            False    False   False
# 8  False    False     False            False    False    True
# 9  False    False     False            False    False   False

# %%
df.isnull().sum()
# Out:
# DATE               0
# USER_ID            4
# MOVIE_ID           0
# PRODUCTION_YEAR    2
# Section            3
# RATING             3
# dtype: int64

# %%
df.dtypes
# Out:
# DATE                object
# USER_ID            float64
# MOVIE_ID             int64
# PRODUCTION_YEAR    float64
# Section             object
# RATING             float64
# dtype: object

# %%
df['RATING'] = df['RATING'].fillna(df['RATING'].mean())
df
# Out:
#          DATE    USER_ID  MOVIE_ID  PRODUCTION_YEAR Section  RATING
# 0  25-01-2021   1.000000   4642044           2015.0       A    10.0
# 1  25-02-2021   6.333333   4642044              NaN     NaN     NaN
# 2  25-03-2021   3.000000   1245897           2014.0     NaN     8.0
# 3  25-04-2021   6.333333   1390411           2015.0     NaN     6.0
# 4  25-05-2021   6.333333   6306064              NaN       B     NaN
# 5  25-06-2021   6.333333   6306064           2020.0       D     4.0
# 6  25-07-2021   7.000000   2719848           2015.0       E     4.0
# 7  25-08-2021   8.000000    462504           2006.0       B     9.0
# 8  25-09-2021   9.000000     25468           2015.0       F     NaN
# 9  25-10-2021  10.000000   2564789           2015.0       D     9.0

# %%
xz = df['USER_ID'].mean()

# %%
ro = round(xz,0)
ro
# Out:
# 6.0

# %%
df = pd.read_csv(r"Data/Movieratingdata4.csv")
df['USER_ID'] = df['USER_ID'].fillna(ro)
df
# Out:
#          DATE  USER_ID  MOVIE_ID  PRODUCTION_YEAR Section  RATING
# 0  25-01-2021      1.0   4642044           2015.0       A    10.0
# 1  25-02-2021      6.0   4642044              NaN     NaN     NaN
# 2  25-03-2021      3.0   1245897           2014.0     NaN     8.0
# 3  25-04-2021      6.0   1390411           2015.0     NaN     6.0
# 4  25-05-2021      6.0   6306064              NaN       B     NaN
# 5  25-06-2021      6.0   6306064           2020.0       D     4.0
# 6  25-07-2021      7.0   2719848           2015.0       E     4.0
# 7  25-08-2021      8.0    462504           2006.0       B     9.0
# 8  25-09-2021      9.0     25468           2015.0       F     NaN
# 9  25-10-2021     10.0   2564789           2015.0       D     9.0

# %%
df['Section'].mode()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df['Section'].mode()
#
# NameError: name 'df' is not defined

# %%
df['Section'] = df['Section'].fillna(df['Section'].mode()[0])
df
# Out:
#          DATE  USER_ID  MOVIE_ID  PRODUCTION_YEAR Section  RATING
# 0  25-01-2021      1.0   4642044           2015.0       A    10.0
# 1  25-02-2021      6.0   4642044              NaN       B     NaN
# 2  25-03-2021      3.0   1245897           2014.0       B     8.0
# 3  25-04-2021      6.0   1390411           2015.0       B     6.0
# 4  25-05-2021      6.0   6306064              NaN       B     NaN
# 5  25-06-2021      6.0   6306064           2020.0       D     4.0
# 6  25-07-2021      7.0   2719848           2015.0       E     4.0
# 7  25-08-2021      8.0    462504           2006.0       B     9.0
# 8  25-09-2021      9.0     25468           2015.0       F     NaN
# 9  25-10-2021     10.0   2564789           2015.0       D     9.0
