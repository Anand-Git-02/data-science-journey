# %%
import pandas as pd

# %%
df = pd.read_csv('Data/survey_results_public.csv')
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
India_df = df[df['Country'] == "India"]
India_df
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 7               8             I code primarily as a hobby      Yes
# 9              10          I am a developer by profession      Yes
# 14             15  I am a student who is learning to code      Yes
# 49             50          I am a developer by profession      Yes
# 64             65          I am a developer by profession      Yes
# ...           ...                                     ...      ...
# 88808       77339                                     NaN      Yes
# 88825       79795                                     NaN      Yes
# 88852       83862                                     NaN      Yes
# 88853       84299                                     NaN      Yes
# 88864       86012                                     NaN      Yes
#
#                                              OpenSourcer  \
# 7                                Less than once per year
# ...

# %%
India_df.reset_index(drop=True,inplace=True)

# %%
India_df.shape
# Out:
# (9061, 85)

# %%
India_df['Respondent'] = range(1,9062)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_16412\2290704893.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   India_df['Respondent'] = range(1,9062)

# %%
India_df.to_csv('india.csv',index=False)

# %%
pd.read_csv('India.csv')
# Out:
#       Respondent                              MainBranch Hobbyist  \
# 0              1             I code primarily as a hobby      Yes
# 1              2          I am a developer by profession      Yes
# 2              3  I am a student who is learning to code      Yes
# 3              4          I am a developer by profession      Yes
# 4              5          I am a developer by profession      Yes
# ...          ...                                     ...      ...
# 9056        9057                                     NaN      Yes
# 9057        9058                                     NaN      Yes
# 9058        9059                                     NaN      Yes
# 9059        9060                                     NaN      Yes
# 9060        9061                                     NaN      Yes
#
#                                             OpenSourcer  \
# 0                               Less than once per year
# 1                            Once a month or more often
# ...

# %%
India_df.to_csv(r'C:\Users\Lenovo\OneDrive\Desktop\Python\India.csv')

# %%
df = pd.read_html('https://www.w3schools.com/html/html_tables.asp')
df
# Out:
# [                        Company           Contact  Country
#  0           Alfreds Futterkiste      Maria Anders  Germany
#  1    Centro comercial Moctezuma   Francisco Chang   Mexico
#  2                  Ernst Handel     Roland Mendel  Austria
#  3                Island Trading     Helen Bennett       UK
#  4  Laughing Bacchus Winecellars   Yoshi Tannamuri   Canada
#  5  Magazzini Alimentari Riuniti  Giovanni Rovelli    Italy,
#            Tag                                        Description
#  0     <table>                                    Defines a table
#  1        <th>                   Defines a header cell in a table
#  2        <tr>                           Defines a row in a table
#  3        <td>                          Defines a cell in a table
#  4   <caption>                            Defines a table caption
#  5  <colgroup>  Specifies a group of one or more columns in a ...
#  6       <col>  Specifies column properties for each column wi...
# ...

# %%
df[0].to_json('file1.json')

# %%
pd.read_excel(r"C:\Users\Lenovo\Data Science\Classroom\Module_4\Excel_Workbook.xlsx",sheet_name='Conditional Formatting')
# Out:
#     S No First Name Last Name        DOJ  Sal-Jan  Sal-Feb  Sal-Mar  \
# 0    1.0      Ankit    Sharma 2022-01-15   5000.0   5200.0   4800.0
# 1    2.0      Priya     Verma 2023-02-20   6000.0   5900.0   6100.0
# 2    3.0      Meera      Iyer 2021-12-05   4500.0   4700.0   4600.0
# 3    4.0      Rohan     Gupta 2020-08-10   7000.0   6900.0   7100.0
# 4    5.0      Kavya     Desai 2019-04-25   5500.0   5300.0   5600.0
# 5    NaN        NaN       NaN        NaT      NaN      NaN      NaN
# 6    NaN        NaN       NaN        NaT      NaN      NaN      NaN
# 7    NaN        NaN       NaN        NaT      NaN      NaN      NaN
# 8    NaN        NaN       NaN        NaT      NaN      NaN      NaN
# 9    NaN        NaN       NaN        NaT      NaN      NaN      NaN
# 10   NaN        NaN       NaN        NaT      NaN      NaN      NaN
# 11   NaN        NaN       NaN        NaT      NaN      NaN      NaN
# 12   NaN        NaN       NaN        NaT      NaN      NaN      NaN
# ...
