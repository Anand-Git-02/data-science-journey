# %%
import pandas as pd
import numpy as np

# %%
path = r"Data/imdb_movie_data_2023.csv"

# %%
data = pd.read_csv(path)
data
# Out:
#       User_Id                   Moive Name  Rating     Votes  Meta Score  \
# 0           1       Leave the World Behind     6.5   90000.0        67.0
# 1           2                        Wonka     7.4   24000.0        66.0
# 2           3                  Poor Things     8.5    6700.0        86.0
# 3           4   Killers of the Flower Moon     7.8  128000.0        89.0
# 4           5                 May December     7.0   21000.0        85.0
# ...       ...                          ...     ...       ...         ...
# 1945     1946            Definitely, Maybe     7.1  172000.0        59.0
# 1946     1947                      The Fly     7.6  198000.0        79.0
# 1947     1948             The Mighty Ducks     6.5   71000.0        46.0
# 1948     1949                Little Giants     6.4   30000.0         NaN
# 1949     1950                American Made     7.1  203000.0        65.0
#
#                           Genre PG Rating  Year Duration  \
# ...

# %% [markdown]
# # Filtering

# %%
data['Year']>2020
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1945    False
# 1946    False
# 1947    False
# 1948    False
# 1949    False
# Name: Year, Length: 1950, dtype: bool

# %%
data1 = data[data['Year']>2020]
data1
# Out:
#       User_Id                   Moive Name  Rating     Votes  Meta Score  \
# 0           1       Leave the World Behind     6.5   90000.0        67.0
# 1           2                        Wonka     7.4   24000.0        66.0
# 2           3                  Poor Things     8.5    6700.0        86.0
# 3           4   Killers of the Flower Moon     7.8  128000.0        89.0
# 4           5                 May December     7.0   21000.0        85.0
# ...       ...                          ...     ...       ...         ...
# 1907     1908                      Missing     7.1   54000.0        66.0
# 1917     1918                       Memory     5.7   34000.0        41.0
# 1928     1929        Boudica: Queen of War     4.4    1600.0         NaN
# 1937     1938                Occupied City     7.1     141.0        75.0
# 1944     1945                      Annette     6.3   22000.0        67.0
#
#                           Genre PG Rating  Year Duration  \
# ...

# %%
data[data['Moive Name'].duplicated()]['Moive Name']
# Out:
# 98             Miracle on 34th Street
# 158                  The Color Purple
# 370                              Dune
# 422                 A Christmas Carol
# 514                     The Lion King
# 532                   Black Christmas
# 561                          Godzilla
# 694                            Scream
# 794                         The Mummy
# 862                          Vacation
# 1046                A Christmas Carol
# 1084                           Legend
# 1099                     Little Women
# 1187                       Wrong Turn
# 1204             Beauty and the Beast
# 1240               Planet of the Apes
# 1352                  Black Christmas
# 1443                            Crash
# 1450                  West Side Story
# 1463                       Cinderella
# 1496                          Aladdin
# 1505                          RoboCop
# 1521     Teenage Mutant Ninja Turtles
# 1542                           Lolita
# 1562           Leave the World Behind
# ...

# %% [markdown]
# # filtering with and

# %% [markdown]
# ### Year > 1980 and Moive Name

# %%
data2 = data[(data['Year']>1980) & (data['Moive Name']==' The Lion King')]
data2
# Out:
#      User_Id      Moive Name  Rating      Votes  Meta Score  \
# 507      508   The Lion King     8.5  1100000.0        88.0
# 514      515   The Lion King     6.8   262000.0        55.0
#
#                            Genre PG Rating  Year Duration  \
# 507  Animation, Adventure, Drama         G  1994   1h 28m
# 514  Animation, Adventure, Drama        PG  2019   1h 58m
#
#                                                   Cast  \
# 507  Matthew Broderick, Jeremy Irons, James Earl Jo...
# 514  Donald Glover, Beyoncé, Seth Rogen, Chiwetel E...
#
#                     Director
# 507  Roger AllersRob Minkoff
# 514              Jon Favreau

# %% [markdown]
# # filtering with or

# %%
data2 = data[(data['Year']>2012) | (data['Moive Name']==' The Karate Kid')]
data2
# Out:
#       User_Id                        Moive Name  Rating     Votes  Meta Score  \
# 0           1            Leave the World Behind     6.5   90000.0        67.0
# 1           2                             Wonka     7.4   24000.0        66.0
# 2           3                       Poor Things     8.5    6700.0        86.0
# 3           4        Killers of the Flower Moon     7.8  128000.0        89.0
# 4           5                      May December     7.0   21000.0        85.0
# ...       ...                               ...     ...       ...         ...
# 1937     1938                     Occupied City     7.1     141.0        75.0
# 1941     1942           Dragged Across Concrete     6.9   54000.0        60.0
# 1943     1944   Transformers: Age of Extinction     5.6  328000.0        32.0
# 1944     1945                           Annette     6.3   22000.0        67.0
# 1949     1950                     American Made     7.1  203000.0        65.0
#
# ...

# %% [markdown]
# # filtering with str

# %%
data3 = data[data['Genre'].str.contains('Adventure', na=False)]
data3
# if i do not put na = False and if GENERES colume have nan value then error will occure
# Out:
#       User_Id                                         Moive Name  Rating  \
# 1           2                                              Wonka     7.4
# 5           6   The Hunger Games: The Ballad of Songbirds & S...     7.1
# 6           7                                           Napoleon     6.6
# 11         12                                             Barbie     7.0
# 13         14             Rebel Moon - Part One: A Child of Fire     6.3
# ...       ...                                                ...     ...
# 1908     1909                                      Cold Mountain     7.2
# 1921     1922                                           Monsters     6.4
# 1924     1925                                         Goldfinger     7.7
# 1938     1939                           The Man in the Iron Mask     6.5
# 1943     1944                    Transformers: Age of Extinction     5.6
#
#          Votes  Meta Score                         Genre PG Rating  Year  \
# ...

# %%
data4 = data[(data['Genre'].str.contains('Adventure')) & (data['Year']>2015) ]
data4
# Out:
#       User_Id                                         Moive Name  Rating  \
# 1           2                                              Wonka     7.4
# 5           6   The Hunger Games: The Ballad of Songbirds & S...     7.1
# 6           7                                           Napoleon     6.6
# 11         12                                             Barbie     7.0
# 13         14             Rebel Moon - Part One: A Child of Fire     6.3
# ...       ...                                                ...     ...
# 1842     1843                                   Star Trek Beyond     7.0
# 1888     1889                                        The Witches     5.4
# 1891     1892                                            Rampage     6.1
# 1905     1906                                          Pinocchio     5.1
# 1906     1907                                    The Jungle Book     7.4
#
#          Votes  Meta Score                         Genre PG Rating  Year  \
# ...

# %%
data4 = data[(data['Genre'].str.contains('Adventure')) | (data['Year']>2015) ]
data4
# Out:
#       User_Id                        Moive Name  Rating     Votes  Meta Score  \
# 0           1            Leave the World Behind     6.5   90000.0        67.0
# 1           2                             Wonka     7.4   24000.0        66.0
# 2           3                       Poor Things     8.5    6700.0        86.0
# 3           4        Killers of the Flower Moon     7.8  128000.0        89.0
# 4           5                      May December     7.0   21000.0        85.0
# ...       ...                               ...     ...       ...         ...
# 1938     1939          The Man in the Iron Mask     6.5  176000.0        48.0
# 1941     1942           Dragged Across Concrete     6.9   54000.0        60.0
# 1943     1944   Transformers: Age of Extinction     5.6  328000.0        32.0
# 1944     1945                           Annette     6.3   22000.0        67.0
# 1949     1950                     American Made     7.1  203000.0        65.0
#
# ...

# %% [markdown]
# # filtering with loc

# %%
data.loc[5,"Moive Name"]
# Out:
# ' The Hunger Games: The Ballad of Songbirds & Snakes'

# %%
data.loc[0:5,"Moive Name"]
# Out:
# 0                               Leave the World Behind
# 1                                                Wonka
# 2                                          Poor Things
# 3                           Killers of the Flower Moon
# 4                                         May December
# 5     The Hunger Games: The Ballad of Songbirds & S...
# Name: Moive Name, dtype: object

# %%
filt = data['Rating']>6
data.loc[filt]
# Out:
#       User_Id                   Moive Name  Rating     Votes  Meta Score  \
# 0           1       Leave the World Behind     6.5   90000.0        67.0
# 1           2                        Wonka     7.4   24000.0        66.0
# 2           3                  Poor Things     8.5    6700.0        86.0
# 3           4   Killers of the Flower Moon     7.8  128000.0        89.0
# 4           5                 May December     7.0   21000.0        85.0
# ...       ...                          ...     ...       ...         ...
# 1945     1946            Definitely, Maybe     7.1  172000.0        59.0
# 1946     1947                      The Fly     7.6  198000.0        79.0
# 1947     1948             The Mighty Ducks     6.5   71000.0        46.0
# 1948     1949                Little Giants     6.4   30000.0         NaN
# 1949     1950                American Made     7.1  203000.0        65.0
#
#                           Genre PG Rating  Year Duration  \
# ...

# %%
data[data['Moive Name'].duplicated()]['Moive Name'].values
# Out:
# array([' Miracle on 34th Street', ' The Color Purple', ' Dune',
#        ' A Christmas Carol', ' The Lion King', ' Black Christmas',
#        ' Godzilla', ' Scream', ' The Mummy', ' Vacation',
#        ' A Christmas Carol', ' Legend', ' Little Women', ' Wrong Turn',
#        ' Beauty and the Beast', ' Planet of the Apes', ' Black Christmas',
#        ' Crash', ' West Side Story', ' Cinderella', ' Aladdin',
#        ' RoboCop', ' Teenage Mutant Ninja Turtles', ' Lolita',
#        ' Leave the World Behind', ' The Girl Next Door', ' Hercules',
#        ' Frozen', ' Ben-Hur', ' Conan the Barbarian', ' Hellboy',
#        ' Hellraiser', ' Carrie', ' The Little Mermaid', ' The Karate Kid',
#        ' Memory'], dtype=object)

# %%
filt = (data['Moive Name'] ==' The Mummy' ) | (data['Moive Name'] == ' Hellboy')
data.loc[filt]
# Out:
#       User_Id  Moive Name  Rating     Votes  Meta Score  \
# 499       500   The Mummy     7.1  453000.0        48.0
# 794       795   The Mummy     5.4  203000.0        34.0
# 1489     1490     Hellboy     5.2   96000.0        31.0
# 1809     1810     Hellboy     6.8  345000.0        72.0
#
#                            Genre PG Rating  Year Duration  \
# 499   Action, Adventure, Fantasy     PG-13  1999    2h 4m
# 794   Action, Adventure, Fantasy     PG-13  2017   1h 50m
# 1489  Action, Adventure, Fantasy         R  2019       2h
# 1809  Action, Adventure, Fantasy     PG-13  2004    2h 2m
#
#                                                    Cast            Director
# 499   Brendan Fraser, Rachel Weisz, John Hannah, Arn...     Stephen Sommers
# 794   Tom Cruise, Sofia Boutella, Annabelle Wallis, ...       Alex Kurtzman
# 1489  David Harbour, Milla Jovovich, Ian McShane, Sa...       Neil Marshall
# 1809    Ron Perlman, Doug Jones, Selma Blair, John Hurt  Guillermo del Toro

# %%
filt = (data['Rating'] >=8) & (data['Rating'] <= 9)
data.loc[filt]
# Out:
#       User_Id                    Moive Name  Rating     Votes  Meta Score  \
# 2           3                   Poor Things     8.5    6700.0        86.0
# 7           8                   Oppenheimer     8.4  553000.0        89.0
# 15         16                 The Holdovers     8.0   24000.0        82.0
# 28         29                      Die Hard     8.2  924000.0        72.0
# 37         38         It's a Wonderful Life     8.6  486000.0        89.0
# ...       ...                           ...     ...       ...         ...
# 1795     1796              The Great Escape     8.2  255000.0        86.0
# 1852     1853   Witness for the Prosecution     8.4  134000.0        76.0
# 1859     1860          The Bourne Ultimatum     8.0  653000.0        85.0
# 1892     1893              The Elephant Man     8.2  254000.0        78.0
# 1896     1897                 The Apartment     8.3  192000.0        94.0
#
#                           Genre PG Rating  Year Duration  \
# ...

# %% [markdown]
# # apply method

# %%
data['Moive Name'].apply(len)
# Out:
# 0       23
# 1        6
# 2       12
# 3       27
# 4       13
#         ..
# 1945    18
# 1946     8
# 1947    17
# 1948    14
# 1949    14
# Name: Moive Name, Length: 1950, dtype: int64

# %% [markdown]
# # apply lambda

# %%
data['Moive Name'].apply(lambda x : x.upper())
# Out:
# 0            LEAVE THE WORLD BEHIND
# 1                             WONKA
# 2                       POOR THINGS
# 3        KILLERS OF THE FLOWER MOON
# 4                      MAY DECEMBER
#                    ...
# 1945              DEFINITELY, MAYBE
# 1946                        THE FLY
# 1947               THE MIGHTY DUCKS
# 1948                  LITTLE GIANTS
# 1949                  AMERICAN MADE
# Name: Moive Name, Length: 1950, dtype: object

# %%
data['Moive Name'].apply(lambda x : x.lower())
# Out:
# 0            leave the world behind
# 1                             wonka
# 2                       poor things
# 3        killers of the flower moon
# 4                      may december
#                    ...
# 1945              definitely, maybe
# 1946                        the fly
# 1947               the mighty ducks
# 1948                  little giants
# 1949                  american made
# Name: Moive Name, Length: 1950, dtype: object

# %% [markdown]
# # applymap with str

# %%
people1 = {
   "first": ["hardik", 'mohan', 'randhir'], 
    
    "last": ["kher", 'patel', 'rana'], 
    "email": ["Hardikkher@gmail.com", 'mohanpatel@email.com', 'randhirrana@email.com']
}

# %%
people = pd.DataFrame(people1)
people
# Out:
#      first   last                  email
# 0   hardik   kher   Hardikkher@gmail.com
# 1    mohan  patel   mohanpatel@email.com
# 2  randhir   rana  randhirrana@email.com

# %%
people.applymap(len)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_16656\1752903538.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   people.applymap(len)
#    first  last  email
# 0      6     4     20
# 1      5     5     20
# 2      7     4     21

# %%
people.applymap(lambda x : x.upper())
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_16656\542873420.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   people.applymap(lambda x : x.upper())
#      first   last                  email
# 0   HARDIK   KHER   HARDIKKHER@GMAIL.COM
# 1    MOHAN  PATEL   MOHANPATEL@EMAIL.COM
# 2  RANDHIR   RANA  RANDHIRRANA@EMAIL.COM

# %%
people.applymap(lambda x : x.lower())
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_16656\3224123453.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   people.applymap(lambda x : x.lower())
#      first   last                  email
# 0   hardik   kher   hardikkher@gmail.com
# 1    mohan  patel   mohanpatel@email.com
# 2  randhir   rana  randhirrana@email.com

# %% [markdown]
# # map() function

# %%
people['first'] = people['first'].map({'hardik': 'Anupam', 'randhir': 'ranvir'},na_action=None)
people
# Out:
#     first   last                  email
# 0  Anupam   kher   Hardikkher@gmail.com
# 1     NaN  patel   mohanpatel@email.com
# 2  ranvir   rana  randhirrana@email.com

# %% [markdown]
# # Replace method

# %%
people = pd.DataFrame(people1)

# %%
people['first'] = people['first'].replace({'hardik': 'Anupam', 'randhir': 'ranvir'})
people
# Out:
#     first   last                  email
# 0  Anupam   kher   Hardikkher@gmail.com
# 1   mohan  patel   mohanpatel@email.com
# 2  ranvir   rana  randhirrana@email.com
