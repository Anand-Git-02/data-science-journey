# %%
import pandas as pd

sales_data = pd.DataFrame({
    'OrderID': [1001, 1002, 1003, 1004],
    'Product': ['Laptop', 'Smartphone', 'Monitor', 'Keyboard'],
    'Quantity': [2, 5, 3, 4],
    'Price': [850, 400, 150, 30],
    'Region': ['North', 'East', 'South', 'West']
})

# %%
region_manager = pd.DataFrame({
    'Region': ['North', 'East', 'South', 'West'],
    'Manager': ['Alice Smith', 'Bob Jones', 'Carol Ray', 'David Yuen']
})

# %%
delivery_status = pd.DataFrame({
    'OrderID': [1001, 1002, 1003, 1004],
    'Status': ['Delivered', 'Shipped', 'Pending', 'Delivered']
})

# %% [markdown]
# ### Dataset 2: employees

# %%
employees = pd.DataFrame({
    'EmpID': ['E101', 'E102', 'E103'],
    'Name': ['John Doe', 'Jane Smith', 'Mike Tan'],
    'Department': ['IT', 'HR', 'Sales'],
    'Salary': [60000, 55000, 50000]
})

# %% [markdown]
# ### Supporting Dataset: dept_manager

# %%
dept_manager = pd.DataFrame({
    'Department': ['IT', 'HR', 'Sales'],
    'Manager': ['Sarah Wong', 'Mark Lin', 'Tina Brooks']
})

# %% [markdown]
# ### Supporting Dataset: employee_address

# %%
employee_address = pd.DataFrame({
    'EmpID': ['E101', 'E102', 'E103'],
    'City': ['New York', 'Boston', 'Chicago'],
    'Zip': ['10001', '02110', '60601']
})

# %% [markdown]
# ### Supporting Input Lists

# %%
# For Exercise 10 (OrderDate)
order_dates = ['2025-04-01', '2025-04-03', '2025-04-05', '2025-04-07']

# For Exercise 18 (PerformanceScore)
performance_scores = [8.5, 9.0, 7.8]

# %% [markdown]
# ### 🔹 **Dataset 1: `sales_data.csv`**
#
# | OrderID | Product    | Quantity | Price | Region     |
# |---------|------------|----------|-------|------------|
# | 1001    | Laptop     | 2        | 850   | North      |
# | 1002    | Smartphone | 5        | 400   | East       |
# | 1003    | Monitor    | 3        | 150   | South      |
# | 1004    | Keyboard   | 4        | 30    | West       |
#
# ---
#
# ### ✅ **Exercise Set**
#
# ---
#
# #### **1. Add a new column "TotalPrice" as Quantity * Price**
# - **Input**: `sales_data`
# - **Output**: DataFrame with a new column `TotalPrice`
#
# ---
#
# #### **2. Add a new row for a new order**
# - **Input**: New order: `1005, Mouse, 10, 20, North`
# - **Output**: Row added to `sales_data`
#
# ---
#
# #### **3. Remove rows where Quantity is less than 3**
# - **Input**: `sales_data`
# - **Output**: Only orders with Quantity ≥ 3
#
# ---
#
# #### **4. Drop the "Region" column from the dataset**
# - **Input**: `sales_data`
# - **Output**: DataFrame without `Region`
#
# ---
#
# #### **5. Merge with `region_manager.csv` on Region column**
#
# **region_manager.csv**:
#
# | Region | Manager     |
# |--------|-------------|
# | North  | Alice Smith |
# | East   | Bob Jones   |
# | South  | Carol Ray   |
# | West   | David Yuen  |
#
# - **Output**: Merged DataFrame with a `Manager` column
#
# ---
#
# #### **6. Add a new column "Discount" with a fixed value of 10%**
# - **Input**: `sales_data`
# - **Output**: New column `Discount = 0.1`
#
# ---
#
# #### **7. Remove duplicates from a duplicated dataset**
# - **Input**: Duplicate `sales_data` twice
# - **Output**: DataFrame with unique rows
#
# ---
#
# #### **8. Merge two DataFrames: one with OrderID, another with Delivery Status**
#
# **delivery_status.csv**:
#
# | OrderID | Status     |
# |---------|------------|
# | 1001    | Delivered  |
# | 1002    | Shipped    |
# | 1003    | Pending    |
# | 1004    | Delivered  |
#
# - **Output**: DataFrame with `Status` column
#
# ---
#
# #### **9. Drop all rows where Product is “Monitor”**
# - **Input**: `sales_data`
# - **Output**: No rows with Monitor
#
# ---
#
# #### **10. Add a column “OrderDate” with random recent dates**
# - **Input**: List of 4 dates
# - **Output**: `OrderDate` column added
#
# ---
#
# ### 🔹 **Dataset 2: `employees.csv`**
#
# | EmpID | Name       | Department | Salary |
# |-------|------------|------------|--------|
# | E101  | John Doe   | IT         | 60000  |
# | E102  | Jane Smith | HR         | 55000  |
# | E103  | Mike Tan   | Sales      | 50000  |
#
# ---
#
# #### **11. Add a new employee row**
# - **Input**: E104, Emily Ray, Finance, 58000
# - **Output**: Row added
#
# ---
#
# #### **12. Remove employees with salary below 55,000**
# - **Output**: Only John and Jane remain
#
# ---
#
# #### **13. Merge with department manager data**
#
# **dept_manager.csv**:
#
# | Department | Manager      |
# |------------|--------------|
# | IT         | Sarah Wong   |
# | HR         | Mark Lin     |
# | Sales      | Tina Brooks  |
#
# - **Output**: Manager column added
#
# ---
#
# #### **14. Add a column "Bonus" as 10% of Salary**
# - **Output**: New column with computed values
#
# ---
#
# #### **15. Drop column “Salary” temporarily**
# - **Output**: All data except Salary
#
# ---
#
# #### **16. Remove the row with EmpID E103**
# - **Output**: Mike Tan’s data removed
#
# ---
#
# #### **17. Merge with address info from another dataset**
#
# **employee_address.csv**:
#
# | EmpID | City       | Zip    |
# |-------|------------|--------|
# | E101  | New York   | 10001  |
# | E102  | Boston     | 02110  |
# | E103  | Chicago    | 60601  |
#
# - **Output**: Address columns merged in
#
# ---
#
# #### **18. Add column "PerformanceScore" with values from a list**
# - **Input**: [8.5, 9.0, 7.8]
# - **Output**: Column added
#
# ---
#
# #### **19. Remove all employees in HR department**
# - **Output**: HR department rows deleted
#
# ---
#
# #### **20. Merge `employees` and `sales_data` on a fake key like Name = Manager**
# - **Output**: Demonstrates merging on different logic
